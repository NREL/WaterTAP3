# %%
import watertap as wt
import pandas as pd
from pyomo.environ import value, Block
from idaes.core import FlowsheetBlock
import numpy as np
from case_study_trains import *
import case_study_trains

m = wt.watertap_setup(dynamic = False)


wt.case_study_trains.train = {"case_study": "tampa_bay",
                             "reference": "nawi",
                             "scenario": "baseline"}


wt.case_study_trains.source_water = {"case_study": "tampa_bay", 
                             "reference": "nawi",
                             "scenario": "baseline",
                             "water_type": "seawater"}

m = wt.case_study_trains.get_case_study(m=m) # flow is set as case study flow unless defined.
# Out:
# tampa_bay
# ------- Adding Unit Processes -------
# sw_onshore_intake
# sulfuric_acid_addition
# ferric_chloride_addition
# chlorination
# static_mixer
# tri_media_filtration
# cartridge_filtration
# ro_first_pass
# ro_second_pass
# lime_softening
# chlorination_b
# caustic_soda_addition
# ammonia_addition
# treated_storage
# 21600.0
# backwash_solids_handling
# municipal_drinking
# surface_discharge
# -------------------------------------
# adding source
# adding splitter
# params into splitter --> [0.67, 0.33]
# ----- Connecting Unit Processes -----
# seawater ToUnitName --> sw_onshore_intake
# sw_onshore_intake ToUnitName --> sulfuric_acid_addition
# sulfuric_acid_addition ToUnitName --> ferric_chloride_addition
# ferric_chloride_addition ToUnitName --> chlorination
# chlorination ToUnitName --> static_mixer
# tri_media_filtration ToUnitName --> cartridge_filtration
# tri_media_filtration ToUnitName --> backwash_solids_handling
# lime_softening ToUnitName --> chlorination_b
# chlorination_b ToUnitName --> caustic_soda_addition
# caustic_soda_addition ToUnitName --> ammonia_addition
# ammonia_addition ToUnitName --> treated_storage
# treated_storage ToUnitName --> municipal_drinking
# ro_second_pass ToUnitName --> mixer1
# mixer1 ToUnitName --> lime_softening
# cartridge_filtration ToUnitName --> mixer2
# ro_second_pass ToUnitName --> mixer2
# mixer2 ToUnitName --> ro_first_pass
# static_mixer ToUnitName --> mixer3
# backwash_solids_handling ToUnitName --> mixer3
# mixer3 ToUnitName --> tri_media_filtration
# splitter1 ToUnitName --> ro_second_pass
# splitter1 ToUnitName --> mixer1
# ro_first_pass ToUnitName --> splitter1
# -------------------------------------

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# RUN MODEL with optimal ro so that the model solves. Then runs again with set pressure.

# %%
# # RUN MODEL with optimal ro --> estimating area and pressure for optimal LCOW
# so that the model solves and gets you results. Then runs again with set pressure.
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).feed.pressure.unfix()
        getattr(m.fs, key).membrane_area.unfix()
        print("unfixing feed presure and area for", key)
        
wt.run_water_tap(m = m, objective=True)

# prints RO results
print("optimal ro area and pressures:")
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(key, "feed pressure", getattr(m.fs, key).feed.pressure[0]())
        print(key, "membrane area", getattr(m.fs, key).membrane_area[0]())

# RESET PRESSURE TO USER INPUT
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        if "feed_pressure" in m.fs.pfd_dict[key]["Parameter"]:
            if m.fs.pfd_dict[key]["Parameter"]["type"] == "pass":
                getattr(m.fs, key).feed.pressure.fix(m.fs.pfd_dict[key]["Parameter"]["feed_pressure"])
                print("setting feed presure for", key, "to -->", m.fs.pfd_dict[key]["Parameter"]["feed_pressure"])

wt.run_water_tap(m = m, objective=True, print_model_results="summary")

for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(key, "feed pressure", getattr(m.fs, key).feed.pressure[0]())
        print(key, "membrane area", getattr(m.fs, key).membrane_area[0]())
# Out:
# unfixing feed presure and area for ro_first_pass
# unfixing feed presure and area for ro_second_pass
# degrees_of_freedom: 4
# WaterTAP3 solution optimal
# optimal ro area and pressures:
# ro_first_pass feed pressure 58.34633458170394
# ro_first_pass membrane area 149292.29208671325
# ro_second_pass feed pressure 89.9999984749248
# ro_second_pass membrane area 21315.732816039417
# setting feed presure for ro_first_pass to --> 85
# setting feed presure for ro_second_pass to --> 35
# degrees_of_freedom: 2
# WaterTAP3 solution optimal
# fs.sw_onshore_intake
# total_cap_investment: 10.216867778290633
# ----------------------------------------------------------------------
# fs.sulfuric_acid_addition
# total_cap_investment: 0.23072715211599915
# ----------------------------------------------------------------------
# fs.ferric_chloride_addition
# total_cap_investment: 2.9536394454284336
# ----------------------------------------------------------------------
# fs.chlorination
# total_cap_investment: 9.265881440407075
# ----------------------------------------------------------------------
# fs.static_mixer
# total_cap_investment: 0.1162155841035918
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# total_cap_investment: 8.067722349162832
# ----------------------------------------------------------------------
# fs.cartridge_filtration
# total_cap_investment: 7.584516536765473
# ----------------------------------------------------------------------
# fs.ro_first_pass
# total_cap_investment: 59.24730099590329
# ----------------------------------------------------------------------
# fs.ro_second_pass
# total_cap_investment: 16.20850723823043
# ----------------------------------------------------------------------
# fs.lime_softening
# total_cap_investment: 35.902489513741145
# ----------------------------------------------------------------------
# fs.chlorination_b
# total_cap_investment: 8.219656109145959
# ----------------------------------------------------------------------
# fs.caustic_soda_addition
# total_cap_investment: 1.533310047664485
# ----------------------------------------------------------------------
# fs.ammonia_addition
# total_cap_investment: 0.6617911787444554
# ----------------------------------------------------------------------
# fs.treated_storage
# total_cap_investment: 9.29517303482325
# ----------------------------------------------------------------------
# fs.backwash_solids_handling
# total_cap_investment: 6.2847052741837865
# ----------------------------------------------------------------------
# fs.municipal_drinking
# total_cap_investment: 2.741967830455352
# ----------------------------------------------------------------------
# fs.surface_discharge
# total_cap_investment: 10.021055078703384
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 188.55152658786963
# Annual Fixed Operating Cost ($MM/yr) 2.5024678934274807
# Annual Catalysts and Chemicals Cost ($MM/yr) 3.5095812194608116
# Annual Electricity Costs ($MM/yr) 11.993225389816356
# Annual Other Variable Costs ($MM/yr) 1.072016079818366
# Annual Operating Costs ($MM/yr) 19.077290582523013
# Treated water (m3/s) ---> 1.3167852881287092
# Total water recovery (%) ---> 68.3068493387996
# Electricity intensity (kwh/m3) --->  3.7753132101044704
# LCOW ($/m3) --->  0.8237498644816008
# Electricity portion of LCOW (%) ---> 35.06057761293177
# ----------------------------------------------------------------------
# ro_first_pass feed pressure 85
# ro_first_pass membrane area 104453.73834628114
# ro_second_pass feed pressure 35
# ro_second_pass membrane area 74215.60829011319

# %%
# If you need the system recovery to match better.... set a maximum recovery rate.

# %%
from pyomo.environ import Constraint
m.recovery_bound = Constraint(expr = m.fs.costing.system_recovery <= 0.55) # THIS IS FOR TAMPA BAY
#m.recovery_bound = Constraint(expr = m.fs.costing.system_recovery <= 0.50) # THIS IS FOR SANTA BARBARA

# %%
# set cap utilization factor
m.fs.costing_param.plant_cap_utilization = 0.75

# %%
wt.run_water_tap(m = m, objective=True, print_model_results="summary")
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(key, "feed pressure", getattr(m.fs, key).feed.pressure[0]())
        print(key, "membrane area", getattr(m.fs, key).membrane_area[0]())
# Out:
# degrees_of_freedom: 2
# WaterTAP3 solution optimal
# fs.sw_onshore_intake
# total_cap_investment: 10.216867778290633
# ----------------------------------------------------------------------
# fs.sulfuric_acid_addition
# total_cap_investment: 0.23072715211599915
# ----------------------------------------------------------------------
# fs.ferric_chloride_addition
# total_cap_investment: 2.9536394454284336
# ----------------------------------------------------------------------
# fs.chlorination
# total_cap_investment: 9.265881440407075
# ----------------------------------------------------------------------
# fs.static_mixer
# total_cap_investment: 0.1162155841035918
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# total_cap_investment: 8.067722349162832
# ----------------------------------------------------------------------
# fs.cartridge_filtration
# total_cap_investment: 7.584516536765473
# ----------------------------------------------------------------------
# fs.ro_first_pass
# total_cap_investment: 56.742191992275345
# ----------------------------------------------------------------------
# fs.ro_second_pass
# total_cap_investment: 12.90133982397298
# ----------------------------------------------------------------------
# fs.lime_softening
# total_cap_investment: 30.646011881054868
# ----------------------------------------------------------------------
# fs.chlorination_b
# total_cap_investment: 7.6773679091494635
# ----------------------------------------------------------------------
# fs.caustic_soda_addition
# total_cap_investment: 1.3407075846803524
# ----------------------------------------------------------------------
# fs.ammonia_addition
# total_cap_investment: 0.6039757845113588
# ----------------------------------------------------------------------
# fs.treated_storage
# total_cap_investment: 7.950910090940397
# ----------------------------------------------------------------------
# fs.backwash_solids_handling
# total_cap_investment: 6.2847052741837865
# ----------------------------------------------------------------------
# fs.municipal_drinking
# total_cap_investment: 2.272995815973161
# ----------------------------------------------------------------------
# fs.surface_discharge
# total_cap_investment: 13.365277233665381
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 178.22105367668104
# Annual Fixed Operating Cost ($MM/yr) 2.365545925952114
# Annual Catalysts and Chemicals Cost ($MM/yr) 3.275256768186887
# Annual Electricity Costs ($MM/yr) 9.91845265069753
# Annual Other Variable Costs ($MM/yr) 0.6976410015225003
# Annual Operating Costs ($MM/yr) 16.25689634635903
# Treated water (m3/s) ---> 1.0602625152213458
# Total water recovery (%) ---> 55.000000789591276
# Electricity intensity (kwh/m3) --->  3.8775952507042697
# LCOW ($/m3) --->  1.2185434410906735
# Electricity portion of LCOW (%) ---> 32.45799060046844
# ----------------------------------------------------------------------
# ro_first_pass feed pressure 85
# ro_first_pass membrane area 58672.389479765174
# ro_second_pass feed pressure 35
# ro_second_pass membrane area 57601.11077398489

# %%
# RESET AREA TO USER INPUT
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).membrane_area.fix(getattr(m.fs, key).membrane_area[0]())

# %%
# Readjust recovery constraint
m.recovery_bound = Constraint(expr = m.fs.costing.system_recovery >= 0)

# %%
# NOW RUN AS SIMULATION
wt.run_water_tap(m = m, objective=False, print_model_results="summary")
# Out:
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# fs.sw_onshore_intake
# total_cap_investment: 10.216867778290633
# ----------------------------------------------------------------------
# fs.sulfuric_acid_addition
# total_cap_investment: 0.23072715211599915
# ----------------------------------------------------------------------
# fs.ferric_chloride_addition
# total_cap_investment: 2.9536394454284336
# ----------------------------------------------------------------------
# fs.chlorination
# total_cap_investment: 9.265881440407075
# ----------------------------------------------------------------------
# fs.static_mixer
# total_cap_investment: 0.1162155841035918
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# total_cap_investment: 8.067722349162832
# ----------------------------------------------------------------------
# fs.cartridge_filtration
# total_cap_investment: 7.584516536765473
# ----------------------------------------------------------------------
# fs.ro_first_pass
# total_cap_investment: 56.742191992275465
# ----------------------------------------------------------------------
# fs.ro_second_pass
# total_cap_investment: 12.901339823973016
# ----------------------------------------------------------------------
# fs.lime_softening
# total_cap_investment: 30.64601188105482
# ----------------------------------------------------------------------
# fs.chlorination_b
# total_cap_investment: 7.67736790914946
# ----------------------------------------------------------------------
# fs.caustic_soda_addition
# total_cap_investment: 1.340707584680351
# ----------------------------------------------------------------------
# fs.ammonia_addition
# total_cap_investment: 0.6039757845113584
# ----------------------------------------------------------------------
# fs.treated_storage
# total_cap_investment: 7.9509100909403845
# ----------------------------------------------------------------------
# fs.backwash_solids_handling
# total_cap_investment: 6.2847052741837865
# ----------------------------------------------------------------------
# fs.municipal_drinking
# total_cap_investment: 2.2729958159731565
# ----------------------------------------------------------------------
# fs.surface_discharge
# total_cap_investment: 13.365277233717416
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 178.22105367673322
# Annual Fixed Operating Cost ($MM/yr) 2.3655459259528056
# Annual Catalysts and Chemicals Cost ($MM/yr) 3.275256768186887
# Annual Electricity Costs ($MM/yr) 9.918452650697537
# Annual Other Variable Costs ($MM/yr) 0.6976410015225003
# Annual Operating Costs ($MM/yr) 16.25689634635973
# Treated water (m3/s) ---> 1.0602625152213438
# Total water recovery (%) ---> 55.000000789591176
# Electricity intensity (kwh/m3) --->  3.87759525070428
# LCOW ($/m3) --->  1.2185434410908709
# Electricity portion of LCOW (%) ---> 32.45799060046327
# ----------------------------------------------------------------------

# %%
# creates csv in results folder with the name: *case_study*_*scenario*.csv
# In this case, save the final baseline result.

df = wt.get_results_table(m = m, case_study = wt.case_study_trains.source_water["case_study"], 
                                scenario = wt.case_study_trains.source_water["scenario"])

# %%
# sensitivity analyses
sens_df = pd.DataFrame()

lcow_list = []
water_recovery_list = []
scenario_value = []
scenario_name = []
elec_lcow = []

lcow_list.append(value(m.fs.costing.LCOW))
water_recovery_list.append(value(m.fs.costing.system_recovery))
scenario_value.append("n/a")
scenario_name.append("baseline")
elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))

runs_per_scenario = 50

############ onstream_factor 70-100% ############
stash_value = m.fs.costing_param.plant_cap_utilization
scenario = "plant_cap_utilization"
print(scenario)
ub = 1
lb = 0.7
step = (ub - lb) / runs_per_scenario
for i in np.arange(lb, ub, step):
    m.fs.costing_param.plant_cap_utilization = i
    wt.run_water_tap(m = m, objective=False)
    print("LCOW -->", m.fs.costing.LCOW())
    
    lcow_list.append(value(m.fs.costing.LCOW))
    water_recovery_list.append(value(m.fs.costing.system_recovery))
    scenario_value.append(i)
    scenario_name.append(scenario)
    elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
m.fs.costing_param.plant_cap_utilization = stash_value    
############################################################    

############ salinity  30-45 ############
stash_value = m.fs.seawater.conc_mass_in[0, "tds"]()
scenario = "inlet salinty 25k-45k mg/L"
print(scenario)
ub = 25
lb = 45
step = (ub - lb) / runs_per_scenario
for i in np.arange(lb, ub, step):
    m.fs.seawater.conc_mass_in[0, "tds"].fix(i) 
    wt.run_water_tap(m = m, objective=False)
    print("LCOW -->", m.fs.costing.LCOW())
    
    lcow_list.append(value(m.fs.costing.LCOW))
    water_recovery_list.append(value(m.fs.costing.system_recovery))
    scenario_value.append(i)
    scenario_name.append(scenario)
    elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
m.fs.seawater.conc_mass_in[0, "tds"].fix(stash_value) 
############################################################

############ inlet flow ############
stash_value = m.fs.seawater.flow_vol_in[0]()
scenario = "inlet flow"
print(scenario)
ub = stash_value * 1.3
lb = stash_value * 0.7
step = (ub - lb) / runs_per_scenario
for i in np.arange(lb, ub, step):
    m.fs.seawater.flow_vol_in.fix(i) 
    wt.run_water_tap(m = m, objective=False)
    print("LCOW -->", m.fs.costing.LCOW())
    
    lcow_list.append(value(m.fs.costing.LCOW))
    water_recovery_list.append(value(m.fs.costing.system_recovery))
    scenario_value.append(i)
    scenario_name.append(scenario)
    elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
m.fs.seawater.flow_vol_in.fix(stash_value) 
############################################################

############ lifetime years ############

stash_value = value(m.fs.costing_param.plant_lifetime_yrs)
scenario = "lifetime (yrs)"
print(scenario)
ub = 50
lb = 15
step = (ub - lb) / runs_per_scenario
for i in np.arange(lb, ub, step):
    m.fs.costing_param.plant_lifetime_yrs = i 
    wt.run_water_tap(m = m, objective=False)
    print("LCOW -->", m.fs.costing.LCOW())
    
    lcow_list.append(value(m.fs.costing.LCOW))
    water_recovery_list.append(value(m.fs.costing.system_recovery))
    scenario_value.append(i)
    scenario_name.append(scenario)
    elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
m.fs.costing_param.plant_lifetime_yrs = stash_value
############################################################

############ elec cost +-20% ############

stash_value = value(m.fs.costing_param.electricity_price)
scenario = "electricity price +- 20%"
print(scenario)
ub = stash_value * 1.3
lb = stash_value * 0.7
step = (ub - lb) / runs_per_scenario
for i in np.arange(lb, ub, step):
    m.fs.costing_param.electricity_price = i 
    wt.run_water_tap(m = m, objective=False)
    print("LCOW -->", m.fs.costing.LCOW())
    
    lcow_list.append(value(m.fs.costing.LCOW))
    water_recovery_list.append(value(m.fs.costing.system_recovery))
    scenario_value.append(i)
    scenario_name.append(scenario)
    elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
m.fs.costing_param.electricity_price = stash_value
############################################################

############ RO scenarios --> pressure, membrane area, replacement rate% ############

for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        area = value(getattr(m.fs, key).membrane_area[0])

        scenario_dict = {"membrane_area" : [-area*0.2, area*0.2], 
                         "pressure": [-10, 10], 
                         "factor_membrane_replacement": [-0.1, 0.1]}
        
        for scenario in scenario_dict.keys():
            if scenario == "pressure":
                stash_value = value(getattr(getattr(getattr(m.fs, key), "feed"), scenario)[0])
            else:
                stash_value = value(getattr(getattr(m.fs, key), scenario)[0])

            print(scenario)
            ub = stash_value + scenario_dict[scenario][1]
            lb = stash_value + scenario_dict[scenario][0]
            step = (ub - lb) / runs_per_scenario
            
            for i in np.arange(lb, ub, step):
                if scenario == "pressure":
                    getattr(getattr(getattr(m.fs, key), "feed"), scenario).fix(i)
                else:
                    getattr(getattr(m.fs, key), scenario).fix(i)
                
                wt.run_water_tap(m = m, objective=False)
                print("LCOW -->", m.fs.costing.LCOW())
    
                lcow_list.append(value(m.fs.costing.LCOW))
                water_recovery_list.append(value(m.fs.costing.system_recovery))
                scenario_value.append(i)
                scenario_name.append(key + "_" + scenario)
                elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
    
            if scenario == "pressure":
                getattr(getattr(getattr(m.fs, key), "feed"), scenario).fix(stash_value)
            else:
                getattr(getattr(m.fs, key), scenario).fix(stash_value)
                            
############################################################

# final run to get baseline numbers again
wt.run_water_tap(m = m, objective=False)

sens_df["lcow"] = lcow_list
sens_df["water_recovery"] =  water_recovery_list
sens_df["elec_lcow"] =  elec_lcow
sens_df["scenario_value"] = scenario_value
sens_df["scenario_name"] = scenario_name
sens_df["lcow_difference"] =  sens_df.lcow - value(m.fs.costing.LCOW)
sens_df["water_recovery_difference"] = (sens_df.water_recovery - value(m.fs.costing.system_recovery))
sens_df["elec_lcow_difference"] = (sens_df.elec_lcow - value(m.fs.costing.elec_frac_LCOW))

sens_df.elec_lcow = sens_df.elec_lcow * 100
sens_df.water_recovery = sens_df.water_recovery * 100
# Out:
# plant_cap_utilization
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3055822583116472
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2944866583826526
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.283578062946844
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2728517838692934
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2623032884228627
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.251928192901579
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.241722256546403
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2316813757657044
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221801578633894
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2120790196527227
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2025099747607275
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1930908365772233
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1838181098680738
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1746884072212762
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1656984449211134
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.15684503901032
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1481251015303424
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1395356369303649
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1310737386363277
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1227365857716864
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1145214400221375
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.106425642636989
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0984466115602798
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0905818386851462
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0828288872252996
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.075185389197827
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0676490430118606
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.06021761115795
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0528889179932637
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0456608476180236
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.03853134183881
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0314983982146195
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0245600681817857
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0177144552540676
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0109597132944166
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0042940448551125
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9977156995831362
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9912229726878011
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9848142034678371
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9784877738952386
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.972242107253354
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9660756668267999
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9599869546409164
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9539745102485935
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.948036909562399
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9421727637300543
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9363807180513858
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.930659450934982
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9250076728928669
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 0.9194241255715823
# inlet salinty 25k-45k mg/L
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4576806831213007
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4496450941895787
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4417235607750967
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.433913489940981
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4262123700899805
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.418617768453576
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4111273287606612
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.403738769088031
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.396449879895438
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3892585222499505
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3821626262465525
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.37516018963451
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3682492766621082
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3614280171558963
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3546946058549465
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3480473020257517
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3414844293896786
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3350043764025554
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3286055969353259
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3222866114163292
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3160460085101664
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3098824474260837
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3037946609714748
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2977814594946149
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.291841735897096
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2859744719428243
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.280178746150058
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.274453743630057
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2687987683360586
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2632132583172508
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2576968047443924
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2522491757009535
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.246870346035103
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2415605349694108
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.236320253701545
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2311503659466325
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2260521653300183
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2210274748118721
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2160787749962023
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2112093703224645
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2064236047799486
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2017271417791222
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1971273256042547
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1926336429824098
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1882582993578543
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.184016908474428
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1799292528580683
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1760199860029494
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1723189911368412
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1688608859062302
# inlet flow
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1752122619144296
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1757548365991581
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1764190300160828
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1772011034188539
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1780974980348404
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1791048233660086
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.180219847052989
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1814394861603084
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1827607997588152
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.184180982708117
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.185697360483698
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1873073851254905
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.189008632034289
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1907987977158356
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1926756983667781
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1946372692783818
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.196681565032388
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.198806760470999
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2010111524289317
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2032931622192256
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2056513388689416
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2080843630984222
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.210591051999401
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2131703644429621
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2158214071104745
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410906764
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221335888908016
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2241983417872668
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2271305668721655
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2301325140017223
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2332043215029922
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2363463202809084
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2395590352750852
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2428431831168358
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2461996645729165
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2496295501349355
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2531340569519709
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2567145152758896
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.260372322780944
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2641088856281388
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2679255460586492
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2718234976641292
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2758036912546773
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2798667362585838
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2840128045239458
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2882415448104854
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2925520166880842
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.296942651639637
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3014112468158154
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3059549933948553
# lifetime (yrs)
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3329617498079842
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3122971015916944
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2934779476228613
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2762772363955786
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2605036177570639
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.245994688902181
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2326117178146772
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2202354803614783
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2087629461415637
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1981046178356085
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1881823785035521
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1789277371845555
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.170280389393754
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1621870284907876
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.154600358352326
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1474782686662937
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.140783142433473
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.134481271593764
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1285423615807342
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1229391094066696
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1176468428537065
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1126432106892727
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1079079156812515
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1034224836692321
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.099170063135766
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0951352506789334
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0913039385631815
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0876631811569635
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.08420107758223
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0809066683252024
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0777698439079408
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.074781264010222
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0719322856723887
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0692148994111133
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0666216722485973
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0641456967974465
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0617805456629479
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0595202305255675
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0573591653522711
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0552921332582699
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0533142566031066
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.051420969958324
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0496079956297077
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0478713214564812
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0462071806437612
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0446120334139548
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0430825502881946
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0416155968310188
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0402082197107028
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0388576339444455
# electricity price +- 20%
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.0998890264193195
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1046352030061815
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1093813795930436
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1141275561799056
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1188737327667677
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1236199093536297
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1283660859404916
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1331122625273538
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1378584391142157
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1426046157010779
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1473507922879398
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1520969688748017
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.156843145461664
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.161589322048526
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1663354986353878
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1710816752222502
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.175827851809112
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1805740283959743
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1853202049828362
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1900663815696986
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1948125581565603
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1995587347434225
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2043049113302844
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2090510879171465
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2137972645040085
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410908706
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2232896176777328
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2280357942645947
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.232781970851457
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2375281474383188
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.242274324025181
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2470205006120432
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.251766677198905
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.256512853785767
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2612590303726292
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.266005206959491
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.270751383546353
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.275497560133215
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2802437367200772
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2849899133069393
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2897360898938013
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2944822664806637
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2992284430675254
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3039746196543878
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3087207962412493
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3134669728281116
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.318213149414974
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3229593260018357
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3277055025886981
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3324516791755598
# membrane_area
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.314842971780564
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3097191026526391
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.30472298078674
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2998510850125577
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.295100035705129
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2904665893786067
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.285947633690954
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2815401828537223
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2772413734323727
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2730484605247714
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2689588143075818
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2649699169422193
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2610793598339118
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2572848412391309
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.253584164218204
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2499752349313098
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2464560612771298
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2430247518742
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2396795153852787
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2364186601847595
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2332405943680376
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2301438260995923
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2271269642930451
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2241887196112191
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221327905766761
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410935938
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2158343503457356
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2131997666619228
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.210638933611229
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2081512072054839
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2057360577277991
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2033930711822598
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2011219501172192
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.198922513514069
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1967946953659347
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1947385414999636
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1927542041258876
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1908419335338913
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1890020663245564
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1872350095503155
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1855412201998423
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1839211795852227
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1823753624168691
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.180904200687462
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1795080429359825
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1781871100087051
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1769414490324248
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1757708878942148
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.174674992985796
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.1736530332132937
# pressure
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2564861232904252
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.254187688538615
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.251962396214936
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2498088432338896
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2477256878777472
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2457116491791473
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2437655065511677
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2418860996884757
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2400723287614384
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2383231549295486
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.236637601205677
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.235014753708662
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2334537633486584
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.23195384799772
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.230514295207437
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2291344655462766
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2278137966417912
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2265518080273279
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2253481069093985
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2242023949906808
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2231144765047341
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2220842676418213
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2211118075702476
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2201972712835893
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2193409845291658
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218543441094571
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2178053227420325
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2171275220778408
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2165111686147847
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2159576582132108
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2154686859471329
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2150462822026673
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2146928514320166
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2144112123998279
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2142046379023488
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2140768907422774
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2140322511490849
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2140755288540204
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2142120507782213
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214447613113041
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214788385115618
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2152407522451636
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.215811089667218
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2165054649458331
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2173292814410073
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182868902796662
# degrees_of_freedom: 0
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 1
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 2
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 3
# WaterTAP3 solution infeasible
# WaterTAP3 solver returned an infeasible FINAL solution. Check option to run model with updated initial conditions
# LCOW --> 1.22092473579657
# degrees_of_freedom: 0
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 1
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 2
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 3
# WaterTAP3 solution infeasible
# WaterTAP3 solver returned an infeasible FINAL solution. Check option to run model with updated initial conditions
# LCOW --> 1.2235902079767977
# degrees_of_freedom: 0
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 1
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 2
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 3
# WaterTAP3 solution infeasible
# WaterTAP3 solver returned an infeasible FINAL solution. Check option to run model with updated initial conditions
# LCOW --> 1.2262837270960405
# degrees_of_freedom: 0
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 1
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 2
# WaterTAP3 solver returned an infeasible solution
# Running again with updated initial conditions --- attempt 3
# WaterTAP3 solution infeasible
# WaterTAP3 solver returned an infeasible FINAL solution. Check option to run model with updated initial conditions
# LCOW --> 1.2290055906288588
# factor_membrane_replacement
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.211524465171608
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.211805224208433
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2120859832452013
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2123667422819695
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2126475013187374
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.212928260355506
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2132090193922742
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2134897784290424
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2137705374658103
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2140512965025787
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214332055539347
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2146128145761153
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2148935736128832
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2151743326496516
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2154550916864197
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2157358507231881
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2160166097599563
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2162973687967245
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2165781278334928
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.216858886870261
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2171396459070292
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2174204049437973
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2177011639805657
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.217981923017334
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218262682054102
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410908706
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2188242001276386
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.219104959164407
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.219385718201175
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2196664772379435
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2199472362747112
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2202279953114796
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2205087543482478
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.220789513385016
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2210702724217843
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2213510314585527
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221631790495321
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221912549532089
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2221933085688574
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2224740676056256
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.222754826642394
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2230355856791622
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2233163447159303
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2235971037526983
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2238778627894669
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.224158621826235
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2244393808630034
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2247201398997714
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2250008989365393
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.225281657973308
# membrane_area
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3039146316823427
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2970998271018255
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.290400890558672
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2838280497602714
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2773949402051183
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2711197440276416
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2650266761482523
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2591478154648714
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2535250964685216
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2482118545133534
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2432725517883327
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2387783940861383
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2347965518395054
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2313735925866285
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2285196665886762
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.226203314010328
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2243608498264842
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2229138341887231
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2217847538986093
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2209059750783078
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2202225804641045
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2196917025492628
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.21928050989664
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2189640178304202
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2187231901552233
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218543441092674
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2184135043372397
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2183245964545086
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182698025857073
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182436254249605
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182416526964606
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218260310378554
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182966781060611
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2183483498915875
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218413328105095
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.218489942052331
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185767848989566
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2186726643931667
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2187765640546107
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2188876123681969
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2190050581497782
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2191282507076047
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.219256623758295
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2193896823032806
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.219526991855729
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2196681695458862
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2198128767370542
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2199608128636565
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2201117102636767
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2202653298245358
# pressure
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4391394639708404
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4246211619295277
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.4104012586002377
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.396475543738585
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3828410479332394
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3694963785566003
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3564422096358717
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3436820064029003
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3312231139868662
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.31907841978678
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.3072689283779784
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.295827784471633
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2848065278376213
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.27428447780315
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2643813264017232
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.255268884453386
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.247166472869156
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2402901725139943
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2347477556181494
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2304577188972865
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2271888128797381
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2246741026870023
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2226897473495448
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.221073890911503
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2197163932153687
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410920937
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2175052241836337
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.216567561505568
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2157065134449545
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214904956239127
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2141503899530695
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2134335149743762
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2127472906993977
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2120863010814449
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.211446318855286
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2108240007558002
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2102166706847848
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.209622162968032
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.209038707357739
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.20846484349382
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.207899356461254
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2073412276633206
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2067895969575275
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.206243733173194
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.205703010936539
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2051668922921
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2046349120070519
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2041066657293538
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2035818003762877
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2030600062801844
# factor_membrane_replacement
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2116526222064024
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2119282549614852
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2122038877168766
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2124795204722674
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2127551532276586
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2130307859830496
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2133064187384406
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2135820514938314
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2138576842492226
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2141333170046136
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2144089497600046
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214684582515396
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.214960215270787
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.215235848026178
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2155114807815688
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2157871135369598
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2160627462923512
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2163383790477418
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.216614011803133
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.216889644558524
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2171652773139152
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2174409100693062
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2177165428246974
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2179921755800884
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2182678083354794
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2185434410908706
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2188190738462614
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2190947066016524
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2193703393570436
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2196459721124346
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2199216048678254
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2201972376232169
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2204728703786076
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2207485031339986
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2210241358893896
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2212997686447808
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2215754014001716
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2218510341555626
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2221266669109538
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2224022996663448
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2226779324217358
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2229535651771268
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2232291979325178
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.223504830687909
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2237804634433
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.224056096198691
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2243317289540823
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2246073617094733
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2248829944648645
# degrees_of_freedom: 0
# WaterTAP3 solution optimal
# LCOW --> 1.2251586272202555
# degrees_of_freedom: 0
# WaterTAP3 solution optimal

# %%
sens_df.to_csv("results/case_studies/tampa_bay_baseline_sensitivity.csv")

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)
