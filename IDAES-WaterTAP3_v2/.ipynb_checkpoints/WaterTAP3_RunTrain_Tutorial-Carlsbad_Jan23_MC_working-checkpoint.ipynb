# %%
# %matplotlib inline
from pylab import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import write_dot, graphviz_layout
from pyomo.environ import ConcreteModel, SolverFactory, TerminationCondition, \
    value, Var, Constraint, Expression, Objective, TransformationFactory, units as pyunits
from pyomo.network import Arc, SequentialDecomposition
from idaes.core.util.model_statistics import degrees_of_freedom

from split_test2 import Separator1

from mixer_example import Mixer1

# %% [markdown]
# ### TODO: CREATE INTRO

# %% [markdown]
# ##### Import WaterTAP3 Package

# %%
import watertap as wt

# %% [markdown]
# ##### Step 1: Look up unit process library. Returns a List.

# %% [markdown]
# ##### Step 3: Set up IDAES flowsheet for watertap. This selects a property package for you (see water_props.py). The property package could be changed in the future for performing heat/energy and other balances.

# %%
m = wt.watertap_setup(dynamic = False)

# %% [markdown]
# ##### Step 3: Add a water source and define inlet flow.

# %%
m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)
# Out:
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
##### Step 5:  Run model and display results. The resutls display will be put into easier format to read for user soon.

# %%
result = wt.run_water_tap(m)
# Out:
# Ipopt 3.12.13:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      133
#
# Total number of variables............................:      283
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      283
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 4.57e+02 1.80e+04  -1.0 1.54e+03    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 5.38e-01 4.96e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.86e+02 1.83e+07  -1.0 3.84e+04    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 5.36e-01 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.82e+02 7.83e+07  -1.0 7.93e+04    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 4.16e-02 1.28e+06  -1.0 1.83e+00   4.9 1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 2.75e+02 2.85e+08  -1.0 1.51e+05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 2.01e-02 1.14e+06  -1.0 2.46e+00   4.4 1.00e+00 1.00e+00h  1
#   11  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   12  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   13  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   14  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   15  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   16  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   17  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   18  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   19  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.90e+05    -  1.00e+00 6.10e-05h 15
#   21  0.0000000e+00 2.61e+02 1.07e+09  -1.7 2.90e+05    -  1.00e+00 1.00e+00w  1
#   22  0.0000000e+00 1.30e-02 1.05e+06  -1.7 3.41e+00   3.9 1.00e+00 1.00e+00h  1
#   23  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.39e+05    -  1.00e+00 1.22e-04h 14
#   24  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   25  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   26  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   27  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   28  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   29  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.40e+05    -  1.00e+00 6.10e-05h 15
#   31  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5

# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142727946, (0.0, 'TOC'): 139.98600277526563, (0.0, 'nitrates'): -6.184192140031203e-22}
#          :    flow_vol : {0.0: 4.583299909134666}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1281.3506046896923, (0.0, 'TOC'): 249.15150646743643, (0.0, 'nitrates'): 1.1005705853839129e-17}
#          :    flow_vol : {0.0: 0.00025753888029725883}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.swoi
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142727946, (0.0, 'TOC'): 139.98600277526563, (0.0, 'nitrates'): -6.1843527529351085e-22}
#          :    flow_vol : {0.0: 4.583299909134666}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136249308, (0.0, 'TOC'): 139.9874026492921, (0.0, 'nitrates'): 1.7197522118270783e-22}
#          :    flow_vol : {0.0: 4.5832540761355745}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.6600561900882947e-13, (0.0, 'TOC'): 1.30085086322681e-11, (0.0, 'nitrates'): -7.904095451916211e-17}
#          :    flow_vol : {0.0: 4.583299909109287e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost swoi
# total_up_cost: 23.36602641172056
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136249308, (0.0, 'TOC'): 139.9874026492921, (0.0, 'nitrates'): 1.7195978301826649e-22}
#          :    flow_vol : {0.0: 4.5832540761355745}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9568485639583, (0.0, 'TOC'): 76.99538519364555, (0.0, 'nitrates'): 3.505872659417516e-23}
#          :    flow_vol : {0.0: 4.583116347849939}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 2.4354641102618194e-14, (0.0, 'TOC'): 1144161.1977068093, (0.0, 'nitrates'): 2.4865291978472063e-18}
#          :    flow_vol : {0.0: 0.00025234121362327836}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost coag_floc
# total_up_cost: 14.21137321157784
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer1
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9568485639583, (0.0, 'TOC'): 76.99538519364555, (0.0, 'nitrates'): 3.504390495303609e-23}
#          :    flow_vol : {0.0: 4.583116347849939}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 0.4812111083378385}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 651.5467412142722, (0.0, 'TOC'): 69.67931275453974, (0.0, 'nitrates'): 9.501974595854331e-06}
#          :    flow_vol : {0.0: 5.064327456187778}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should skip: mixer1
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 651.5467412142722, (0.0, 'TOC'): 69.67931275453974, (0.0, 'nitrates'): 9.501974595854331e-06}
#          :    flow_vol : {0.0: 5.064327456187778}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.9408235714135, (0.0, 'TOC'): 77.42145861615526, (0.0, 'nitrates'): 1.0557749550949255e-05}
#          :    flow_vol : {0.0: 4.557894710569}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -4.472756102227533e-25, (0.0, 'TOC'): -3.3496617972428515e-26, (0.0, 'nitrates'): -1.1843635000126307e-29}
#          :    flow_vol : {0.0: 0.5064327456187773}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost tri_media_filtration
# total_up_cost: 42.35423210804329
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.splitter1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.4823824646207997e-24, (0.0, 'TOC'): -4.054487199500678e-24, (0.0, 'nitrates'): -1.500388014131775e-27}
#          :    flow_vol : {0.0: 0.5064327456187773}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 0.4812111083378385}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 0.025421637280938887}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: splitter1
# ----------------------------------------------------------------------
# fs.SAA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.9408235714135, (0.0, 'TOC'): 77.42145861615526, (0.0, 'nitrates'): 1.0557749550949255e-05}
#          :    flow_vol : {0.0: 4.557894710569}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.948063052044, (0.0, 'TOC'): 77.42223283848365, (0.0, 'nitrates'): 1.0557855129500551e-05}
#          :    flow_vol : {0.0: 4.557849131621895}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 4.482036126251499e-16, (0.0, 'TOC'): -3.9010201665118276e-16, (0.0, 'nitrates'): 2.1072046146131917e-19}
#          :    flow_vol : {0.0: 4.5578947105436974e-05}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SAA
# total_up_cost: 0.7168792202834147
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.SBA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.948063052044, (0.0, 'TOC'): 77.42223283848365, (0.0, 'nitrates'): 1.0557855129500551e-05}
#          :    flow_vol : {0.0: 4.557849131621895}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.95530260507, (0.0, 'TOC'): 77.42300706855434, (0.0, 'nitrates'): 1.0557960709107642e-05}
#          :    flow_vol : {0.0: 4.5578035531305785}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -4.603064093456815e-16, (0.0, 'TOC'): -8.089714639871366e-16, (0.0, 'nitrates'): -2.403689465709441e-19}
#          :    flow_vol : {0.0: 4.5578491316252795e-05}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SBA
# total_up_cost: 1.2175901406857728
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.cf
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.95530260507, (0.0, 'TOC'): 77.42300706855434, (0.0, 'nitrates'): 1.0557960709107642e-05}
#          :    flow_vol : {0.0: 4.5578035531305785}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.9625422304923, (0.0, 'TOC'): 77.4237813063674, (0.0, 'nitrates'): 1.0558066289770534e-05}
#          :    flow_vol : {0.0: 4.557757975095047}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.2341802368805914e-12, (0.0, 'TOC'): -7.458082959764411e-13, (0.0, 'nitrates'): 4.575980003758323e-16}
#          :    flow_vol : {0.0: 4.5578035531509514e-05}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost cf
# total_up_cost: 13.380566057903298
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 723.9625422304923, (0.0, 'TOC'): 77.4237813063674, (0.0, 'nitrates'): 1.0558066289770534e-05}
#          :    flow_vol : {0.0: 4.557757975095047}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7810954725801, (0.0, 'TOC'): 147.06193097298836, (0.0, 'nitrates'): 2.0054427589508283e-05}
#          :    flow_vol : {0.0: 2.399525522182392}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1146.648747011028, (0.0, 'TOC'): 2.772664069343583e-24, (0.0, 'nitrates'): 1.261530888654115e-27}
#          :    flow_vol : {0.0: 2.158232452912655}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ro
# total_up_cost: 330.1512751203201
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7810954725801, (0.0, 'TOC'): 147.06193097298836, (0.0, 'nitrates'): 2.0054427589508283e-05}
#          :    flow_vol : {0.0: 2.399525522182392}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.78453331791326, (0.0, 'TOC'): 147.06340160700444, (0.0, 'nitrates'): 2.0054628135789643e-05}
#          :    flow_vol : {0.0: 2.3995015269271702}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.1757276673851415e-13, (0.0, 'TOC'): -1.9503031826887574e-13, (0.0, 'nitrates'): -6.003059583289608e-17}
#          :    flow_vol : {0.0: 2.399525522189635e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost lime
# total_up_cost: 58.86326081903539
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.co2
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.78453331791326, (0.0, 'TOC'): 147.06340160700444, (0.0, 'nitrates'): 2.0054628135789643e-05}
#          :    flow_vol : {0.0: 2.3995015269271702}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7879711976252, (0.0, 'TOC'): 147.06487225572698, (0.0, 'nitrates'): 2.005482868407648e-05}
#          :    flow_vol : {0.0: 2.3994775319119013}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 4.633203481353762e-15, (0.0, 'TOC'): -6.469540593522044e-15, (0.0, 'nitrates'): -2.2119000074774012e-18}
#          :    flow_vol : {0.0: 2.399501526894995e-05}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost co2
# total_up_cost: 8.617171813378992
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.chlor
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7879711976252, (0.0, 'TOC'): 147.06487225572698, (0.0, 'nitrates'): 2.005482868407648e-05}
#          :    flow_vol : {0.0: 2.3994775319119013}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.79140911171635, (0.0, 'TOC'): 147.06634291915617, (0.0, 'nitrates'): 2.0055029234368822e-05}
#          :    flow_vol : {0.0: 2.399453537136582}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.1577910685164025e-18, (0.0, 'TOC'): 7.066733175009476e-19, (0.0, 'nitrates'): -8.530972972885736e-22}
#          :    flow_vol : {0.0: 2.3994775319112173e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost chlor
# total_up_cost: 10.469047400765668
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.79140911171635, (0.0, 'TOC'): 147.06634291915617, (0.0, 'nitrates'): 2.0055029234368822e-05}
#          :    flow_vol : {0.0: 2.399453537136582}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7948470601869, (0.0, 'TOC'): 147.06781359729214, (0.0, 'nitrates'): 2.0055229786666688e-05}
#          :    flow_vol : {0.0: 2.399429542601211}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.0847727519825232e-19, (0.0, 'TOC'): 5.101807287495677e-21, (0.0, 'nitrates'): -6.724412153300272e-25}
#          :    flow_vol : {0.0: 2.3994535371050753e-05}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ammonia
# total_up_cost: 0.8710053573690554
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.TWS_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7948470601869, (0.0, 'TOC'): 147.06781359729214, (0.0, 'nitrates'): 2.0055229786666688e-05}
#          :    flow_vol : {0.0: 2.399429542601211}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7982850430373, (0.0, 'TOC'): 147.06928429013504, (0.0, 'nitrates'): 2.0055430340970097e-05}
#          :    flow_vol : {0.0: 2.399405548305785}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 6.421212342891491e-20, (0.0, 'TOC'): 3.420258615998837e-21, (0.0, 'nitrates'): 5.224538216610746e-25}
#          :    flow_vol : {0.0: 2.3994295426097957e-05}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost TWS_24_hr
# total_up_cost: 13.27153601568671
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.muni
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.7982850430373, (0.0, 'TOC'): 147.06928429013504, (0.0, 'nitrates'): 2.0055430340970097e-05}
#          :    flow_vol : {0.0: 2.399405548305785}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 343.80172306026793, (0.0, 'TOC'): 147.07075499768501, (0.0, 'nitrates'): 2.0055630897279067e-05}
#          :    flow_vol : {0.0: 2.399381554250302}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 2.1338551906057768e-20, (0.0, 'TOC'): 1.2760966507031822e-21, (0.0, 'nitrates'): 7.141402886782455e-25}
#          :    flow_vol : {0.0: 2.3994055482921518e-05}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost muni
# total_up_cost: 7.920273094535757
# ----------------------------------------------------------------------

# %%
unit_process_names = [
    "swoi", 
    "coag_floc",
    "tri_media_filtration",
    "SAA",
    "SBA",
    "cf",
    "ro",
    "lime",
    "co2",
    "chlor",
    "ammonia",
    "TWS_24_hr",
    "muni"
]


cost_variables = [
    "total_up_cost",
    "fixed_cap_inv_unadjusted",
    "fixed_cap_inv",
    "total_fixed_op_cost",
    "total_cap_investment",
    "land_cost",
    "working_cap",
    "catalysts_chemicals",#
    #"electricity",##
    "cap_replacement_parts", #
    "salaries",
    "benefits",
    "maintenance",
    "lab",
    "insurance_taxes",
    "base_employee_salary_cost",
    
    "cat_and_chem_cost",##
    "labor_and_other_fixed",#
    "consumer_price_index",#
    
    "electricity_cost", ##
    "other_var_cost"   ## 
]

# %%
def get_results_table(model, unit_process_names):
    data = {} 

    for variable in cost_variables:
        cost_list = []
        for node in unit_process_names:
            # call m.fs.'node'.costing.'variable'() for each node and variable
            costing_attr = getattr(m.fs, node).costing
            cost_method = getattr(costing_attr, variable) #m.fs.swoi.costing.total_up_cost
            
            #Todo: add unit (e.g. million $ or m3/s etc.)
            
            if type(cost_method) == int:
                cost_method = np.float64(cost_method)
                
            if type(cost_method) == np.float64:
                cost_value = cost_method
            else:
                cost_value = cost_method()
            # append ^ to a list
            cost_list.append(cost_value)            
            
        # assign 'variable': List['node' values] in a data dictionary
        data[variable] = cost_list
    
    
    df = pd.DataFrame(data = data, index = unit_process_names, columns = cost_variables)
    
    
    
    #print(df)
    return df

# %%
get_results_table(m, unit_process_names).to_csv("excel_comparison.csv")

# %%
get_results_table(m, unit_process_names).head()
# Out:
#                       total_up_cost  fixed_cap_inv_unadjusted  fixed_cap_inv  \
# swoi                      23.366026                 20.308784      20.980305
# coag_floc                 14.211373                 11.765810      11.765810
# tri_media_filtration      42.354232                 11.748013      12.751178
# SAA                        0.716879                  0.351380       0.418187
# SBA                        1.217590                  0.351816       0.418706
#
#                       total_fixed_op_cost  total_cap_investment  land_cost  \
# swoi                             1.305235             22.060791   0.031470
# coag_floc                        0.732488             12.371749   0.017649
# tri_media_filtration            24.703293             13.407863   0.019127
# SAA                              0.027077              0.439723   0.000627
# SBA                              0.027110              0.440270   0.000628
#
#                       working_cap  catalysts_chemicals  cap_replacement_parts  \
# swoi                     1.049015             1.045314               1.033066
# coag_floc                0.588291             1.000000               1.000000
# tri_media_filtration     0.637559             1.094885               1.085390
# SAA                      0.020909             1.449793               1.190128
# SBA                      0.020935             1.449793               1.190128
#
#                        salaries   benefits  maintenance       lab  \
# swoi                   0.543417   0.489075     0.167842  0.062941
# coag_floc              0.305017   0.274515     0.094126  0.035297
# tri_media_filtration  12.914488  11.623039     0.102009  0.038254
# SAA                    0.011390   0.010251     0.003345  0.001255
# SBA                    0.011404   0.010263     0.003350  0.001256
#
#                       insurance_taxes  base_employee_salary_cost  \
# swoi                         0.041961                   0.020309
# coag_floc                    0.023532                   0.011766
# tri_media_filtration         0.025502                   0.011748
# SAA                          0.000836                   0.000351
# SBA                          0.000837                   0.000352
#
#                       cat_and_chem_cost  labor_and_other_fixed  \
# swoi                           0.000000               1.032158
# coag_floc                      1.008727               1.000000
# tri_media_filtration           0.000000               1.144289
# SAA                            0.250068               1.255215
# SBA                            0.750197               1.255215
#
#                       consumer_price_index  electricity_cost  other_var_cost
# swoi                              1.034582          1.984638       -1.984638
# coag_floc                         1.000000          0.098409        0.000000
# tri_media_filtration              1.104141          4.243076        0.000000
# SAA                               1.260734          0.000011        0.000000
# SBA                               1.260734          0.000013        0.000000

# %%
variables = cost_variables + ["inlet_flow", "outlet_flow", "waste_flow"]

# %%
def get_results_table(model, unit_process_names, scenario = None, case_study = None):
    # could make a dictionary if betteR?
    value_list = [] 
    up_list = []
    scenario_list = []
    unit_list = []
    variable_list = []
    case_study_list = []
    
    for node in unit_process_names:
        
        for variable in variables:
            
            if variable == "inlet_flow":
                value_list.append(getattr(m.fs, node).inlet.flow_vol.extract_values()[0])
                variable_list.append(variable)
                unit_list.append("m3/s")
            elif variable == "outlet_flow":
                value_list.append(getattr(m.fs, node).outlet.flow_vol.extract_values()[0])
                variable_list.append(variable)
                unit_list.append("m3/s")
            elif variable == "waste_flow":
                value_list.append(getattr(m.fs, node).waste.flow_vol.extract_values()[0])
                variable_list.append(variable)
                unit_list.append("m3/s")
            else:
                # call m.fs.'node'.costing.'variable'() for each node and variable
                costing_attr = getattr(m.fs, node).costing
                cost_method = getattr(costing_attr, variable) #m.fs.swoi.costing.total_up_cost            
            
                if type(cost_method) == int:
                    cost_method = np.float64(cost_method)

                if type(cost_method) == np.float64:
                    cost_value = cost_method
                else:
                    cost_value = cost_method()
                # append ^ to a list
                value_list.append(cost_value)            
                variable_list.append(variable)
                unit_list.append("$MM")        
        
            up_list.append(node)
            scenario_list.append(scenario)
            case_study_list.append(case_study)
    
    df = pd.DataFrame()
    df["Case_Study"] = case_study_list
    df["Scenario"] = scenario_list
    df["Unit_Process"] = up_list
    df["Variable"] = variable_list
    df["Unit"] = unit_list
    df["Value"] = value_list
    
    #print(df)
    return df

# %%
t1 = get_results_table(m, unit_process_names, scenario = "Baseline", case_study = "Carlsbad")

# %%
t1.head()
# Out:
#   Case_Study  Scenario Unit_Process                  Variable Unit      Value
# 0   Carlsbad  Baseline         swoi             total_up_cost  $MM  23.366026
# 1   Carlsbad  Baseline         swoi  fixed_cap_inv_unadjusted  $MM  20.308784
# 2   Carlsbad  Baseline         swoi             fixed_cap_inv  $MM  20.980305
# 3   Carlsbad  Baseline         swoi       total_fixed_op_cost  $MM   1.305235
# 4   Carlsbad  Baseline         swoi      total_cap_investment  $MM  22.060791

# %%
t1.to_csv("results_v2.csv")

# %%
m.fs.tri_media_filtration.inlet.flow_vol.extract_values()[0]
# Out:
# 5.064327456187778

# %%
m.fs.tri_media_filtration.costing.salaries()
# Out:
# 12.914488212339975

# %%
m.fs.chlor.costing.catalysts_chemicals
# Out:
# 1.0948846182937026

# %%
m.fs.chlor.costing.applied_cl2_dose * 3.78541178 * (0.34) * 1.0948846182937026 * 365 * 2.399478 * 22.824465227271
# Out:
# 267605.01864422136

# %%
t1[t1.Unit_Process == "swoi"]
# Out:
#    Case_Study  Scenario Unit_Process                   Variable  Unit  \
# 0    Carlsbad  Baseline         swoi              total_up_cost   $MM
# 1    Carlsbad  Baseline         swoi   fixed_cap_inv_unadjusted   $MM
# 2    Carlsbad  Baseline         swoi              fixed_cap_inv   $MM
# 3    Carlsbad  Baseline         swoi        total_fixed_op_cost   $MM
# 4    Carlsbad  Baseline         swoi       total_cap_investment   $MM
# 5    Carlsbad  Baseline         swoi                  land_cost   $MM
# 6    Carlsbad  Baseline         swoi                working_cap   $MM
# 7    Carlsbad  Baseline         swoi        catalysts_chemicals   $MM
# 8    Carlsbad  Baseline         swoi      cap_replacement_parts   $MM
# 9    Carlsbad  Baseline         swoi                   salaries   $MM
# 10   Carlsbad  Baseline         swoi                   benefits   $MM
# 11   Carlsbad  Baseline         swoi                maintenance   $MM
# 12   Carlsbad  Baseline         swoi                        lab   $MM
# 13   Carlsbad  Baseline         swoi            insurance_taxes   $MM
# 14   Carlsbad  Baseline         swoi  base_employee_salary_cost   $MM
# 15   Carlsbad  Baseline         swoi          cat_and_chem_cost   $MM
# 16   Carlsbad  Baseline         swoi      labor_and_other_fixed   $MM
# 17   Carlsbad  Baseline         swoi       consumer_price_index   $MM
# 18   Carlsbad  Baseline         swoi           electricity_cost   $MM
# 19   Carlsbad  Baseline         swoi             other_var_cost   $MM
# 20   Carlsbad  Baseline         swoi                 inlet_flow  m3/s
# 21   Carlsbad  Baseline         swoi                outlet_flow  m3/s
# 22   Carlsbad  Baseline         swoi                 waste_flow  m3/s
#
#         Value
# 0   23.366026
# 1   20.308784
# 2   20.980305
# 3    1.305235
# 4   22.060791
# 5    0.031470
# 6    1.049015
# 7    1.045314
# 8    1.033066
# 9    0.543417
# 10   0.489075
# 11   0.167842
# 12   0.062941
# 13   0.041961
# 14   0.020309
# 15   0.000000
# 16   1.032158
# 17   1.034582
# 18   1.984638
# 19  -1.984638
# 20   4.583300
# 21   4.583254
# 22   0.000046

# %%
results_table = get_results_table(m, unit_process_name)

# %%
results_table.total_up_cost.sum()
# Out:
# 462.8602092987865

# %%
results_table
# Out:
#                       total_up_cost  fixed_cap_inv_unadjusted  fixed_cap_inv  \
# swoi                      23.366026                 20.308784      20.980305
# coag_floc                 15.121692                 11.765810      11.765810
# tri_media_filtration      14.283696                 11.748013      12.751178
# SAA                        0.966936                  0.351380       0.418187
# SBA                        1.967774                  0.351816       0.418706
# cf                        13.380566                 11.044252      11.987322
# ro                       296.404263                223.115886     265.536470
# lime                      59.544991                 52.909213      52.909213
# co2                        8.515704                  7.646860       7.771228
# chlor                     10.362694                  8.699168       9.441991
# ammonia                    0.870994                  0.666818       0.793598
# TWS_24_hr                 13.271536                  9.709731      12.152581
# muni                       4.803337                  4.383360       4.383360
#
#                       total_fixed_op_cost  total_cap_investment  land_cost  \
# swoi                             1.305235             22.060791   0.031470
# coag_floc                        0.732488             12.371749   0.017649
# tri_media_filtration             0.875833             13.407863   0.019127
# SAA                              0.027077              0.439723   0.000627
# SBA                              0.027110              0.440270   0.000628
# cf                               0.775897             12.604669   0.017981
# ro                              17.192665            279.211598   0.398305
# ammonia                           1.260734          0.000012       -0.000012
# TWS_24_hr                         1.296380          0.000000       -0.000000
# muni                              1.000000          3.116936       -3.116936

# %%
#results_table = pd.read_csv('./cost_results.csv',index_col=0)
results_table.index.names=['Unit_Process']
results_table = results_table.reset_index()
df = pd.melt(results_table, id_vars=['Unit_Process'], value_vars=results_table.columns.to_list()[1:])

# %%
df["Case_Study"] = "Carlsbad"
df["Unit"] = "Million $"
df["Scenario"] = "A"

# %%
df
# Out:
#              Unit_Process        variable      value Case_Study       Unit
# 0                    swoi   total_up_cost  23.366026   Carlsbad  Million $
# 1               coag_floc   total_up_cost  15.121692   Carlsbad  Million $
# 2    tri_media_filtration   total_up_cost  14.283696   Carlsbad  Million $
# 3                     SAA   total_up_cost   0.966936   Carlsbad  Million $
# 4                     SBA   total_up_cost   1.967774   Carlsbad  Million $
# ..                    ...             ...        ...        ...        ...
# 255                   co2  other_var_cost  -0.101468   Carlsbad  Million $
# 256                 chlor  other_var_cost  -0.101467   Carlsbad  Million $
# 257               ammonia  other_var_cost  -0.000012   Carlsbad  Million $
# 258             TWS_24_hr  other_var_cost  -0.000000   Carlsbad  Million $
# 259                  muni  other_var_cost  -3.116936   Carlsbad  Million $
#
# [260 rows x 5 columns]

# %%
m.fs.tri_media_filtration.inlet.flow_vol.display()
# Out:
# flow_vol_in : Volumetric flowrate of water into unit
#     Size=1, Index=fs.time
#     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#     0.0 :  None : 5.064327456187778 :  None : False : False :  Reals

# %%
m.fs.tri_media_filtration.inlet.flow_vol.extract_values()[0]
# Out:
# 5.064327456187778

# %%
cost_range_list = []; #results will be inputted in this array
#up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.

#for value_change in pct_to_target1: # cycles through each value from MC range
for value_change in [0.4, 0.8]: #, 0.9]:

    # create and build model
    m = wt.watertap_setup(dynamic = False)
    m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

    m.fs.tri_media_filtration.water_recovery.fix(value_change)

    # set variable to MC value
    wt.run_water_tap(m)
    results_table = get_results_table(m, unit_process_name)
    cost_range_list.append(results_table.total_up_cost.sum())
# Out:
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# Ipopt 3.12.13:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      133
#
# Total number of variables............................:      283
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      283
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.11e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    2  0.0000000e+00 1.13e+04 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 1.25e+03 1.80e+04  -1.0 1.86e+03    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 9.61e+00 5.00e+07  -1.0 4.26e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 4.60e+02 1.01e+08  -1.0 5.64e+04    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 4.60e+02 2.25e+22  -1.0 7.93e+14    -  1.00e+00 3.05e-05h 16
#    7  0.0000000e+00 8.27e-02 4.80e+21  -1.0 7.48e+09    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 4.11e-02 2.40e+21  -1.0 1.34e+10    -  1.00e+00 5.00e-01h  2
#    9  0.0000000e+00 3.99e-02 2.25e+21  -1.0 2.67e+10    -  1.00e+00 6.25e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 3.87e-02 2.11e+21  -1.0 2.85e+10    -  1.00e+00 6.25e-02h  5
#   11  0.0000000e+00 3.75e-02 1.98e+21  -1.0 3.04e+10    -  1.00e+00 6.25e-02h  5
#   12  0.0000000e+00 3.65e-02 1.85e+21  -1.0 3.24e+10    -  1.00e+00 6.25e-02h  5
#   13  0.0000000e+00 3.55e-02 1.74e+21  -1.0 3.46e+10    -  1.00e+00 6.25e-02h  5
#   14  0.0000000e+00 3.46e-02 1.63e+21  -1.0 3.69e+10    -  1.00e+00 6.25e-02h  5
#   15  0.0000000e+00 3.37e-02 1.53e+21  -1.0 3.94e+10    -  1.00e+00 6.25e-02h  5
#   16  0.0000000e+00 3.29e-02 1.43e+21  -1.0 4.20e+10    -  1.00e+00 6.25e-02h  5
#   17  0.0000000e+00 3.21e-02 1.34e+21  -1.0 4.48e+10    -  1.00e+00 6.25e-02h  5
#   18  0.0000000e+00 3.30e-01 6.35e+16  -1.0 4.78e+10    -  1.00e+00 1.00e+00w  1
#   19  0.0000000e+00 2.44e-11 2.96e+27  -1.7 1.03e+16    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   2.9642947524911724e+27    2.9642947524911724e+27
# Constraint violation....:   2.4354085330986937e-11    2.4354085330986937e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.4354085330986937e-11    2.9642947524911724e+27
#
#
# Number of objective function evaluations             = 80
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 85
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 19
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.083
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9279999999999, (0.0, 'TOC'): 139.986, (0.0, 'nitrates'): -1.0947644252537633e-47}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.0321698551383952e+16, (0.0, 'TOC'): 2006996940546879.8, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 3.197124953390092e-17}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.swoi
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9279999999999, (0.0, 'TOC'): 139.986, (0.0, 'nitrates'): -1.0947644252537633e-47}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9351993519934, (0.0, 'TOC'): 139.98739987399873, (0.0, 'nitrates'): -1.8513955310659483e-41}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 7.507244108342335e-28, (0.0, 'TOC'): 2.904381380277132e-23, (0.0, 'nitrates'): 7.011107221298684e-31}
#          :    flow_vol : {0.0: 4.583299999971757e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost swoi
# total_up_cost: 23.366026837777117
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9351993519934, (0.0, 'TOC'): 139.98739987399873, (0.0, 'nitrates'): -1.8513955310659483e-41}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.942398775981, (0.0, 'TOC'): 76.99383986909798, (0.0, 'nitrates'): -1.8508350116802184e-41}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 4.001986127939457e-30, (0.0, 'TOC'): 6299432.994404859, (0.0, 'nitrates'): -1.4840983521116012e-35}
#          :    flow_vol : {0.0: 4.5832541669454934e-05}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost coag_floc
# total_up_cost: 15.12169237570296
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer1
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.942398775981, (0.0, 'TOC'): 76.99383986909798, (0.0, 'nitrates'): -1.8508350116802184e-41}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 6.075648257305228}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 309.56853406908283, (0.0, 'TOC'): 33.106685798503655, (0.0, 'nitrates'): 5.7000938186935336e-05}
#          :    flow_vol : {0.0: 10.65885659176356}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should skip: mixer1
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 309.56853406908283, (0.0, 'TOC'): 33.106685798503655, (0.0, 'nitrates'): 5.7000938186935336e-05}
#          :    flow_vol : {0.0: 10.65885659176356}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.921335172707, (0.0, 'TOC'): 82.76671449625914, (0.0, 'nitrates'): 0.0001425023454673383}
#          :    flow_vol : {0.0: 4.263542636705424}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.793662034335766e-43, (0.0, 'TOC'): 2.2420775429197073e-44, (0.0, 'nitrates'): -2.7369110631344083e-48}
#          :    flow_vol : {0.0: 6.3953139550581355}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost tri_media_filtration
# total_up_cost: 22.845818644506974
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.splitter1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.793662034335766e-43, (0.0, 'TOC'): 2.2420775429197073e-44, (0.0, 'nitrates'): -2.7369110631344083e-48}
#          :    flow_vol : {0.0: 6.3953139550581355}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 6.075648257305228}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 0.319865697752907}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: splitter1
# ----------------------------------------------------------------------
# fs.SAA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.921335172707, (0.0, 'TOC'): 82.76671449625914, (0.0, 'nitrates'): 0.0001425023454673383}
#          :    flow_vol : {0.0: 4.263542636705424}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9290744634517, (0.0, 'TOC'): 82.76754217168086, (0.0, 'nitrates'): 0.00014250377050504338}
#          :    flow_vol : {0.0: 4.2635000012790565}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 9.552147163855121e-40, (0.0, 'TOC'): 2.279026980827024e-39, (0.0, 'nitrates'): -2.0603291320967785e-41}
#          :    flow_vol : {0.0: 4.263542636717687e-05}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SAA
# total_up_cost: 0.9148246374453335
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.SBA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9290744634517, (0.0, 'TOC'): 82.76754217168086, (0.0, 'nitrates'): 0.00014250377050504338}
#          :    flow_vol : {0.0: 4.2635000012790565}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9368138315899, (0.0, 'TOC'): 82.7683698553794, (0.0, 'nitrates'): 0.00014250519555699892}
#          :    flow_vol : {0.0: 4.263457366279044}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 5.908771156610597e-40, (0.0, 'TOC'): -9.8319584412115e-40, (0.0, 'nitrates'): 9.929600918205654e-42}
#          :    flow_vol : {0.0: 4.2635000012225526e-05}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SBA
# total_up_cost: 1.8510400235028612
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.cf
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9368138315899, (0.0, 'TOC'): 82.7683698553794, (0.0, 'nitrates'): 0.00014250519555699892}
#          :    flow_vol : {0.0: 4.263457366279044}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9445532771226, (0.0, 'TOC'): 82.76919754735488, (0.0, 'nitrates'): 0.00014250662062320515}
#          :    flow_vol : {0.0: 4.263414731705382}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -3.2307440562455815e-39, (0.0, 'TOC'): 2.550228680418592e-39, (0.0, 'nitrates'): -2.7759722578274626e-41}
#          :    flow_vol : {0.0: 4.263457366260325e-05}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost cf
# total_up_cost: 12.839808598824911
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 773.9445532771226, (0.0, 'TOC'): 82.76919754735488, (0.0, 'nitrates'): 0.00014250662062320515}
#          :    flow_vol : {0.0: 4.263414731705382}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.51556999192985, (0.0, 'TOC'): 157.21523556480815, (0.0, 'nitrates'): 0.00027068296654687016}
#          :    flow_vol : {0.0: 2.2445624616919506}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1225.8128017743245, (0.0, 'TOC'): -7.174648137343064e-43, (0.0, 'nitrates'): 2.802596928649634e-45}
#          :    flow_vol : {0.0: 2.018852270013431}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ro
# total_up_cost: 281.9392200896194
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.51556999192985, (0.0, 'TOC'): 157.21523556480815, (0.0, 'nitrates'): 0.00027068296654687016}
#          :    flow_vol : {0.0: 2.2445624616919506}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.51924518438165, (0.0, 'TOC'): 157.21680773288548, (0.0, 'nitrates'): 0.0002706856734036042}
#          :    flow_vol : {0.0: 2.244540016067334}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -1.200946415089512e-39, (0.0, 'TOC'): -2.485387797877354e-39, (0.0, 'nitrates'): -4.4696166142720446e-42}
#          :    flow_vol : {0.0: 2.2445624616729273e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost lime
# total_up_cost: 56.61173447954997
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.co2
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.51924518438165, (0.0, 'TOC'): 157.21680773288548, (0.0, 'nitrates'): 0.0002706856734036042}
#          :    flow_vol : {0.0: 2.244540016067334}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5229204135858, (0.0, 'TOC'): 157.21837991668465, (0.0, 'nitrates'): 0.00027068838028740703}
#          :    flow_vol : {0.0: 2.244517570667173}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -5.9789481837039835e-40, (0.0, 'TOC'): -1.0292032753018624e-39, (0.0, 'nitrates'): -1.7537250281025086e-42}
#          :    flow_vol : {0.0: 2.2445400160719938e-05}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost co2
# total_up_cost: 8.116302674911518
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.chlor
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5229204135858, (0.0, 'TOC'): 157.21837991668465, (0.0, 'nitrates'): 0.00027068838028740703}
#          :    flow_vol : {0.0: 2.244517570667173}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.52659567954254, (0.0, 'TOC'): 157.2199521162058, (0.0, 'nitrates'): 0.000270691087198279}
#          :    flow_vol : {0.0: 2.2444951254914667}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.474805191874773e-40, (0.0, 'TOC'): -3.736646433029984e-40, (0.0, 'nitrates'): -6.0706876909171685e-43}
#          :    flow_vol : {0.0: 2.244517570648696e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost chlor
# total_up_cost: 10.133116903586902
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.52659567954254, (0.0, 'TOC'): 157.2199521162058, (0.0, 'nitrates'): 0.000270691087198279}
#          :    flow_vol : {0.0: 2.2444951254914667}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5302709822524, (0.0, 'TOC'): 157.2215243314491, (0.0, 'nitrates'): 0.00027069379413622034}
#          :    flow_vol : {0.0: 2.2444726805402118}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -1.237806169895112e-39, (0.0, 'TOC'): -1.6803025937657454e-39, (0.0, 'nitrates'): -2.608517091340647e-42}
#          :    flow_vol : {0.0: 2.2444951254918518e-05}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ammonia
# total_up_cost: 0.8456401256277591
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.TWS_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5302709822524, (0.0, 'TOC'): 157.2215243314491, (0.0, 'nitrates'): 0.00027069379413622034}
#          :    flow_vol : {0.0: 2.2444726805402118}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5339463217155, (0.0, 'TOC'): 157.22309656241472, (0.0, 'nitrates'): 0.0002706965011012314}
#          :    flow_vol : {0.0: 2.2444502358134066}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -1.0024239011292295e-38, (0.0, 'TOC'): -1.2466668603447307e-38, (0.0, 'nitrates'): -1.8539704169941452e-41}
#          :    flow_vol : {0.0: 2.2444726805126433e-05}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost TWS_24_hr
# total_up_cost: 12.725112466286006
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.muni
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5339463217155, (0.0, 'TOC'): 157.22309656241472, (0.0, 'nitrates'): 0.0002706965011012314}
#          :    flow_vol : {0.0: 2.2444502358134066}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 367.5376216979325, (0.0, 'TOC'): 157.2246688091028, (0.0, 'nitrates'): 0.0002706992080933123}
#          :    flow_vol : {0.0: 2.2444277913110486}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -6.962099186274275e-40, (0.0, 'TOC'): -8.05264570315042e-40, (0.0, 'nitrates'): -1.1502032957486139e-42}
#          :    flow_vol : {0.0: 2.2444502357998882e-05}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost muni
# total_up_cost: 4.527685601077918
# ----------------------------------------------------------------------
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# Ipopt 3.12.13:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      133
#
# Total number of variables............................:      283
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      283
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 4.53e+02 1.80e+04  -1.0 1.60e+03    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 5.44e-01 4.97e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.86e+02 1.86e+07  -1.0 3.87e+04    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 5.99e-01 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.82e+02 8.02e+07  -1.0 8.03e+04    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 5.56e-02 1.28e+06  -1.0 1.83e+00   4.9 1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 2.75e+02 2.91e+08  -1.0 1.52e+05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 2.01e-02 1.14e+06  -1.0 2.46e+00   4.4 1.00e+00 1.00e+00h  1
#   11  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   12  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   13  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   14  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   15  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   16  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   17  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   18  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   19  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  0.0000000e+00 2.01e-02 1.14e+06  -1.7 2.93e+05    -  1.00e+00 6.10e-05h 15
#   21  0.0000000e+00 2.61e+02 1.09e+09  -1.7 2.93e+05    -  1.00e+00 1.00e+00w  1
#   22  0.0000000e+00 1.30e-02 1.05e+06  -1.7 3.41e+00   3.9 1.00e+00 1.00e+00h  1
#   23  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.44e+05    -  1.00e+00 1.22e-04h 14
#   24  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   25  0.0000000e+00 1.30e-02 1.05e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   26  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   27  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   28  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   29  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5.44e+05    -  1.00e+00 6.10e-05h 15
#   31  0.0000000e+00 1.30e-02 1.04e+06  -1.7 5
-01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   9.8329942437228003e-05    9.8329942437228003e-05
# Constraint violation....:   1.9670504833246838e-04    1.9670504833246838e-04
# Complementarity.........:   9.0909090909090910e-10    9.0909090909090910e-10
# Overall NLP error.......:   1.9670504833246838e-04    1.9670504833246838e-04
#
#
# Number of objective function evaluations             = 691
# Number of objective gradient evaluations             = 52
# Number of equality constraint evaluations            = 691
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 70
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 68
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.360
# Total CPU secs in NLP function evaluations           =      0.011
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#         message from solver=Ipopt 3.12.13\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142733767, (0.0, 'TOC'): 139.9860027753788, (0.0, 'nitrates'): -1.0042434530935294e-21}
#          :    flow_vol : {0.0: 4.58329990913096}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1676.8518595617677, (0.0, 'TOC'): 326.0545282481177, (0.0, 'nitrates'): 2.3388427184019243e-17}
#          :    flow_vol : {0.0: 0.00019679591737235602}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.swoi
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142733767, (0.0, 'TOC'): 139.9860027753788, (0.0, 'nitrates'): -1.0042521067190075e-21}
#          :    flow_vol : {0.0: 4.58329990913096}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136255129, (0.0, 'TOC'): 139.98740264940528, (0.0, 'nitrates'): 2.735429575775987e-21}
#          :    flow_vol : {0.0: 4.583254076131869}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -8.114463850223561e-13, (0.0, 'TOC'): 1.3031902290958716e-11, (0.0, 'nitrates'): -3.739654749770712e-16}
#          :    flow_vol : {0.0: 4.583299909109287e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost swoi
# total_up_cost: 23.366026411703185
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136255129, (0.0, 'TOC'): 139.98740264940528, (0.0, 'nitrates'): 2.7354213134411203e-21}
#          :    flow_vol : {0.0: 4.583254076131869}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9495526053078, (0.0, 'TOC'): 76.99460493140097, (0.0, 'nitrates'): 2.1495802072349374e-21}
#          :    flow_vol : {0.0: 4.583162793086613}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.1270210773755101e-13, (0.0, 'TOC'): 2088381.7016630599, (0.0, 'nitrates'): 1.942315047018292e-17}
#          :    flow_vol : {0.0: 0.00013825012208260675}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost coag_floc
# total_up_cost: 15.121692104044573
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer1
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9495526053078, (0.0, 'TOC'): 76.99460493140097, (0.0, 'nitrates'): 2.1495722892218596e-21}
#          :    flow_vol : {0.0: 4.583162793086613}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 1.0751863341808103}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 583.1464329441484, (0.0, 'TOC'): 62.36428827060529, (0.0, 'nitrates'): 1.900176729992708e-05}
#          :    flow_vol : {0.0: 5.658349127267424}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should skip: mixer1
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 583.1464329441484, (0.0, 'TOC'): 62.36428827060529, (0.0, 'nitrates'): 1.900176729992708e-05}
#          :    flow_vol : {0.0: 5.658349127267424}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9330411801856, (0.0, 'TOC'): 77.95536033825661, (0.0, 'nitrates'): 2.3752209124908846e-05}
#          :    flow_vol : {0.0: 4.526679301813939}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -6.803822396945771e-26, (0.0, 'TOC'): 2.9371908992881163e-26, (0.0, 'nitrates'): -3.574704493345771e-29}
#          :    flow_vol : {0.0: 1.1316698254534847}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost tri_media_filtration
# total_up_cost: 15.304393095030534
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.splitter1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.2104694726885396e-24, (0.0, 'TOC'): -4.383955178629578e-24, (0.0, 'nitrates'): -1.9790131965923756e-27}
#          :    flow_vol : {0.0: 1.1316698254534847}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 1.0751863341808103}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# outlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    flow_vol : {0.0: 0.05668349127267428}
#          :    pressure : {0.0: 199999.99949999998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: splitter1
# ----------------------------------------------------------------------
# fs.SAA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9330411801856, (0.0, 'TOC'): 77.95536033825661, (0.0, 'nitrates'): 2.3752209124908846e-05}
#          :    flow_vol : {0.0: 4.526679301813939}
#          :    pressure : {0.0: 199999.99939999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9403305834913, (0.0, 'TOC'): 77.95613989965561, (0.0, 'nitrates'): 2.375244664937534e-05}
#          :    flow_vol : {0.0: 4.526634035020921}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 2.520546057263993e-16, (0.0, 'TOC'): -1.9236065462668712e-16, (0.0, 'nitrates'): 2.235909819896396e-19}
#          :    flow_vol : {0.0: 4.526679301797287e-05}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SAA
# total_up_cost: 0.9614295637395786
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.SBA
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9403305834913, (0.0, 'TOC'): 77.95613989965561, (0.0, 'nitrates'): 2.375244664937534e-05}
#          :    flow_vol : {0.0: 4.526634035020921}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9476200596919, (0.0, 'TOC'): 77.95691946885029, (0.0, 'nitrates'): 2.37526841762171e-05}
#          :    flow_vol : {0.0: 4.526588768680571}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.462570492006315e-18, (0.0, 'TOC'): 1.5889584086484896e-17, (0.0, 'nitrates'): 3.6637613182322515e-21}
#          :    flow_vol : {0.0: 4.526634034984767e-05}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost SBA
# total_up_cost: 1.9554138937757113
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.cf
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.9476200596919, (0.0, 'TOC'): 77.95691946885029, (0.0, 'nitrates'): 2.37526841762171e-05}
#          :    flow_vol : {0.0: 4.526588768680571}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.954909608788, (0.0, 'TOC'): 77.95769904584074, (0.0, 'nitrates'): 2.3752921705434153e-05}
#          :    flow_vol : {0.0: 4.526543502792885}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): -2.1339398264163254e-17, (0.0, 'TOC'): 1.0377960916341613e-17, (0.0, 'nitrates'): -1.5730188875852463e-20}
#          :    flow_vol : {0.0: 4.526588768616335e-05}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost cf
# total_up_cost: 13.323807340499908
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 728.954909608788, (0.0, 'TOC'): 77.95769904584074, (0.0, 'nitrates'): 2.3752921705434153e-05}
#          :    flow_vol : {0.0: 4.526543502792885}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1517727192568, (0.0, 'TOC'): 148.07607639992096, (0.0, 'nitrates'): 4.5117281451662644e-05}
#          :    flow_vol : {0.0: 2.3830920205880184}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1154.5559127344154, (0.0, 'TOC'): 1.4095397202615567e-24, (0.0, 'nitrates'): 7.200444651240438e-28}
#          :    flow_vol : {0.0: 2.1434514822048665}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ro
# total_up_cost: 294.8803259329162
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1517727192568, (0.0, 'TOC'): 148.07607639992096, (0.0, 'nitrates'): 4.5117281451662644e-05}
#          :    flow_vol : {0.0: 2.3830920205880184}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1552342715995, (0.0, 'TOC'): 148.07755717549273, (0.0, 'nitrates'): 4.5117732628988924e-05}
#          :    flow_vol : {0.0: 2.3830681896678128}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 6.094635241846212e-19, (0.0, 'TOC'): -8.462632540849906e-19, (0.0, 'nitrates'): -3.829303909587748e-22}
#          :    flow_vol : {0.0: 2.383092020563637e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost lime
# total_up_cost: 59.235981313024865
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.co2
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1552342715995, (0.0, 'TOC'): 148.07755717549273, (0.0, 'nitrates'): 4.5117732628988924e-05}
#          :    flow_vol : {0.0: 2.3830681896678128}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1586958585581, (0.0, 'TOC'): 148.07903796587237, (0.0, 'nitrates'): 4.511818381082704e-05}
#          :    flow_vol : {0.0: 2.383044358985916}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 2.7965501660381518e-18, (0.0, 'TOC'): -3.741900264323855e-18, (0.0, 'nitrates'): -2.5319906601749174e-21}
#          :    flow_vol : {0.0: 2.3830681896708225e-05}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost co2
# total_up_cost: 8.473675190865075
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.chlor
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1586958585581, (0.0, 'TOC'): 148.07903796587237, (0.0, 'nitrates'): 4.511818381082704e-05}
#          :    flow_vol : {0.0: 2.383044358985916}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.16215748013286, (0.0, 'TOC'): 148.08051877106007, (0.0, 'nitrates'): 4.5118634997177e-05}
#          :    flow_vol : {0.0: 2.3830205285423265}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.2143271745165354e-19, (0.0, 'TOC'): -1.4476119666463906e-19, (0.0, 'nitrates'): -1.858734953722643e-24}
#          :    flow_vol : {0.0: 2.3830443589556435e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost chlor
# total_up_cost: 10.338793604161093
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.16215748013286, (0.0, 'TOC'): 148.08051877106007, (0.0, 'nitrates'): 4.5118634997177e-05}
#          :    flow_vol : {0.0: 2.3830205285423265}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1656191363242, (0.0, 'TOC'): 148.081999591056, (0.0, 'nitrates'): 4.511908618803888e-05}
#          :    flow_vol : {0.0: 2.382996698337041}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 8.607079735725047e-20, (0.0, 'TOC'): -1.0356014590485956e-19, (0.0, 'nitrates'): -1.6948503396646008e-24}
#          :    flow_vol : {0.0: 2.3830205285513273e-05}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost ammonia
# total_up_cost: 0.8683467161836179
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.TWS_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.1656191363242, (0.0, 'TOC'): 148.081999591056, (0.0, 'nitrates'): 4.511908618803888e-05}
#          :    flow_vol : {0.0: 2.382996698337041}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.16908082713246, (0.0, 'TOC'): 148.08348042586024, (0.0, 'nitrates'): 4.511953738341272e-05}
#          :    flow_vol : {0.0: 2.3829728683700577}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 5.13410232881484e-20, (0.0, 'TOC'): -6.222108769379527e-20, (0.0, 'nitrates'): -9.396481962829245e-25}
#          :    flow_vol : {0.0: 2.3829966983246464e-05}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost TWS_24_hr
# total_up_cost: 13.214184669664542
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.muni
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.16908082713246, (0.0, 'TOC'): 148.08348042586024, (0.0, 'nitrates'): 4.511953738341272e-05}
#          :    flow_vol : {0.0: 2.3829728683700577}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 346.172542552558, (0.0, 'TOC'): 148.08496127547298, (0.0, 'nitrates'): 4.511998858329855e-05}
#          :    flow_vol : {0.0: 2.382949038641374}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.7071126182376547e-20, (0.0, 'TOC'): -2.0748440481158506e-20, (0.0, 'nitrates'): -2.1065025411616427e-24}
#          :    flow_vol : {0.0: 2.382972868364419e-05}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
# Show some costing values
# ---------------------
# should have a cost muni
# total_up_cost: 4.774190570660693
# ----------------------------------------------------------------------

# %%
cost_range_list
# Out:
# [451.8380234584197, 461.8182604062696]

# %%
import time
from multiprocessing import Pool
import multiprocessing

# %%
mu = 0.6
sigma = .1
num_reps = 50

input_list = np.random.normal(mu,sigma, size = num_reps) #, sigma, num_reps).round(4)

count, bins, ignored = plt.hist(input_list, 25, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
          linewidth=2, color='r')
plt.show()

### INPUT TO MODEL LIST: ### CAN BE AUTOMATED FOR USER TO LABEL THE VARIABLE. TOOD ###
no_of_proc = 4
list_final = []
for i in range(no_of_proc):
    part2 = len(input_list) / no_of_proc
    i2 = ((i+1)*part2)
    list1 = input_list[int(i*part2):int(i2)]
    list_final.append(list1)

# %%
def monte_run(list_final):
    print('goes in')

    up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.
    cost_range_list = []; #results will be inputted in this array

    #for value_change in pct_to_target1: # cycles through each value from MC range
    for value_change in list_final:

        # create and build model
        m = wt.watertap_setup(dynamic = False)
        m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

        getattr(m.fs, up_name).water_recovery.fix(value_change)

        # set variable to MC value
        result = wt.run_water_tap(m)
        results_table = get_results_table(m, unit_process_names)
        cost_range_list.append(results_table.total_up_cost.sum())


    return cost_range_list

# %%
startTime = time.time()

pool=Pool()
dfs = pool.map(monte_run, list_final) #SomeClass().preprocess_data()

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# goes ingoes ingoes ingoes in
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/NAWI-WaterTAP3/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# Ipopt 3.12.13:
# Ipopt 3.12.13:
# Ipopt 3.12.13:
# Ipopt 3.12.13:
#
#
#
#
# ******************************************************************************
# ******************************************************************************
# ******************************************************************************
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
# This program contains Ipopt, a library for large-scale nonlinear optimization.
# This program contains Ipopt, a library for large-scale nonlinear optimization.
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#          For more information visit http://projects.coin-or.org/Ipopt
#          For more information visit http://projects.coin-or.org/Ipopt
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
# ******************************************************************************
# ******************************************************************************
# ******************************************************************************
#
#
#
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# This is Ipopt version 3.12.13, running with linear solver mumps.
# This is Ipopt version 3.12.13, running with linear solver mumps.
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
#
#
#
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in equality constraint Jacobian...:      755
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      133
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      133
# Number of nonzeros in Lagrangian Hessian.............:      133
#
# Number of nonzeros in Lagrangian Hessian.............:      133
#
#
# Total number of variables............................:      283
# Total number of variables............................:      283
#
# Total number of variables............................:      283
#                      variables with only lower bounds:        0
# Total number of variables............................:      283
#                      variables with only lower bounds:        0
#                      variables with only lower bounds:        0
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        1
#                 variables with lower and upper bounds:        1
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
#                      variables with only upper bounds:        0
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      283
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      283
# Total number of equality constraints.................:      283
# Total number of inequality constraints...............:        0
# Total number of inequality constraints...............:        0
# Total number of equality constraints.................:      283
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#         inequality constraints with only upper bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
#
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    1  0.0000000e+00 1.18e+04 7.76e-01  -1.0 1.00e+05    -  5.78e-01 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 4.78e+02 1.80e+04  -1.0 1.70e+03    -  1.00e+00 1.00e+00h  1
#    3  0.0000000e+00 4.50e+02 1.80e+04  -1.0 1.66e+03    -  1.00e+00 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 4.51e+02 1.80e+04  -1.0 1.63e+03    -  1.00e+00 1.00e+00h  1
#    3  0.0000000e+00 4.59e+02 1.80e+04  -1.0 1.69e+03    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 9.24e-01 4.97e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 6.15e-01 4.97e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 5.74e-01 4.97e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.85e+02 2.05e+07  -1.0 4.06e+04    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 8.61e-01 4.97e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.86e+02 1.95e+07  -1.0 3.96e+04    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 1.38e+00 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.86e+02 1.90e+07  -1.0 3.91e+04    -  1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.85e+02 2.03e+07  -1.0 4.04e+04    -  1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.81e+02 9.15e+07  -1.0 8.58e+04    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 8.07e-01 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 1.24e+00 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 6.83e-01 1.27e+06  -1.0 1.42e+00   5.4 1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 2.60e-01 1.29e+06  -1.0 1.83e+00   4.9 1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.81e+02 8.54e+07  -1.0 8.28e+04    -  1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.81e+02 9.03e+07  -1.0 8.52e+04    -  1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 2.82e+02 8.24e+07  -1.0 8.13e+04    -  1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 2.74e+02 3.23e+08  -1.0 1.61e+05    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00
x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
#   50r 0.0000000e+00 3.83e-04 4.21e-01  -6.9 9.23e+01    -  1.00e+00 1.00e+00h  1
#   51r 0.0000000e+00 3.83e-04 4.42e-05  -6.9 1.78e-01    -  1.00e+00 1.00e+00h  1
#   52r 0.0000000e+00 3.83e-04 1.36e-12  -6.9 9.71e-06    -  1.00e+00 1.00e+00h  1
#   53r 0.0000000e+00 3.94e-04 3.62e-04  -9.0 2.93e-03    -  9.78e-01 1.00e+00f  1
#   54r 0.0000000e+00 5.90e-02 1.79e+02  -9.0 4.10e+03    -  1.00e+00 1.00e+00f  1
#   55r 0.0000000e+00 1.40e-02 4.25e+01  -9.0 4.30e+02    -  1.00e+00 1.00e+00h  1
#   56r 0.0000000e+00 1.97e-04 3.01e-01  -9.0 5.76e+01    -  1.00e+00 1.00e+00h  1
#   57r 0.0000000e+00 1.97e-04 2.25e-05  -9.0 2.66e-01    -  1.00e+00 1.00e+00h  1
#
# degrees_of_freedom:Number of Iterations....: 57
#
#  0                                   (scaled)                 (unscaled)
#
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# ----------------------------------------------------------------------Dual infeasibility......:   9.8365572719114305e-05    9.8365572719114305e-05
#
# Constraint violation....:   1.9673910139594852e-04    1.9673910139594852e-04
# fs.source1Complementarity.........:   9.0909090909090910e-10    9.0909090909090910e-10
# Overall NLP error.......:   1.9673910139594852e-04    1.9673910139594852e-04
#
#
# inlet :
# Number of objective function evaluations             = 499
# Size=1
# Number of objective gradient evaluations             = 42
# Number of equality constraint evaluations            = 499
#     Key  : Name        : Value
# Number of inequality constraint evaluations          = 0
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
# Number of equality constraint Jacobian evaluations   = 60
#          :    flow_vol : {0.0: 4.5833}
# Number of inequality constraint Jacobian evaluations = 0
#          :    pressure : {0.0: 200000.0}
# Number of Lagrangian Hessian evaluations             = 58
#          : temperature : {0.0: 300}
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.392
# outlet : Total CPU secs in NLP function evaluations           =      0.011
#
# Size=1
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142734099, (0.0, 'TOC'): 139.98600277538526, (0.0, 'nitrates'): -1.2945187495982244e-21}
#          :    flow_vol : {0.0: 4.583299909130749}
#          :    pressure : {0.0: 199999.9999}
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
#          : temperature : {0.0: 300.0}
# waste : Size=
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1676.3330439804186, (0.0, 'TOC'): 325.9536474406332, (0.0, 'nitrates'): 3.013949333873754e-17}
#          :    flow_vol : {0.0: 0.00019685682459401183}
# degrees_of_freedom:WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#         message from solver=Ipopt 3.12.13\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
#           :    pressure : {0.0: 199999.9999}
# 0  42r 0.0000000e+00 6.22e-03 9.99e+02  -2.2 0.00e+00    -  0.00e+00 4.77e-07R 22
#          : temperature : {0.0: 300.0}
#   43r 0.0000000e+00 9.04e-04 9.83e+02  -2.2 6.44e+02    -  5.50e-01 1.05e-03f  1
#   44r 0.0000000e+00 4.71e-04 6.06e+02  -2.2 9.10e+00    -  1.00e+00 3.83e-01f  1
#   45r 0.0000000e+00 4.14e-04 9.09e+00  -2.2 5.54e+00    -  1.00e+00 1.00e+00f  1
#
#   46r 0.0000000e+00 4.05e-04 1.52e+01  -2.2 1.26e-01    -  1.00e+00 1.00e+00h  1
# Show some costing values  47r 0.0000000e+00 4.05e-04 4.13e-02  -2.2 4.18e-03    -  1.00e+00 1.00e+00h  1
#   48r 0.0000000e+00 4.05e-04 1.80e+00  -3.3 1.90e-01    -  1.00e+00 1.00e+00f  1
#   49r 0.0000000e+00 6.97e-04 3.42e+00  -3.3 1.88e+01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r 0.0000000e+00 3.89e-04 2.08e-03  -3.3 1.58e-01    -  1.00e+00 1.00e+00h  1
#   51r 0.0000000e+00 3.91e-04 3.03e-03  -5.0 6.52e-02    -  1.00e+00 1.00e+00f  1
#   52r 0.0000000e+00 1.28e-02 3.87e+01  -5.0 8.40e+01    -  1.00e+00 1.00e+00f  1
# ----------------------------------------------------------------------  53r 0.0000000e+00 3.64e-04 3.86e-01  -5.0 1.14e+01    -  1.00e+00 1.00e+00h  1
#
#   54r 0.0000000e+00 3.63e-04 2.29e-05  -5.0 3.83e-02    -  1.00e+00 1.00e+00h  1
#   55r 0.0000000e+00 4.08e-04 2.64e-02  -7.4 1.14e-02    -  8.93e-01 1.00e+00f  1
#   56r 0.0000000e+00 5.82e-02 1.76e+02  -7.4 6.65e+02    -  1.00e+00 1.00e+00f  1
#   57r 0.0000000e+00 8.55e-03 2.59e+01  -7.4 2.33e+02    -  1.00e+00 1.00e+00h  1
#
#   58r 0.0000000e+00 3.29e-04 1.52e-01  -7.4 1.74e+01    -  1.00e+00 1.00e+00h  1
# ---------------------  59r 0.0000000e+00 3.29e-04 5.59e-06  -7.4 6.18e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 59
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# fs.source1Dual infeasibility......:   2.8098374143872254e-04    2.8098374143872254e-04
#
# Constraint violation....:   3.2905536183402972e-04    3.2905536183402972e-04
# Complementarity.........:   3.5837555057586144e-08    3.5837555057586144e-08
# Overall NLP error.......:   3.2905536183402972e-04    3.2905536183402972e-04
#
#
#
# Number of objective function evaluations             = 540
# Number of objective gradient evaluations             = 44
# Number of equality constraint evaluations            = 540
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 62
# Number of inequality constraint Jacobian evaluations = 0
# should skip:Number of Lagrangian Hessian evaluations             = 60
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.417
# inlet : Total CPU secs in NLP function evaluations           =      0.012
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# Size=1 source1
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
# ----------------------------------------------------------------------         :    flow_vol : {0.0: 4.5833}
#
#          :    pressure : {0.0: 200000.0}
# fs.swoi
#          : temperature : {0.0: 300}
# outlet : inlet : Size=1Size=1
#
#     Key  : Name        : Value
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9285577919907, (0.0, 'TOC'): 139.98610845955375, (0.0, 'nitrates'): -2.133819775279572e-20}
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142734099, (0.0, 'TOC'): 139.98600277538526, (0.0, 'nitrates'): -1.2945313559411868e-21}
#          :    flow_vol : {0.0: 4.5832964489142665}
#          :    flow_vol : {0.0: 4.583299909130749}
#          :    pressure : {0.0: 199999.9999}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
#          : temperature : {0.0: 300.0}
# waste : outlet : Size=1Size=1
#
#     Key  : Name        : Value
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 992.0016535906329, (0.0, 'TOC'): 192.88921042025413, (0.0, 'nitrates'): 2.939902753256842e-16}
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136255461, (0.0, 'TOC'): 139.98740264941173, (0.0, 'nitrates'): 3.545895097326334e-21}
#          :    flow_vol : {0.0: 0.00033265831645087044}
#          :    flow_vol : {0.0: 4.583254076131658}
#          :    pressure : {0.0: 199999.9999}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
#          : temperature : {0.0: 300.0}
# waste : Show some costing values
# Size=1---------------------
#
#     Key  : Name        : Value
# should skip:    None :   conc_mass : {(0.0, 'TDS'): -9.050772815632798e-13, (0.0, 'TOC'): 1.3536737732933104e-11, (0.0, 'nitrates'): -4.840391583886234e-16}
#           :    flow_vol : {0.0: 4.583299909109287e-05}
# source1         :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
#
# ----------------------------------------------------------------------Show some costing values
#
# fs.swoi---------------------
#
# inlet : should have a costSize=1 swoi
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9285577919907, (0.0, 'TOC'): 139.98610845955375, (0.0, 'nitrates'): -2.1342572794408423e-20}
# total_up_cost:         :    flow_vol : {0.0: 4.583296448914265}
#           :    pressure : {0.0: 199999.9999}
# 23.366026411702197         : temperature : {0.0: 300.0}
#
# outlet : ----------------------------------------------------------------------Size=1
#
# ----------------------------------------------------------------------    Key  : Name        : Value
#
# fs.coag_floc    None :   conc_mass : {(0.0, 'TDS'): 719.9357571495619, (0.0, 'TOC'): 139.98750833463703, (0.0, 'nitrates'): 1.4087401312182861e-18}
#
#          :    flow_vol : {0.0: 4.583250615949777}
# inlet :          :    pressure : {0.0: 199999.9998}
# Size=1         : temperature : {0.0: 300.0}
#
# waste : Size=1    Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352136255461, (0.0, 'TOC'): 139.98740264941173, (0.0, 'nitrates'): 3.54588303572531e-21}
#
#     Key  : Name        : Value
#          :    flow_vol : {0.0: 4.583254076131658}
#     None :   conc_mass : {(0.0, 'TDS'): -2.492769351767169e-10, (0.0, 'TOC'): 1.868052188439707e-09, (0.0, 'nitrates'): -1.4300688211470833e-13}
#          :    pressure : {0.0: 199999.9998}
#          :    flow_vol : {0.0: 4.583296448785148e-05}
#          : temperature : {0.0: 300.0}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1Show some costing values
#
# ---------------------    Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9494771531124, (0.0, 'TOC'): 76.99459686220784, (0.0, 'nitrates'): 2.7937714711965158e-21}
#
# should have a cost         :    flow_vol : {0.0: 4.583163273411561}
#          :    pressure : {0.0: 199999.9997}
#  swoi         : temperature : {0.0: 300.0}
#
# waste : total_up_cost:Size=1 23.366010187165685
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.1619371477818e-13, (0.0, 'TOC'): 2104209.940157554, (0.0, 'nitrates'): 2.5124736066037886e-17}
# ----------------------------------------------------------------------
#          :    flow_vol : {0.0: 0.00013721018026765047}
# ----------------------------------------------------------------------         :    pressure : {0.0: 199999.9997}
#
#          : temperature : {0.0: 300.0}
# fs.coag_flocShow some costing values
#
# ---------------------inlet : Size=1
# should have a cost
#  coag_floc    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 719.9357571495619, (0.0, 'TOC'): 139.98750833463703, (0.0, 'nitrates'): 1.4087359514890533e-18}
#          :    flow_vol : {0.0: 4.583250615949776}
#          :    pressure : {0.0: 199999.9998}
# total_up_cost:         : temperature : {0.0: 300.0}
#  14.211373211566912outlet :
# Size=1----------------------------------------------------------------------
#
#     Key  : Name        : Value
# ----------------------------------------------------------------------    None :   conc_mass : {(0.0, 'TDS'): 719.9498144916284, (0.0, 'TOC'): 76.99463293868803, (0.0, 'nitrates'): 9.702240830319196e-19}
#
#          :    flow_vol : {0.0: 4.583161125932016}
# fs.mixer1         :    pressure : {0.0: 199999.9997}
#
#          : temperature : {0.0: 300.0}
# inlet1 : waste : Size=1
# Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9494771531124, (0.0, 'TOC'): 76.99459686220784, (0.0, 'nitrates'): 2.7937598627694333e-21}
#     Key  : Name        : Value
#          :    flow_vol : {0.0: 4.583163273411561}
#          :    pressure : {0.0: 199999.9997}
#     None :   conc_mass : {(0.0, 'TDS'): 4.966500940414094e-11, (0.0, 'TOC'): 2171326.0938512697, (0.0, 'nitrates'): 1.511552294667706e-14}
#          :    flow_vol : {0.0: 0.0001329689842661543}
#          : temperature : {0.0: 300.0}
#          :    pressure : {0.0: 199999.9997}
# inlet2 :          : temperature : {0.0: 300.0}
# Size=1Show some costing values
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
# ---------------------
#          :    flow_vol : {0.0: 1.4402214353180405}
#          :    pressure : {0.0: 199999.99949999998}
# should have a cost          : temperature : {0.0: 300.0}
# outlet : coag_flocSize=1
#
# total_up_cost:     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 547.805977200828, (0.0, 'TOC'): 58.58482724849392, (0.0, 'nitrates'): 2.3910500573386076e-05}
# 14.21136355430038         :    flow_vol : {0.0: 6.023384708729601}
#
# ----------------------------------------------------------------------         :    pressure : {0.0: 199999.99949999998}
#
#          : temperature : {0.0: 299.9999}
# ----------------------------------------------------------------------Show some costing values
#
# fs.mixer1---------------------
#
# should skip: inlet1 : Size=1mixer1
#
# ----------------------------------------------------------------------    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 719.9498144916284, (0.0, 'TOC'): 76.99463293868803, (0.0, 'nitrates'): 9.702200820135513e-19}
# fs.tri_media_filtration
#          :    flow_vol : {0.0: 4.583161125932016}
#          :    pressure : {0.0: 199999.9997}
# inlet : Size=1         : temperature : {0.0: 300.0}
#
# inlet2 :     Key  : Name        : Value
# Size=1
#     None :   conc_mass : {(0.0, 'TDS'): 547.805977200828, (0.0, 'TOC'): 58.58482724849392, (0.0, 'nitrates'): 2.3910500573386076e-05}
#          :    flow_vol : {0.0: 6.023384708729601}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 0.0001, (0.0, 'TOC'): 0.0001, (0.0, 'nitrates'): 0.0001}
#          :    pressure : {0.0: 199999.99949999998}
# WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#         message from solver=Ipopt 3.12.13\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#          :    flow_vol : {0.0: 4.583296450211352}
# WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#     None :   conc_mass : {(0.0, 'TDS'): 719.9285575882489, (0.0, 'TOC'): 139.9861084199373, (0.0, 'nitrates'): -2.161250544714922e-20}
#         message from solver=Ipopt 3.12.13\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
# degrees_of_freedom:    None :   conc_mass : {(0.0, 'TDS'): 992.1602221770767, (0.0, 'TOC'): 192.92004320095154, (0.0, 'nitrates'): 2.978175083314941e-16}
#          :    flow_vol : {0.0: 0.00033260515048248225}
#  0         :    pressure : {0.0: 199999.9999}
#
#          : temperature : {0.0: 300.0}
# Show some costing values----------------------------------------------------------------------
#
# fs.source1---------------------
#          :    flow_vol : {0.0: 2.328708488136839}
# inlet :          : temperature : {0.0: 299.9999}
# Size=1outlet :          :    pressure : {0.0: 199999.9995}
#
#     Key  : Name        : Value
#          : temperature : {0.0: 300.0}
# Size=1    None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
# outlet :          :    flow_vol : {0.0: 4.5833}
#
#          :    pressure : {0.0: 200000.0}
# Size=1         : temperature : {0.0: 300}
#     Key  : Name        : Value
#
# outlet :     None :   conc_mass : {(0.0, 'TDS'): 732.0399345044178, (0.0, 'TOC'): 78.28763264154341, (0.0, 'nitrates'): 3.195189903393945e-05}
# Size=1
#     Key  : Name        : Value
#          :    flow_vol : {0.0: 4.507467408394822}
#     Key  : Name        : Value
#          :    pressure : {0.0: 199999.99939999997}
#     None :   conc_mass : {(0.0, 'TDS'): 477.38837962952005, (0.0, 'TOC'): 51.05406513204131, (0.0, 'nitrates'): 3.36914412186955e-05}
#     None :   conc_mass : {(0.0, 'TDS'): 719.9280142734511, (0.0, 'TOC'): 139.9860027753933, (0.0, 'nitrates'): -1.5853088148037455e-21}
#          :    flow_vol : {0.0: 6.911869614068855}
#          : temperature : {0.0: 299.9999}
#          :    flow_vol : {0.0: 4.583299909130486}
#          :    pressure : {0.0: 199999.9999}
#          :    pressure : {0.0: 199999.9995}
# waste :          : temperature : {0.0: 300.0}
#          : temperature : {0.0: 299.9999}
# waste : Size=1Show some costing valuesSize=1
#
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1676.561747547712, (0.0, 'TOC'): 325.99811757871805, (0.0, 'nitrates'): 3.691481522916975e-17}
#     Key  : Name        : Value
# ---------------------         :    flow_vol : {0.0: 0.00019682997091081375}
# ...
# total_up_cost:
# ----------------------------------------------------------------------
# 10.429263664093401
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime
# ----------------------------------------------------------------------inlet :
# Size=1fs.ammonia
#
# ---------------------inlet :     Key  : Name        : Value
# Size=1    None :   conc_mass : {(0.0, 'TDS'): 349.1245422299763, (0.0, 'TOC'): 149.347789161864, (0.0, 'nitrates'): 7.650032557768987e-05}
#
#          :    flow_vol : {0.0: 2.362800221719613}
#     Key  : Name        : Value
#
# 10.392128424725009should have a cost          :    pressure : {0.0: 199999.99899999995}
#
# ----------------------------------------------------------------------ro
#
# ----------------------------------------------------------------------total_up_cost:
#      None :   conc_mass : {(0.0, 'TDS'): 347.63758640901705, (0.0, 'TOC'): 148.71168838955026, (0.0, 'nitrates'): 6.069439951449143e-05}
# 324.9552210673688fs.ammonia
#
# inlet : ----------------------------------------------------------------------         : temperature : {0.0: 299.9999}
#
# Size=1----------------------------------------------------------------------
#     Key  : Name        : Value
#
# fs.lime    None :   conc_mass : {(0.0, 'TDS'): 351.28212046025163, (0.0, 'TOC'): 150.27077342450048, (0.0, 'nitrates'): 9.916622538529371e-05}
#
#          :    flow_vol : {0.0: 2.3482879166662647}
#          :    pressure : {0.0: 199999.9987}
# inlet : Size=1         : temperature : {0.0: 299.9999}
#
# outlet :     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.88651615479154, (0.0, 'TOC'): 150.1015390607374, (0.0, 'nitrates'): 9.509806397979479e-05}
# Size=1outlet :
#          :    flow_vol : {0.0: 2.350935469200098}
#          :    flow_vol : {0.0: 2.3729066385674886}
#     Key  : Name        : Value
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9999}
#     None :   conc_mass : {(0.0, 'TDS'): 351.2856333165848, (0.0, 'TOC'): 150.27227614726195, (0.0, 'nitrates'): 9.916721705746428e-05}
#          :    flow_vol : {0.0: 2.348264433787098}
# outlet : Size=1         :    pressure : {0.0: 199999.9986}
#
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
#     Key  : Name        : Value
# waste : Size=1    None :   conc_mass : {(0.0, 'TDS'): 350.8900250550421, (0.0, 'TOC'): 150.10304009113827, (0.0, 'nitrates'): 9.509901496994448e-05}
# Size=1         :    flow_vol : {0.0: 2.3509119598454062}
#
#          :    pressure : {0.0: 199999.99889999998}
#     Key  : Name        : Value
#          : temperature : {0.0: 299.9999}
#          : temperature : {0.0: 299.9999}
# waste :     None :   conc_mass : {(0.0, 'TDS'): 9.083536195341078e-16, (0.0, 'TOC'): 3.3941789327087427e-16, (0.0, 'nitrates'): 7.439612516521157e-21}
# Size=1         :    flow_vol : {0.0: 2.3482879166536372e-05}
#
#          :    pressure : {0.0: 199999.9986}
#     Key  : Name        : Value
#          : temperature : {0.0: 299.9999}
#     None :   conc_mass : {(0.0, 'TDS'): 1.7748650142651766e-14, (0.0, 'TOC'): -2.143339535554625e-14, (0.0, 'nitrates'): -3.0475857895333653e-17}
# Show some costing values         :    flow_vol : {0.0: 2.3509354691863934e-05}
#          :    pressure : {0.0: 199999.99889999998}
#
#
#          : temperature : {0.0: 299.9999}
# ---------------------Show some costing values
#
# should have a costoutlet : ---------------------
#  ammoniashould have a cost
# Size=1 limetotal_up_cost:
#     Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 349.1280335103114, (0.0, 'TOC'): 149.34928265469054, (0.0, 'nitrates'): 7.650109058859575e-05}
#     Key  : Name        : Value
#          :    flow_vol : {0.0: 2.362776593717396}
#     None :   conc_mass : {(0.0, 'TDS'): 347.64106281964524, (0.0, 'TOC'): 148.7131755213055, (0.0, 'nitrates'): 6.069500646455607e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          :    flow_vol : {0.0: 2.372882909501103}
#          : temperature : {0.0: 299.9999}
#          :    pressure : {0.0: 199999.99859999996}
# waste :          : temperature : {0.0: 299.9999}
# Size=1waste :
# Size=1    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): -6.081468586452926e-18, (0.0, 'TOC'): 9.789494474003022e-18, (0.0, 'nitrates'): 1.062074239990434e-20}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 8.725986970584117e-20, (0.0, 'TOC'): -1.0674304445200033e-19, (0.0, 'nitrates'): 5.08552040195325e-25}
#          :    flow_vol : {0.0: 2.3628002217002106e-05}
#          :    flow_vol : {0.0: 2.3729066385591583e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9999}
#          : temperature : {0.0: 299.9999}
# Show some costing valuesShow some costing values
#
# ------------------------------------------
#
# should have a costshould have a cost  limeammonia
#
# total_up_cost:total_up_cost:  0.866724179652062858.182467206406635
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# fs.co2fs.TWS_24_hr
#
# inlet : inlet : Size=1Size=1
#
#     Key  : Name        : Value
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 349.1280335103114, (0.0, 'TOC'): 149.34928265469054, (0.0, 'nitrates'): 7.650109058859575e-05}
#          :    flow_vol : {0.0: 2.362776593717396}
#     None :   conc_mass : {(0.0, 'TDS'): 347.64106281964524, (0.0, 'TOC'): 148.7131755213055, (0.0, 'nitrates'): 6.069500646455607e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          :    flow_vol : {0.0: 2.372882909501103}
#          : temperature : {0.0: 299.9999}
#          :    pressure : {0.0: 199999.99859999996}
# outlet :          : temperature : {0.0: 299.9999}
# Size=1outlet :
# Size=1
#     Key  : Name        : Value
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 349.13152482555967, (0.0, 'TOC'): 149.35077616245215, (0.0, 'nitrates'): 7.650185560715182e-05}
#     None :   conc_mass : {(0.0, 'TDS'): 347.6445392650379, (0.0, 'TOC'): 148.71466266793215, (0.0, 'nitrates'): 6.0695613420690275e-05}
#          :    flow_vol : {0.0: 2.362752965951459}
#          :    flow_vol : {0.0: 2.372859180672008}
#          :    pressure : {0.0: 199999.99879999997}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# waste :          : temperature : {0.0: 299.9999}
# Size=1waste : total_up_cost: 0.862731421866672
# 57.96201286904505----------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# fs.TWS_24_hr
# fs.co2
#
# inlet :     Key  : Name        : Value
# Size=1inlet :
# Size=1    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 351.2856333165848, (0.0, 'TOC'): 150.27227614726195, (0.0, 'nitrates'): 9.916721705746428e-05}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.8900250550421, (0.0, 'TOC'): 150.10304009113827, (0.0, 'nitrates'): 9.509901496994448e-05}
#          :    flow_vol : {0.0: 2.348264433787098}
#     None :   conc_mass : {(0.0, 'TDS'): 6.6564941147947514e-18, (0.0, 'TOC'): -8.15563481407979e-18, (0.0, 'nitrates'): -1.0627024939973782e-20}
#          :    flow_vol : {0.0: 2.3509119598454062}
#          :    pressure : {0.0: 199999.9986}
#          :    pressure : {0.0: 199999.99889999998}
# Size=1         : temperature : {0.0: 299.9999}
#          : temperature : {0.0: 299.9999}
# outlet :          :    flow_vol : {0.0: 2.3627765937117563e-05}
# Size=1outlet : Size=1
#
#
#     Key  : Name        : Value
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 351.2891462080469, (0.0, 'TOC'): 150.2737788850508, (0.0, 'nitrates'): 9.916820873955168e-05}
#          :    pressure : {0.0: 199999.99879999997}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.8935339903819, (0.0, 'TOC'): 150.1045411365496, (0.0, 'nitrates'): 9.509996596960417e-05}
#          :    flow_vol : {0.0: 2.34824095114276}
#          :    pressure : {0.0: 199999.9985}
#          :    flow_vol : {0.0: 2.350888450725808}
#          : temperature : {0.0: 299.9999}
#          : temperature : {0.0: 299.9999}
#          :    pressure : {0.0: 199999.99879999997}
#     None :   conc_mass : {(0.0, 'TDS'): 5.202853986250809e-20, (0.0, 'TOC'): -6.4150142311751e-20, (0.0, 'nitrates'): -6.621174729728917e-25}
# waste :          : temperature : {0.0: 299.9999}
# waste : Size=1Size=1
#          :    flow_vol : {0.0: 2.3728829094959995e-05}
# Show some costing values
#     Key  : Name        : Value
#          :    pressure : {0.0: 199999.99849999996}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 5.083891465794468e-16, (0.0, 'TOC'): 1.9170657515106897e-16, (0.0, 'nitrates'): 7.945720359085792e-22}
#          :    flow_vol : {0.0: 2.34826443379354e-05}
#     None :   conc_mass : {(0.0, 'TDS'): 1.0691091555020335e-14, (0.0, 'TOC'): -8.591069538277629e-15, (0.0, 'nitrates'): -1.739118797770638e-17}
#
#          :    flow_vol : {0.0: 2.3509119598141684e-05}
#          :    pressure : {0.0: 199999.9985}
#          : temperature : {0.0: 299.9999}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
# Show some costing values         : temperature : {0.0: 299.9999}
#
# Show some costing valuesShow some costing values---------------------
# ------------------------------------------
#
# should have a cost
#  should have a cost
#  TWS_24_hrco2
#
# total_up_cost:total_up_cost:should have a cost  8.49062875113122613.092512282708343---------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# fs.chlorfs.muni
# should have a costinlet : co2
# Size=1inlet :
# Size=1
#
#     Key  : Name        : Value
#      Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.8935339903819, (0.0, 'TOC'): 150.1045411365496, (0.0, 'nitrates'): 9.509996596960417e-05}
#     None :   conc_mass : {(0.0, 'TDS'): 351.2891462080469, (0.0, 'TOC'): 150.2737788850508, (0.0, 'nitrates'): 9.916820873955168e-05}
#          :    flow_vol : {0.0: 2.350888450725808}
# TWS_24_hr         :    flow_vol : {0.0: 2.34824095114276}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9999}
#          :    pressure : {0.0: 199999.9985}
# outlet : total_up_cost:         : temperature : {0.0: 299.9999}
# outlet : Size=1Size=1
#     Key  : Name        : Value
#
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.89704296081146, (0.0, 'TOC'): 150.10604219697157, (0.0, 'nitrates'): 9.510091697877395e-05}
#           :    flow_vol : {0.0: 2.350864941841301}
#     None :   conc_mass : {(0.0, 'TDS'): 351.2926591346382, (0.0, 'TOC'): 150.27528163786715, (0.0, 'nitrates'): 9.9169200431556e-05}
#          :    flow_vol : {0.0: 2.348217468733249}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
# 8.521589695732047         :    pressure : {0.0: 199999.99839999998}
#          : temperature : {0.0: 299.9999}
# waste : waste : Size=1
# Size=1total_up_cost:
#     Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 1.3321535424020037e-15, (0.0, 'TOC'): 1.4193081707933755e-15, (0.0, 'nitrates'): -7.65005515167396e-19}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.6362445496081013e-16, (0.0, 'TOC'): 6.128333965523612e-17, (0.0, 'nitrates'): 1.2247518486060244e-22}
#           :    flow_vol : {0.0: 2.3508884507083986e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          :    flow_vol : {0.0: 2.3482409511110785e-05}
# ----------------------------------------------------------------------13.178818660450487
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
#          : temperature : {0.0: 299.9999}
# ----------------------------------------------------------------------fs.chlor
#          :    pressure : {0.0: 199999.99839999998}
#
# fs.muniinlet :          : temperature : {0.0: 299.9999}
#
# Size=1inlet :
#     Key  : Name        : Value
# Size=1    None :   conc_mass : {(0.0, 'TDS'): 349.13152482555967, (0.0, 'TOC'): 149.35077616245215, (0.0, 'nitrates'): 7.650185560715182e-05}
#
#          :    flow_vol : {0.0: 2.362752965951459}
#     Key  : Name        : Value
#          :    pressure : {0.0: 199999.99879999997}
#     None :   conc_mass : {(0.0, 'TDS'): 347.6445392650379, (0.0, 'TOC'): 148.71466266793215, (0.0, 'nitrates'): 6.0695613420690275e-05}
#          :    flow_vol : {0.0: 2.372859180672008}
#          : temperature : {0.0: 299.9999}
# outlet :          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9999}
# Size=1Show some costing values
# outlet : Size=1    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 349.13501617572143, (0.0, 'TOC'): 149.352269685149, (0.0, 'nitrates'): 7.650262063335815e-05}
#          :    flow_vol : {0.0: 2.3627293384217993}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 347.6480157451953, (0.0, 'TOC'): 148.71614982943044, (0.0, 'nitrates'): 6.06962203828941e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9999}
#          :    flow_vol : {0.0: 2.3728354520802015}
#          :    pressure : {0.0: 199999.99839999995}
# waste :
# Show some costing valuesSize=1         : temperature : {0.0: 299.9999}
# waste :
# Size=1    Key  : Name        : Value
#
#     None :   conc_mass : {(0.0, 'TDS'): 1.2667700656920024e-19, (0.0, 'TOC'): -1.1953663600848366e-19, (0.0, 'nitrates'): -3.590268824391576e-23}
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.7289104968430174e-20, (0.0, 'TOC'): -2.1391366786694173e-20, (0.0, 'nitrates'): 3.1834673622175373e-25}
#          :    flow_vol : {0.0: 2.3627529659453462e-05}
#          :    flow_vol : {0.0: 2.3728591806548852e-05}
#          :    pressure : {0.0: 199999.99869999997}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9999}
#
#          : temperature : {0.0: 299.9999}
# ---------------------Show some costing values
# Show some costing values
# ------------------------------------------should have a cost
#
#
# chlor---------------------should have a costshould have a cost
#
#   chlorshould have a costtotal_up_cost:muni
#
# munitotal_up_cost:10.396026645616512total_up_cost:
#
#  10.4139404541929487.762992724646517
# ----------------------------------------------------------------------
# total_up_cost:----------------------------------------------------------------------
#
# 7.838693594400685----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# fs.ammonia
# --------------------------------------------------------------------------------------------------------------------------------------------
# inlet :
# Size=1fs.ammonia
#
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 350.89704296081146, (0.0, 'TOC'): 150.10604219697157, (0.0, 'nitrates'): 9.510091697877395e-05}
# inlet :          :    flow_vol : {0.0: 2.350864941841301}
# Size=1         :    pressure : {0.0: 199999.99869999997}
#
#     Key  : Name        : Value
#          : temperature : {0.0: 299.9999}
#     None :   conc_mass : {(0.0, 'TDS'): 349.13501617572143, (0.0, 'TOC'): 149.352269685149, (0.0, 'nitrates'): 7.650262063335815e-05}
# outlet :          :    flow_vol : {0.0: 2.3627293384217993}
# Size=1

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)
