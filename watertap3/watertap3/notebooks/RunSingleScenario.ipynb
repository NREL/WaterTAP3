# %%
# %cd ..
from watertap3.utils import watertap_setup, get_case_study, run_water_tap, run_water_tap_ro, show_train2
# Out:
# /Users/ksitterl/Documents/Python/watertap3/NAWI-WaterTAP3/watertap3/watertap3

# %%
case_study = 'ashkelon'
scenario = 'baseline'
reference = 'nawi'
source_water = 'seawater'
ro_bounds = 'seawater'
desired_recovery = 1

# %%
m = watertap_setup(dynamic=False, case_study=case_study, reference=reference, 
                      scenario=scenario, source_scenario="baseline")

m = get_case_study(m=m)

m = run_water_tap_ro(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds,
                 source_water_category='other', scenario_name=scenario,
                 source_scenario='baseline')
# Out:
# ASHKELON
#
# ------- Adding Unit Processes -------
# SW ONSHORE INTAKE
# SULFURIC ACID ADDITION
# FERRIC CHLORIDE ADDITION
# CHLORINATION
# STATIC MIXER
# TRI MEDIA FILTRATION
# CARTRIDGE FILTRATION
# RO FIRST PASS
# RO FIRST STAGE
# LIME SOFTENING
# CHLORINATION B
# CAUSTIC SODA ADDITION
# TREATED STORAGE
# BACKWASH SOLIDS HANDLING
# MUNICIPAL DRINKING
# SURFACE DISCHARGE
# LANDFILL
# -------------------------------------
#
#
# Connecting unit processes...
#
# Unfixing feed pressure and area for RO FIRST PASS...
#
#
# Unfixing feed pressure and area for RO FIRST STAGE...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 8
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# 	Feed pressure for RO FIRST PASS: 60.06 bar
# 	Membrane area for RO FIRST PASS: 161446.91 m2
# 	Pure Water Flux for RO FIRST PASS: 44.28 LMH
# 	A constant for RO FIRST PASS: 9.0
# 	B constant for RO FIRST PASS: 0.9
#
#
# 	Feed pressure for RO FIRST STAGE: 90.0 bar
# 	Membrane area for RO FIRST STAGE: 288967.22 m2
# 	Pure Water Flux for RO FIRST STAGE: 29.77 LMH
# 	A constant for RO FIRST STAGE: 9.0
# 	B constant for RO FIRST STAGE: 0.9
#
#
#
# Seawater bounds for RO:
# 	Flux [LMH] (min, max) = (10, 45)
# 	Pressure [bar] (min, max) = (5, 85)
# 	Min. Area [m2] = 500
# 	Water Perm. [units] (min, max) = (2, 7)
# 	Salt Perm. [units] (min, max) = (0.2, 0.7)
#
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 8
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# 	Feed pressure for RO FIRST PASS: 59.9 bar
# 	Membrane area for RO FIRST PASS: 144350.96 m2
# 	Pure Water Flux for RO FIRST PASS: 39.23 LMH
# 	A constant for RO FIRST PASS: 7.0
# 	B constant for RO FIRST PASS: 0.7
#
#
# 	Feed pressure for RO FIRST STAGE: 85.0 bar
# 	Membrane area for RO FIRST STAGE: 377783.76 m2
# 	Pure Water Flux for RO FIRST STAGE: 25.06 LMH
# 	A constant for RO FIRST STAGE: 7.0
# 	B constant for RO FIRST STAGE: 0.7
#
#
# Rebuilding model, running with unfixed, then fixed RO based on model results...
#
# ASHKELON
#
# ------- Adding Unit Processes -------
# SW ONSHORE INTAKE
# SULFURIC ACID ADDITION
# FERRIC CHLORIDE ADDITION
# CHLORINATION
# STATIC MIXER
# TRI MEDIA FILTRATION
# CARTRIDGE FILTRATION
# RO FIRST PASS
# RO FIRST STAGE
# LIME SOFTENING
# CHLORINATION B
# CAUSTIC SODA ADDITION
# TREATED STORAGE
# BACKWASH SOLIDS HANDLING
# MUNICIPAL DRINKING
# SURFACE DISCHARGE
# LANDFILL
# -------------------------------------
#
#
# Connecting unit processes...
# Unfixing feed pressure and area for RO FIRST PASS ...
#
# Unfixing feed pressure and area for RO FIRST STAGE ...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 8
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# SW ONSHORE INTAKE:
#
# 	total cap investment: 35.31534
# 	cat and chem cost: 0.0
# 	electricity cost: 2.46439
# 	total fixed op cost: 0.46849
#
# SULFURIC ACID ADDITION:
#
# 	total cap investment: 0.54647
# 	cat and chem cost: 0.4272
# 	electricity cost: 1e-05
# 	total fixed op cost: 0.00728
#
# FERRIC CHLORIDE ADDITION:
#
# 	total cap investment: 4.60981
# 	cat and chem cost: 6.26501
# 	electricity cost: 8e-05
# 	total fixed op cost: 0.06138
#
# CHLORINATION:
#
# 	total cap investment: 14.38081
# 	cat and chem cost: 0.86822
# 	electricity cost: 0.00014
# 	total fixed op cost: 0.19149
#
# STATIC MIXER:
#
# 	total cap investment: 0.11622
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00154
#
# TRI MEDIA FILTRATION:
#
# 	total cap investment: 17.24233
# 	cat and chem cost: 0.0
# 	electricity cost: 4.76594
# 	total fixed op cost: 0.2296
#
# CARTRIDGE FILTRATION:
#
# 	total cap investment: 16.20963
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.21584
#
# RO FIRST PASS:
#
# 	total cap investment: 231.92539
# 	cat and chem cost: 2.20566
# 	electricity cost: 44.23985
# 	total fixed op cost: 3.08836
#
# RO FIRST STAGE:
#
# 	total cap investment: 227.3447
# 	cat and chem cost: 2.1621
# 	electricity cost: -5.17823
# 	total fixed op cost: 3.02736
#
# LIME SOFTENING:
#
# 	total cap investment: 84.10405
# 	cat and chem cost: 1.37985
# 	electricity cost: 7e-05
# 	total fixed op cost: 1.11579
#
# CHLORINATION B:
#
# 	total cap investment: 11.86098
# 	cat and chem cost: 0.47101
# 	electricity cost: 7e-05
# 	total fixed op cost: 0.15794
#
# CAUSTIC SODA ADDITION:
#
# 	total cap investment: 3.154
# 	cat and chem cost: 0.63714
# 	electricity cost: 5e-05
# 	total fixed op cost: 0.042
#
# TREATED STORAGE:
#
# 	total cap investment: 5.91308
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.07772
#
# BACKWASH SOLIDS HANDLING:
#
# 	total cap investment: 20.64961
# 	cat and chem cost: 0.0
# 	electricity cost: 0.24632
# 	total fixed op cost: 0.27497
#
# MUNICIPAL DRINKING:
#
# 	total cap investment: 7.51304
# 	cat and chem cost: 0.0
# 	electricity cost: 4.00837
# 	total fixed op cost: 0.09967
#
# SURFACE DISCHARGE:
#
# 	total cap investment: 35.71571
# 	cat and chem cost: 0.0
# 	electricity cost: 0.88543
# 	total fixed op cost: 0.47383
#
# LANDFILL:
#
# 	total cap investment: 1.33243
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.01768
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
#
#
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 717.934
# Annual Fixed Operating Cost ($MM/yr) 9.551
# Annual Catalysts and Chemicals Cost ($MM/yr) 14.416
# Annual Electricity Costs ($MM/yr) 51.433
# Annual Other Variable Costs ($MM/yr) 3.916
# Annual Operating Costs ($MM/yr) 79.316
# Treated water (m3/s) ---> 4.219
# Total water recovery (%) ---> 54.212
# Electricity intensity (kwh/m3) --->  3.945
# LCOW ($/m3) --->  1.029
# Electricity portion of LCOW (%) ---> 37.563
# ----------------------------------------------------------------------
#
# 	Feed pressure for RO FIRST PASS: 59.9 bar
# 	Membrane area for RO FIRST PASS: 144350.96 m2
# 	Pure Water Flux for RO FIRST PASS: 39.23 LMH
# 	A constant for RO FIRST PASS: 7.0
# 	B constant for RO FIRST PASS: 0.7
#
#
# 	Feed pressure for RO FIRST STAGE: 85.0 bar
# 	Membrane area for RO FIRST STAGE: 377783.76 m2
# 	Pure Water Flux for RO FIRST STAGE: 25.06 LMH
# 	A constant for RO FIRST STAGE: 7.0
# 	B constant for RO FIRST STAGE: 0.7
