# %%
import watertap as wt
import pandas as pd
from pyomo.environ import value, Block
from idaes.core import FlowsheetBlock
import numpy as np
from case_study_trains import *
import case_study_trains
import pyomo.environ as env
from pyomo.environ import Constraint

m = wt.watertap_setup(dynamic=False)


wt.case_study_trains.train = {"case_study": "santa_barbara",
                             "reference": "nawi",
                             "scenario": "baseline"}


wt.case_study_trains.source_water = {"case_study": "santa_barbara", 
                             "reference": "nawi",
                             "scenario": "baseline",
                             "water_type": "seawater"}

m = wt.case_study_trains.get_case_study(m=m)
# Out:
# santa_barbara
#
# ------- Adding Unit Processes -------
# sw_onshore_intake
# ferric_chloride_addition
# chlorination
# static_mixer
# holding_tank
# media_filtration
# anti_scalant_addition
# cartridge_filtration
# reverse_osmosis
# holding_tank_b
# uv_aop
# co2_addition
# lime_addition
# treated_storage
# backwash_solids_handling
# landfill
# municipal_drinking
# -------------------------------------
#
# adding source
#
# Connecting unit processes...

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
### # RUN MODEL with optimal ro --> estimating area and pressure for optimal LCOW
# so that the model solves and gets you results. Then runs again with set pressure.
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).feed.pressure.unfix()
        getattr(m.fs, key).membrane_area.unfix()
        print("Unfixing feed presure and area for", key, '...\n')

wt.run_water_tap(m=m, objective=True, skip_small=True)

wt.run_water_tap(m=m, objective=True, print_model_results="summary", skip_small=True)
wt.print_ro_results(m)
# Out:
# Unfixing feed presure and area for reverse_osmosis ...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 4
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 4
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# SW ONSHORE INTAKE:
#
# 	total cap investment: 2.00857
# 	cat and chem cost: 0.0
# 	electricity cost: 0.13389
# 	total fixed op cost: 0.02665
#
# FERRIC CHLORIDE ADDITION:
#
# 	total cap investment: 1.6475
# 	cat and chem cost: 0.24895
# 	electricity cost: 0.0
# 	total fixed op cost: 0.02194
#
# CHLORINATION:
#
# 	total cap investment: 5.20644
# 	cat and chem cost: 0.0345
# 	electricity cost: 1e-05
# 	total fixed op cost: 0.06933
#
# STATIC MIXER:
#
# 	total cap investment: 0.11622
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00154
#
# HOLDING TANK:
#
# 	total cap investment: 1.48059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.01946
#
# MEDIA FILTRATION:
#
# 	total cap investment: 2.68667
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03578
#
# ANTI SCALANT ADDITION:
#
# 	total cap investment: 0.06842
# 	cat and chem cost: 0.24671
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00091
#
# CARTRIDGE FILTRATION:
#
# 	total cap investment: 2.60237
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03465
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 11.56639
# 	cat and chem cost: 0.11
# 	electricity cost: 1.66399
# 	total fixed op cost: 0.15402
#
# HOLDING TANK B:
#
# 	total cap investment: 0.55158
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00725
#
# UV AOP:
#
# 	total cap investment: 5.00334
# 	cat and chem cost: 0.04153
# 	electricity cost: 0.06644
# 	total fixed op cost: 0.06662
#
# CO2 ADDITION:
#
# 	total cap investment: 1.21212
# 	cat and chem cost: 0.0
# 	electricity cost: 0.00664
# 	total fixed op cost: 0.01608
#
# LIME ADDITION:
#
# 	total cap investment: 0.72014
# 	cat and chem cost: 0.00248
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00959
#
# TREATED STORAGE:
#
# 	total cap investment: 0.55142
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00725
#
# BACKWASH SOLIDS HANDLING:
#
# 	total cap investment: 0.00205
# 	cat and chem cost: 0.0
# 	electricity cost: 1e-05
# 	total fixed op cost: 3e-05
#
# LANDFILL:
#
# 	total cap investment: 8e-05
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# MUNICIPAL DRINKING:
#
# 	total cap investment: 0.4351
# 	cat and chem cost: 0.0
# 	electricity cost: 0.20402
# 	total fixed op cost: 0.00577
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 35.859
# Annual Fixed Operating Cost ($MM/yr) 0.477
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.684
# Annual Electricity Costs ($MM/yr) 2.075
# Annual Other Variable Costs ($MM/yr) 0.168
# Annual Operating Costs ($MM/yr) 3.404
# Treated water (m3/s) ---> 0.157
# Total water recovery (%) ---> 50.789
# Electricity intensity (kwh/m3) --->  3.127
# LCOW ($/m3) --->  1.268
# Electricity portion of LCOW (%) ---> 33.035
# ----------------------------------------------------------------------
# 	Feed pressure for reverse_osmosis: 63.98 bar
# 	Membrane area for reverse_osmosis: 33863.39 m2
# 	Feed Flux for reverse_osmosis: 31.619964340355807 lmh
# 	Reject Flux for reverse_osmosis: 1.6199999999999999 lmh
# 	A constant for reverse_osmosis: 2.5
# 	B constant for reverse_osmosis: 0.32682000761023855

# %%
# ONLY FOR DEBUGGING
# Find bounds for RO pessure:
# m.fs.objective_function.deactivate()

# for key in m.fs.pfd_dict.keys():
#     if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        
#         stash_value = value(getattr(m.fs, key).feed.pressure[0])
#         getattr(m.fs, key).feed.pressure.unfix()
#         m.fs.objective_function1 = env.Objective(expr=getattr(m.fs, key).feed.pressure[0], sense=env.minimize)
#         wt.run_water_tap(m = m, objective=False, skip_small = True)
#         print("LCOW -->", m.fs.costing.LCOW())
#         print(key, "Minimum -->", getattr(m.fs, key).feed.pressure[0]())

#         m.fs.objective_function1 = env.Objective(expr=getattr(m.fs, key).feed.pressure[0], sense=env.maximize)
#         wt.run_water_tap(m = m, objective=False, skip_small = True)
#         print("LCOW -->", m.fs.costing.LCOW())
#         print(key, "Maximum -->", getattr(m.fs, key).feed.pressure[0]())
        
#         getattr(m.fs, key).feed.pressure.unfix()
        
# m.fs.objective_function1.deactivate()

# %%
# add more reasonable flux constraints --> THIS CAN AFFECT WATER RECOVERY! MAY NEED TO ADJUST TO NOT OVER CONSTRAIN.
feed_flux_max = 40 #lmh
reject_flux_min = 2.75 #lmh
b = [0.2*1.15, 0.9*0.85]
a = [2.5*1.15, 9*0.85]
min_mem_cost = 25
max_pressure = 84

q=1
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).feed.water_flux[0] * 3600 <= feed_flux_max)
               )
        q = q + 1
        
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).mem_cost[0] >= min_mem_cost)
               )
        q = q + 1
        
        setattr(m, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).retenate.water_flux[0] * 3600 >= reject_flux_min)
               )
        q = q + 1
        
        setattr(m, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).feed.pressure[0] <= max_pressure)
               )
        q = q + 1        
        
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).a[0] <= a[1])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).a[0] >= a[0])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).b[0] <= b[1])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).b[0] >= b[0])
               )
        q = q + 1
        
wt.run_water_tap(m=m, objective=True, print_model_results="summary", skip_small=True)

wt.print_ro_results(m)
# Out:
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 4
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# SW ONSHORE INTAKE:
#
# 	total cap investment: 2.00857
# 	cat and chem cost: 0.0
# 	electricity cost: 0.13389
# 	total fixed op cost: 0.02665
#
# FERRIC CHLORIDE ADDITION:
#
# 	total cap investment: 1.6475
# 	cat and chem cost: 0.24895
# 	electricity cost: 0.0
# 	total fixed op cost: 0.02194
#
# CHLORINATION:
#
# 	total cap investment: 5.20644
# 	cat and chem cost: 0.0345
# 	electricity cost: 1e-05
# 	total fixed op cost: 0.06933
#
# STATIC MIXER:
#
# 	total cap investment: 0.11622
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00154
#
# HOLDING TANK:
#
# 	total cap investment: 1.48059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.01946
#
# MEDIA FILTRATION:
#
# 	total cap investment: 2.68667
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03578
#
# ANTI SCALANT ADDITION:
#
# 	total cap investment: 0.06842
# 	cat and chem cost: 0.24671
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00091
#
# CARTRIDGE FILTRATION:
#
# 	total cap investment: 2.60237
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03465
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 11.13283
# 	cat and chem cost: 0.10588
# 	electricity cost: 1.4899
# 	total fixed op cost: 0.14825
#
# HOLDING TANK B:
#
# 	total cap investment: 0.52194
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# UV AOP:
#
# 	total cap investment: 4.89234
# 	cat and chem cost: 0.03847
# 	electricity cost: 0.06154
# 	total fixed op cost: 0.06515
#
# CO2 ADDITION:
#
# 	total cap investment: 1.14882
# 	cat and chem cost: 0.0
# 	electricity cost: 0.00615
# 	total fixed op cost: 0.01524
#
# LIME ADDITION:
#
# 	total cap investment: 0.69076
# 	cat and chem cost: 0.0023
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0092
#
# TREATED STORAGE:
#
# 	total cap investment: 0.52179
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# BACKWASH SOLIDS HANDLING:
#
# 	total cap investment: 0.00205
# 	cat and chem cost: 0.0
# 	electricity cost: 1e-05
# 	total fixed op cost: 3e-05
#
# LANDFILL:
#
# 	total cap investment: 8e-05
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# MUNICIPAL DRINKING:
#
# 	total cap investment: 0.40717
# 	cat and chem cost: 0.0
# 	electricity cost: 0.18898
# 	total fixed op cost: 0.0054
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 35.135
# Annual Fixed Operating Cost ($MM/yr) 0.467
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.677
# Annual Electricity Costs ($MM/yr) 1.88
# Annual Other Variable Costs ($MM/yr) 0.176
# Annual Operating Costs ($MM/yr) 3.201
# Treated water (m3/s) ---> 0.145
# Total water recovery (%) ---> 47.043
# Electricity intensity (kwh/m3) --->  3.059
# LCOW ($/m3) --->  1.312
# Electricity portion of LCOW (%) ---> 31.237
# ----------------------------------------------------------------------
# 	Feed pressure for reverse_osmosis: 60.49 bar
# 	Membrane area for reverse_osmosis: 29369.03 m2
# 	Feed Flux for reverse_osmosis: 32.75000052568557 lmh
# 	Reject Flux for reverse_osmosis: 2.7500004821775073 lmh
# 	A constant for reverse_osmosis: 2.8750000044549875
# 	B constant for reverse_osmosis: 0.33004385560173977

# %%
# If you need the system recovery to match better.... set a maximum recovery rate.
# The previous system recovery results must be greater than the limit you set below. If this is not the case, then
# you need to ease the bounds on the flux assumpations.

# desired_recovery = 0.44

# if m.fs.costing.system_recovery() < desired_recovery:
#     m.fs.recovery_bound = Constraint(expr=m.fs.costing.system_recovery >= desired_recovery)

#     wt.run_water_tap(m=m, objective=True, print_model_results="summary", skip_small=True)

#     wt.print_ro_results(m)

# else:
#     print("system recovery already lower than desired recovery. desired:", desired_recovery, 
#           "current:", m.fs.costing.system_recovery())

# %%
# MAKE SURE THAT CURRENT PRESSURE IS NOT AT LIMITS IF WANTING TO DO SENSITIVITY ANALYSES.
# MAKE SURE THAT AREA IS NOT VERY SMALL OR VERY LARGE IF WANTING TO DO SENSITIVITY ANALYSES.
# MAKE SURE THAT FEED PRESSURES ARE REASONABLE --> ~55-75bar for first pass RO, ~10-30 bar for bracksih first pass
# second pass / stage ??

# %%
# store RO variables
ro_stash = {}
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        ro_stash[key] = {"feed.pressure" : getattr(m.fs, key).feed.pressure[0](),
        "membrane_area" : getattr(m.fs, key).membrane_area[0](),
        "a" : getattr(m.fs, key).a[0](),
        "b" : getattr(m.fs, key).b[0]()}

# %%
# set everything and deactivate constraints
m = wt.watertap_setup(dynamic=False)
m = wt.case_study_trains.get_case_study(m=m)

for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).feed.pressure.unfix()
        getattr(m.fs, key).membrane_area.unfix()
        print("Unfixing feed presure and area for", key, '...\n')
        
wt.run_water_tap(m=m, objective=True, skip_small=True)

# set variables so that degrees of freedom is zero
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).feed.pressure.fix(ro_stash[key]["feed.pressure"])
        getattr(m.fs, key).membrane_area.fix(ro_stash[key]["membrane_area"])
        getattr(m.fs, key).a.fix(ro_stash[key]["a"])
        getattr(m.fs, key).b.fix(ro_stash[key]["b"])

# run model to make sure it still works
#m.fs.objective_function.deactivate()
wt.run_water_tap(m=m, objective=False, print_model_results="summary", skip_small=True)

wt.print_ro_results(m)
# Out:
# santa_barbara
#
# ------- Adding Unit Processes -------
# sw_onshore_intake
# ferric_chloride_addition
# chlorination
# static_mixer
# holding_tank
# media_filtration
# anti_scalant_addition
# cartridge_filtration
# reverse_osmosis
# holding_tank_b
# uv_aop
# co2_addition
# lime_addition
# treated_storage
# backwash_solids_handling
# landfill
# municipal_drinking
# -------------------------------------
#
# adding source
#
# Connecting unit processes...
# Unfixing feed presure and area for reverse_osmosis ...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 4
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# SW ONSHORE INTAKE:
#
# 	total cap investment: 2.00857
# 	cat and chem cost: 0.0
# 	electricity cost: 0.13389
# 	total fixed op cost: 0.02665
#
# FERRIC CHLORIDE ADDITION:
#
# 	total cap investment: 1.6475
# 	cat and chem cost: 0.24895
# 	electricity cost: 0.0
# 	total fixed op cost: 0.02194
#
# CHLORINATION:
#
# 	total cap investment: 5.20644
# 	cat and chem cost: 0.0345
# 	electricity cost: 1e-05
# 	total fixed op cost: 0.06933
#
# STATIC MIXER:
#
# 	total cap investment: 0.11622
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00154
#
# HOLDING TANK:
#
# 	total cap investment: 1.48059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.01946
#
# MEDIA FILTRATION:
#
# 	total cap investment: 2.68667
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03578
#
# ANTI SCALANT ADDITION:
#
# 	total cap investment: 0.06842
# 	cat and chem cost: 0.24671
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00091
#
# CARTRIDGE FILTRATION:
#
# 	total cap investment: 2.60237
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03465
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 11.13283
# 	cat and chem cost: 0.10588
# 	electricity cost: 1.4899
# 	total fixed op cost: 0.14825
#
# HOLDING TANK B:
#
# 	total cap investment: 0.52194
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# UV AOP:
#
# 	total cap investment: 4.89234
# 	cat and chem cost: 0.03847
# 	electricity cost: 0.06154
# 	total fixed op cost: 0.06515
#
# CO2 ADDITION:
#
# 	total cap investment: 1.14882
# 	cat and chem cost: 0.0
# 	electricity cost: 0.00615
# 	total fixed op cost: 0.01524
#
# LIME ADDITION:
#
# 	total cap investment: 0.69076
# 	cat and chem cost: 0.0023
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0092
#
# TREATED STORAGE:
#
# 	total cap investment: 0.52179
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# BACKWASH SOLIDS HANDLING:
#
# 	total cap investment: 0.00205
# 	cat and chem cost: 0.0
# 	electricity cost: 1e-05
# 	total fixed op cost: 3e-05
#
# LANDFILL:
#
# 	total cap investment: 8e-05
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# MUNICIPAL DRINKING:
#
# 	total cap investment: 0.40717
# 	cat and chem cost: 0.0
# 	electricity cost: 0.18898
# 	total fixed op cost: 0.0054
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 35.135
# Annual Fixed Operating Cost ($MM/yr) 0.467
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.677
# Annual Electricity Costs ($MM/yr) 1.88
# Annual Other Variable Costs ($MM/yr) 0.176
# Annual Operating Costs ($MM/yr) 3.201
# Treated water (m3/s) ---> 0.145
# Total water recovery (%) ---> 47.043
# Electricity intensity (kwh/m3) --->  3.059
# LCOW ($/m3) --->  1.312
# Electricity portion of LCOW (%) ---> 31.237
# ----------------------------------------------------------------------
# 	Feed pressure for reverse_osmosis: 60.49 bar
# 	Membrane area for reverse_osmosis: 29369.03 m2
# 	Feed Flux for reverse_osmosis: 32.750000525565554 lmh
# 	Reject Flux for reverse_osmosis: 2.750000494474712 lmh
# 	A constant for reverse_osmosis: 2.8750000044549875
# 	B constant for reverse_osmosis: 0.33004385560173977

# %%
###### SENSITIVITY ANALYSES

# %%
# 
q=1
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).a.unfix()
        getattr(m.fs, key).b.unfix()
        
        b = [getattr(m.fs, key).b[0]()*1.10, getattr(m.fs, key).b[0]()*0.90]
        a = [getattr(m.fs, key).a[0]()*1.10, getattr(m.fs, key).a[0]()*0.90]
        print(b)
        print(a)
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).a[0] >= a[1])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).a[0] <= a[0])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).b[0] >= b[1])
               )
        q = q + 1
        setattr(m.fs, ("flux_constraint%s" % q), Constraint(
            expr=getattr(m.fs, key).b[0] <= b[0])
               )
        q = q + 1
# Out:
# [0.4133914934299761, 0.338229403715435]
# [3.162500003061112, 2.587500002504546]

# %%
# run to rest before sensitivity

# sensitivity
case_study=wt.case_study_trains.source_water["case_study"]
scenario=wt.case_study_trains.source_water["scenario"]
wt.sensitivity_runs(m = m, save_results = True, scenario = scenario, case_study = case_study, skip_small_sens = True)
# Out:
# ------- Plant Capacity Utilization 70-100% -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.7 LCOW --> 1.8467681710087485
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.715 LCOW --> 1.8080247828771394
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.73 LCOW --> 1.7708735887977785
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.745 LCOW --> 1.7352184159562356
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.76 LCOW --> 1.7009706841476389
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.775 LCOW --> 1.6680486709894324
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.79 LCOW --> 1.6363768608622873
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.805 LCOW --> 1.6058853666402464
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8200000000000001 LCOW --> 1.5765094148894918
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8350000000000001 LCOW --> 1.5481888865546836
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8500000000000001 LCOW --> 1.5208679062785084
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8650000000000001 LCOW --> 1.4944944744509794
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8800000000000001 LCOW --> 1.469020136890065
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.8950000000000001 LCOW --> 1.4443996877387848
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9100000000000001 LCOW --> 1.4205909017461098
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9250000000000002 LCOW --> 1.3975542925962183
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9400000000000002 LCOW --> 1.375252894376423
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9550000000000002 LCOW --> 1.3536520636397553
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9700000000000002 LCOW --> 1.3327192998328756
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 0.9850000000000002 LCOW --> 1.31242408213158
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Capacity Utilization 70-100% 1.0000000000000002 LCOW --> 1.2927377209611173
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611173
# ------- Weighted Average Cost of Capital 5-10% -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.05 LCOW --> 1.2927377209611177
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.052500000000000005 LCOW --> 1.3056619789612398
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.05500000000000001 LCOW --> 1.3187173992395143
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.05750000000000001 LCOW --> 1.331902250715761
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.06000000000000001 LCOW --> 1.3452147754966135
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.06250000000000001 LCOW --> 1.358653191254951
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.06500000000000002 LCOW --> 1.3722156935798477
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.06750000000000002 LCOW --> 1.3859004582925514
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.07000000000000002 LCOW --> 1.3997056437243098
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.07250000000000002 LCOW --> 1.4136293929521329
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.07500000000000002 LCOW --> 1.4276698359888929
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.07750000000000003 LCOW --> 1.4418250919244329
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.08000000000000003 LCOW --> 1.4560932710146608
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.08250000000000003 LCOW --> 1.4704724767158779
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.08500000000000003 LCOW --> 1.4849608076619139
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.08750000000000004 LCOW --> 1.4995563595818597
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.09000000000000004 LCOW --> 1.5142572271565335
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.09250000000000004 LCOW --> 1.5290615058120407
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.09500000000000004 LCOW --> 1.5439672934490491
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.09750000000000004 LCOW --> 1.5589726921066889
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Weighted Average Cost of Capital 5-10% 0.10000000000000005 LCOW --> 1.5740758095601972
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611177
# ------- Inlet TDS +-20% -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 29.75 LCOW --> 1.1912691673621194
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 30.275 LCOW --> 1.2006092506145252
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 30.8 LCOW --> 1.2101103984059403
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 31.325 LCOW --> 1.2197788813431645
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 31.85 LCOW --> 1.2296212654478558
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 32.375 LCOW --> 1.2396444318762223
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 32.9 LCOW --> 1.249855598159586
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 33.425000000000004 LCOW --> 1.2602623411100136
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 33.95 LCOW --> 1.2708726215568045
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 34.475 LCOW --> 1.2816948110809936
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 35.0 LCOW --> 1.2927377209611182
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 35.525000000000006 LCOW --> 1.3040106335401311
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 36.05000000000001 LCOW --> 1.3155233362626997
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 36.575 LCOW --> 1.3272861586505873
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 37.1 LCOW --> 1.3393100124726542
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 37.62500000000001 LCOW --> 1.3516064378887624
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 38.15000000000001 LCOW --> 1.3686516476274597
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 38.675000000000004 LCOW --> 1.387307266701298
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 39.2 LCOW --> 1.4066742748861842
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 39.72500000000001 LCOW --> 1.4267952549149872
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet TDS +-20% 40.250000000000014 LCOW --> 1.447716334791849
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611206
# ------- Inlet Flow +-20% -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.27827999999999997 LCOW --> 1.3106625797884786
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.281372 LCOW --> 1.3061913861187442
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.284464 LCOW --> 1.302497862294295
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.287556 LCOW --> 1.3011344692427715
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.290648 LCOW --> 1.2998145849793534
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.29374 LCOW --> 1.2985368720683048
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.296832 LCOW --> 1.2973000481833885
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.299924 LCOW --> 1.2961028816933484
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.303016 LCOW --> 1.2949441892715632
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.306108 LCOW --> 1.2938228335608135
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.3092 LCOW --> 1.2927377209611177
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.31229200000000007 LCOW --> 1.2916877995418696
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.315384 LCOW --> 1.2906720570719832
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.31847600000000004 LCOW --> 1.289689519160851
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.32156799999999996 LCOW --> 1.2887392475030095
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.32466000000000006 LCOW --> 1.287820338219884
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.327752 LCOW --> 1.2869319202923288
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.3308440000000001 LCOW --> 1.2860731540793293
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.333936 LCOW --> 1.2852432299111483
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.33702800000000005 LCOW --> 1.2844413667620798
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Inlet Flow +-20% 0.34012 LCOW --> 1.2836668109980052
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611006
# ------- Plant Lifetime 15-45 yrs -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 15.0 LCOW --> 1.4144416296329896
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 16.5 LCOW --> 1.3697297048600667
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 18.0 LCOW --> 1.332829965450406
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 19.5 LCOW --> 1.3019355831973627
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 21.0 LCOW --> 1.2757557027997106
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 22.5 LCOW --> 1.2533434638197765
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 24.0 LCOW --> 1.2339885149557233
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 25.5 LCOW --> 1.2171474648924274
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 27.0 LCOW --> 1.2023975165436862
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 28.5 LCOW --> 1.1894047433666894
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 30.0 LCOW --> 1.177901882957824
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 31.5 LCOW --> 1.167672475441209
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 33.0 LCOW --> 1.1585393277950617
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 34.5 LCOW --> 1.150355987473252
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 36.0 LCOW --> 1.1430003475624144
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 37.5 LCOW --> 1.1363697866004796
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 39.0 LCOW --> 1.1303774298386098
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 40.5 LCOW --> 1.1249492411661968
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 42.0 LCOW --> 1.1200217380013953
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 43.5 LCOW --> 1.1155401787483619
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Plant Lifetime 15-45 yrs 45.0 LCOW --> 1.111457112531464
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611173
# ------- electricity price +- 30% -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.0938 LCOW --> 1.1697830809864231
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.09781999999999999 LCOW --> 1.1820785449838993
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.10183999999999999 LCOW --> 1.1943740089813732
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.10585999999999998 LCOW --> 1.2066694729788459
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.10987999999999998 LCOW --> 1.218964936976317
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.11389999999999997 LCOW --> 1.231260400973787
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.11791999999999997 LCOW --> 1.2435558649712566
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.12193999999999997 LCOW --> 1.2558513289687232
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.12595999999999996 LCOW --> 1.2681467929661894
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.12997999999999996 LCOW --> 1.2804422569636538
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.13399999999999995 LCOW --> 1.2927377209611175
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.13801999999999995 LCOW --> 1.3050331849585795
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.14203999999999994 LCOW --> 1.3173286489560403
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.14605999999999994 LCOW --> 1.3296241129535
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.15007999999999994 LCOW --> 1.3419195769509582
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.15409999999999993 LCOW --> 1.3542150409484146
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.15811999999999993 LCOW --> 1.3665105049458703
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.16213999999999992 LCOW --> 1.3788059689433254
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.16615999999999992 LCOW --> 1.3911014329407794
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.17017999999999991 LCOW --> 1.4033968969382309
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# electricity price +- 30% 0.1741999999999999 LCOW --> 1.4156923609356817
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611173
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611177
# ------- membrane_area -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 24981.066941864294 LCOW --> 1.3194237204303145
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 25421.9092996619 LCOW --> 1.3155728452348252
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 25862.751657459507 LCOW --> 1.3126431888116137
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 26303.594015257113 LCOW --> 1.309821825425604
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 26744.43637305472 LCOW --> 1.3071039996964775
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 27185.278730852326 LCOW --> 1.3044852301168972
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 27626.121088649932 LCOW --> 1.301961299228443
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 28066.96344644754 LCOW --> 1.2995282313186352
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 28507.805804245145 LCOW --> 1.2971822751073168
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 28948.64816204275 LCOW --> 1.2949198878809856
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 29389.490519840358 LCOW --> 1.2927377209611206
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 29830.332877637964 LCOW --> 1.2906326063817446
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 30271.17523543557 LCOW --> 1.2886015446607104
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 30712.017593233177 LCOW --> 1.2866416935574942
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 31152.859951030783 LCOW --> 1.2847503577121602
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 31593.70230882839 LCOW --> 1.282924978961645
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 32034.544666625996 LCOW --> 1.2812330719044875
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 32475.387024423602 LCOW --> 1.2831764556745975
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 32916.22938222121 LCOW --> 1.2851231573182602
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 33357.071740018815 LCOW --> 1.2870731991823021
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# membrane_area 33797.91409781642 LCOW --> 1.2890266060728468
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solver returned an infeasible solution...
# Running again with updated initial conditions --- attempt 1
#
# WaterTAP3 solver returned an infeasible solution...
# Running again with updated initial conditions --- attempt 2
#
# WaterTAP3 solver returned an infeasible solution...
# Running again with updated initial conditions --- attempt 3
#
# WaterTAP3 solution infeasible
#
# ----------------------------------------------------------------------
#
# WaterTAP3 solver returned an infeasible solution. Check option to run model with updated initial conditions.
# ----------------------------------------------------------------------
# membrane_area 34238.75645561403 LCOW --> 1.2907829377718167
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209670385
# ------- pressure -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 51.419335528618454 LCOW --> 1.4401309457017193
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 52.024268887778675 LCOW --> 1.4217517006453961
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 52.629202246938895 LCOW --> 1.4046097553704753
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 53.234135606099116 LCOW --> 1.388608692950053
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 53.83906896525934 LCOW --> 1.3736618890350945
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 54.44400232441956 LCOW --> 1.3596912922416968
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 55.04893568357978 LCOW --> 1.3466263818180795
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 55.65386904274 LCOW --> 1.3344032734476547
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 56.25880240190022 LCOW --> 1.3229639490047997
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 56.86373576106044 LCOW --> 1.312845004571934
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 57.46866912022066 LCOW --> 1.3068278967539513
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 58.07360247938088 LCOW --> 1.3015681359950941
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 58.6785358385411 LCOW --> 1.2990303547395268
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 59.28346919770132 LCOW --> 1.2967208957197878
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 59.88840255686154 LCOW --> 1.2946272217161467
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 60.49333591602176 LCOW --> 1.2927377209611304
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 61.098269275181984 LCOW --> 1.291041618762502
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 61.703202634342205 LCOW --> 1.289528902568444
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 62.308135993502425 LCOW --> 1.2881902548705662
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 62.913069352662646 LCOW --> 1.2870169931198097
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# pressure 63.51800271182287 LCOW --> 1.2860010158340212
# ------- RESET -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# LCOW --> 1.2927377209611173
# ------- factor_membrane_replacement -------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.1 LCOW --> 1.2781156095090793
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.12000000000000001 LCOW --> 1.2810400318053365
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.14 LCOW --> 1.2839644540981894
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.16000000000000003 LCOW --> 1.2868888763881674
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.18000000000000002 LCOW --> 1.2898132986756947
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.2 LCOW --> 1.2927377209611173
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.22000000000000003 LCOW --> 1.2956621432447193
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.24000000000000002 LCOW --> 1.2985865655267326
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.26 LCOW --> 1.301510987807357
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.28 LCOW --> 1.3044354100867588
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.30000000000000004 LCOW --> 1.3073598323650724
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.32000000000000006 LCOW --> 1.3102842546424185
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.3400000000000001 LCOW --> 1.3132086769188978
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.3600000000000001 LCOW --> 1.3161330991946005
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.38 LCOW --> 1.319057521469602
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.4 LCOW --> 1.3219819437439706
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.42000000000000004 LCOW --> 1.3249063660177651
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.44000000000000006 LCOW --> 1.3278307882910352
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.4600000000000001 LCOW --> 1.3307552105638274
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.4800000000000001 LCOW --> 1.333679632836183
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# factor_membrane_replacement 0.5000000000000001 LCOW --> 1.3366040551081384
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------

# %%
wt.run_water_tap(m=m, objective=True, print_model_results="summary", skip_small=True)
# Out:
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# SW ONSHORE INTAKE:
#
# 	total cap investment: 2.00857
# 	cat and chem cost: 0.0
# 	electricity cost: 0.13389
# 	total fixed op cost: 0.02665
#
# FERRIC CHLORIDE ADDITION:
#
# 	total cap investment: 1.6475
# 	cat and chem cost: 0.24895
# 	electricity cost: 0.0
# 	total fixed op cost: 0.02194
#
# CHLORINATION:
#
# 	total cap investment: 5.20644
# 	cat and chem cost: 0.0345
# 	electricity cost: 1e-05
# 	total fixed op cost: 0.06933
#
# STATIC MIXER:
#
# 	total cap investment: 0.11622
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00154
#
# HOLDING TANK:
#
# 	total cap investment: 1.48059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.01946
#
# MEDIA FILTRATION:
#
# 	total cap investment: 2.68667
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03578
#
# ANTI SCALANT ADDITION:
#
# 	total cap investment: 0.06842
# 	cat and chem cost: 0.24671
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00091
#
# CARTRIDGE FILTRATION:
#
# 	total cap investment: 2.60237
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03465
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 10.69954
# 	cat and chem cost: 0.10176
# 	electricity cost: 1.49078
# 	total fixed op cost: 0.14248
#
# HOLDING TANK B:
#
# 	total cap investment: 0.52225
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# UV AOP:
#
# 	total cap investment: 4.8935
# 	cat and chem cost: 0.0385
# 	electricity cost: 0.06159
# 	total fixed op cost: 0.06516
#
# CO2 ADDITION:
#
# 	total cap investment: 1.14947
# 	cat and chem cost: 0.0
# 	electricity cost: 0.00616
# 	total fixed op cost: 0.01525
#
# LIME ADDITION:
#
# 	total cap investment: 0.69107
# 	cat and chem cost: 0.0023
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0092
#
# TREATED STORAGE:
#
# 	total cap investment: 0.52209
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00686
#
# BACKWASH SOLIDS HANDLING:
#
# 	total cap investment: 0.00205
# 	cat and chem cost: 0.0
# 	electricity cost: 1e-05
# 	total fixed op cost: 3e-05
#
# LANDFILL:
#
# 	total cap investment: 8e-05
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# MUNICIPAL DRINKING:
#
# 	total cap investment: 0.40746
# 	cat and chem cost: 0.0
# 	electricity cost: 0.18913
# 	total fixed op cost: 0.00541
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 34.704
# Annual Fixed Operating Cost ($MM/yr) 0.462
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.673
# Annual Electricity Costs ($MM/yr) 1.882
# Annual Other Variable Costs ($MM/yr) 0.134
# Annual Operating Costs ($MM/yr) 3.15
# Treated water (m3/s) ---> 0.146
# Total water recovery (%) ---> 47.082
# Electricity intensity (kwh/m3) --->  3.059
# LCOW ($/m3) --->  1.293
# Electricity portion of LCOW (%) ---> 31.704
# ----------------------------------------------------------------------

# %%
# creates csv in results folder with the name: *case_study*_*scenario*.csv
# In this case, save the final baseline result.

df = wt.get_results_table(m=m, case_study=wt.case_study_trains.source_water["case_study"], 
                                scenario=wt.case_study_trains.source_water["scenario"])

# %%
#m.fs.objective_function.deactivate()

# %%
# lcow_list = []
# water_recovery_list = []
# scenario_value = []
# scenario_name = []
# elec_lcow = []
# elec_int = []

# runs_per_scenario = 20
# skip_small_sens = True
# # ############################################################    
# print("-------", "RESET", "-------")
# wt.run_water_tap(m = m, objective=True, skip_small = True)
# print("LCOW -->", m.fs.costing.LCOW())

# ############ salinity  +-30% ############
# stash_value = []
# for key in m.fs.flow_in_dict:   
#     stash_value.append(value(getattr(m.fs, key).conc_mass_in[0, "tds"]))
# scenario = "Inlet TDS +-20%"
# print("-------", scenario, "-------")
# ub = 1.15
# lb = 0.85
# step = (ub - lb) / runs_per_scenario

# for i in np.arange(lb, ub + step, step):
#     q=0
#     for key in m.fs.flow_in_dict:
#         getattr(m.fs, key).conc_mass_in[0, "tds"].fix(stash_value[q] * i)
#         q = q + 1

#     wt.run_water_tap(m = m, objective=True, skip_small = skip_small_sens)
#     print(scenario, stash_value[q-1] * i, "LCOW -->", m.fs.costing.LCOW())

#     lcow_list.append(value(m.fs.costing.LCOW))
#     water_recovery_list.append(value(m.fs.costing.system_recovery))
#     scenario_value.append(i)
#     scenario_name.append(scenario)
#     elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
#     elec_int.append(value(m.fs.costing.electricity_intensity))

# q=0
# for key in m.fs.flow_in_dict:    
#     getattr(m.fs, key).conc_mass_in[0, "tds"].fix(stash_value[q])
#     q = q + 1

# %%
# ############################################################
# print("-------", "RESET", "-------")
# # wt.run_water_tap(m = m, objective=False, skip_small = True)
# # print("LCOW -->", m.fs.costing.LCOW())
# ############ inlet flow +-30% ############
# stash_value = []
# for key in m.fs.flow_in_dict:   
#     stash_value.append(value(getattr(m.fs, key).flow_vol_in[0]))
# scenario = "Inlet Flow +-20%"
# print("-------", scenario, "-------")
# ub = 1.1
# lb = 0.9
# step = (ub - lb) / runs_per_scenario

# for i in np.arange(lb, ub + step, step):
#     q=0
#     for key in m.fs.flow_in_dict:
#         getattr(m.fs, key).flow_vol_in[0].fix(stash_value[q] * i)
#         q = q + 1

#     wt.run_water_tap(m = m, objective=False, skip_small = skip_small_sens)
#     print(scenario, stash_value[q-1] * i, "LCOW -->", m.fs.costing.LCOW())

#     lcow_list.append(value(m.fs.costing.LCOW))
#     water_recovery_list.append(value(m.fs.costing.system_recovery))
#     scenario_value.append(i)
#     scenario_name.append(scenario)
#     elec_lcow.append(value(m.fs.costing.elec_frac_LCOW))
#     elec_int.append(value(m.fs.costing.electricity_intensity))

# q=0
# for key in m.fs.flow_in_dict:    
#     getattr(m.fs, key).flow_vol_in[0].fix(stash_value[q])
#     q = q + 1
