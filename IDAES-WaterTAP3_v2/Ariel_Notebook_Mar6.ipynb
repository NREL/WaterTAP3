# %%
import watertap as wt
import pandas as pd
from pyomo.environ import value, Block
from idaes.core import FlowsheetBlock
# %matplotlib inline
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
from case_study_trains import *
import case_study_trains
# import pyomo.util.infeasible as infeas
# print(infeas.log_infeasible_bounds(m))
# infeas.log_close_to_bounds(m)


m = wt.watertap_setup(dynamic = False)

# wt.case_study_trains.train = {"case_study": "KBHDP",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Irwin",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "EMWD",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Santa_Barbara",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Carlsbad",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Ashkelon",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Tampa_Bay",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "HRSD",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

wt.case_study_trains.train = {"case_study": "Big_Spring",
                             "reference": "NAWI",
                             "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "OCWD",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}

# wt.case_study_trains.train = {"case_study": "Solaire",
#                              "reference": "NAWI",
#                              "scenario": "Baseline"}


# TODO LATER: how to make this sync with info in train input data. We might not need to do that.
#But, if the source water type is different to what is in the train (pfd dictionary), 
#then we should updat the node name. If more than two sources - what to do? Needs to be
#based on pfd node!?

# wt.case_study_trains.source_water = {"case_study": "KBHDP", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "KBHDP_Brackish_Ave"}

# wt.case_study_trains.source_water = {"case_study": "Irwin", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Brackish"}

# wt.case_study_trains.source_water = {"case_study": "EMWD", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "EMWD_CA_Brackish"}

# wt.case_study_trains.source_water = {"case_study": "Santa_Barbara", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Seawater"}

# wt.case_study_trains.source_water = {"case_study": "Carlsbad", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Seawater"}

# wt.case_study_trains.source_water = {"case_study": "Ashkelon", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Seawater"}

# wt.case_study_trains.source_water = {"case_study": "Tampa_Bay", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Seawater"}
# 
# wt.case_study_trains.source_water = {"case_study": "HRSD", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "HRSD_Municipal"}

wt.case_study_trains.source_water = {"case_study": "Big_Spring", 
                             "reference": "NAWI",
                             "scenario": "Baseline",
                             "water_type": "Big_Spring_Feed"}

# wt.case_study_trains.source_water = {"case_study": "OCWD", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "OCWD_Feed"}

# wt.case_study_trains.source_water = {"case_study": "Solaire", 
#                              "reference": "NAWI",
#                              "scenario": "Baseline",
#                              "water_type": "Solaire_Graywater"}

m = wt.case_study_trains.get_case_study(m=m) # flow is set as case study flow unless defined.
# Out:
# Big_Spring
# holding_tank
# microfiltration
# ro_deep
# uv_aop
# treated_storage
# municipal_drinking
# surface_discharge
# adding source
# [['uv_aop', 'inlet']]
# adding splitter
# params into splitter --> [0.4, 0.6]

# %%
#wt.display.show_train2(model_name=m)
# m.fs.pfd_dict

# %%
#m.fs.Big_Spring_Feed.flow_vol_in.fix(4)

# %%
m = wt.optimize_setup.splitter_streams(m=m, from_units=["microfiltration"])
# Out:
# unfixes stream from ---> splitter1 ---> outlet1
# unfixes stream from ---> splitter1 ---> outlet2

# %%
wt.run_water_tap(m=m, solver_results=False, print_model_results=False, return_results = False, 
                 max_attemps=3, objective=True)
# Out:
# degrees_of_freedom: 2
# WaterTAP3 solution optimal

# %%
for b_unit in m.fs.component_objects(Block, descend_into=True):
    if hasattr(b_unit, 'costing'):
        print(b_unit)
        print("total_cap_investment:", b_unit.costing.total_cap_investment())
        print("----------------------------------------------------------------------")
print(m.fs.costing.LCOW())
# Out:
# fs.holding_tank
# total_cap_investment: 0.013298652226166024
# ----------------------------------------------------------------------
# fs.microfiltration
# total_cap_investment: 4.883752574618745
# ----------------------------------------------------------------------
# fs.ro_deep
# total_cap_investment: 0.6562714795781998
# ----------------------------------------------------------------------
# fs.uv_aop
# total_cap_investment: 5.0436841040345755
# ----------------------------------------------------------------------
# fs.treated_storage
# total_cap_investment: 0.013292255268841865
# ----------------------------------------------------------------------
# fs.municipal_drinking
# total_cap_investment: 0.22934285475041105
# ----------------------------------------------------------------------
# fs.surface_discharge
# total_cap_investment: 0.3496412602425859
# ----------------------------------------------------------------------
# 0.47335326262637734

# %%
m.fs.splitter1.display()
# Out:
# Block fs.splitter1
#
#   Variables:
#     flow_vol_outlet1 : Volumetric flowrate of water out of unit
#         Size=1, Index=fs.time
#         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#         0.0 : 1e-09 : 0.00074984937319379 : 100.0 : False : False : NonNegativeReals
#     conc_mass_outlet1 : Mass concentration of species at outlet
#         Size=25, Index=fs.splitter1.conc_mass_outlet1_index
#         Key                                  : Lower : Value                  : Upper : Fixed : Stale : Domain
#                             (0.0, 'arsenic') :  None :  5.101020153020402e-07 :  None : False : False :  Reals
#                              (0.0, 'barium') :  None :  4.520904135618082e-05 :  None : False : False :  Reals
#                                 (0.0, 'bod') :  None :      99853.31850030458 :  None : False : False :  Reals
#                               (0.0, 'boron') :  None :  0.0004000800120016002 :  None : False : False :  Reals
#                             (0.0, 'bromide') :  None : 1.0002000300040004e-06 :  None : False : False :  Reals
#                             (0.0, 'calcium') :  None :    0.08046609241382183 :  None : False : False :  Reals
#                            (0.0, 'chloride') :  None :    0.29797959293879184 :  None : False : False :  Reals
#             (0.0, 'electrical_conductivity') :  None :     0.1700340051006801 :  None : False : False :  Reals
#                            (0.0, 'fluoride') :  None :  0.0009701940291038805 :  None : False : False :  Reals
#                            (0.0, 'hardness') :  None :     0.3120624093612481 :  None : False : False :  Reals
#                                (0.0, 'iron') :  None :  0.0003023104590687091 :  None : False : False :  Reals
#                           (0.0, 'magnesium') :  None :   0.027015402810408047 :  None : False : False :  Reals
#                           (0.0, 'manganese') :  None :  5.261052157821042e-05 :  None : False : False :  Reals
#                             (0.0, 'nitrate') :  None :      99853.31850030458 :  None : False : False :  Reals
#                 (0.0, 'nitrate_as_nitrogen') :  None :   0.008641728259234564 :  None : False : False :  Reals
#                          (0.0, 'phosphates') :  None :  0.0005201040156020801 :  None : False : False :  Reals
#                           (0.0, 'potassium') :  None :    0.01897379456917589 :  None : False : False :  Reals
#                            (0.0, 'selenium') :  None : 1.0602120318042406e-06 :  None : False : False :  Reals
#                             (0.0, 'silicon') :  None :    0.02104420863128417 :  None : False : False :  Reals
#                              (0.0, 'sodium') :  None :     0.2316263229483264 :  None : False : False :  Reals
#                             (0.0, 'sulfate') :  None :     0.1882876556482531 :  None : False : False :  Reals
#                                 (0.0, 'tds') :  None :     0.9857471395704427 :  None : False : False :  Reals
#                                 (0.0, 'toc') :  None :   0.009531906285938124 :  None : False : False :  Reals
#         (0.0, 'total_coliforms_fecal_ecoli') :  None :      294.2550780730638 :  None : False : False :  Reals
#                                 (0.0, 'tss') :  None :   0.006526305195776103 :  None : False : False :  Reals
#     pressure_outlet1 : Pressure at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#     temperature_outlet1 : Temperature at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 300.0 :  None : False : False : NonNegativeReals
#     split_fraction_outlet1 : split fraction
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  0.01 :  0.01 :  0.99 : False : False : NonNegativeReals
#     flow_vol_outlet2 : Volumetric flowrate of water out of unit
#         Size=1, Index=fs.time
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 : 1e-09 : 0.0742351509552221 : 100.0 : False : False : NonNegativeReals
#     conc_mass_outlet2 : Mass concentration of species at outlet
#         Size=25, Index=fs.splitter1.conc_mass_outlet2_index
#         Key                                  : Lower : Value                  : Upper : Fixed : Stale : Domain
#                             (0.0, 'arsenic') :  None :  5.101020153020402e-07 :  None : False : False :  Reals
#                              (0.0, 'barium') :  None :  4.520904135618082e-05 :  None : False : False :  Reals
#                                 (0.0, 'bod') :  None :      99853.31850030458 :  None : False : False :  Reals
#                               (0.0, 'boron') :  None :  0.0004000800120016002 :  None : False : False :  Reals
#                             (0.0, 'bromide') :  None : 1.0002000300040004e-06 :  None : False : False :  Reals
#                             (0.0, 'calcium') :  None :    0.08046609241382183 :  None : False : False :  Reals
#                            (0.0, 'chloride') :  None :    0.29797959293879184 :  None : False : False :  Reals
#             (0.0, 'electrical_conductivity') :  None :     0.1700340051006801 :  None : False : False :  Reals
#                            (0.0, 'fluoride') :  None :  0.0009701940291038805 :  None : False : False :  Reals
#                            (0.0, 'hardness') :  None :     0.3120624093612481 :  None : False : False :  Reals
#                                (0.0, 'iron') :  None :  0.0003023104590687091 :  None : False : False :  Reals
#                           (0.0, 'magnesium') :  None :   0.027015402810408047 :  None : False : False :  Reals
#                           (0.0, 'manganese') :  None :  5.261052157821042e-05 :  None : False : False :  Reals
#                             (0.0, 'nitrate') :  None :      99853.31850030458 :  None : False : False :  Reals
#                 (0.0, 'nitrate_as_nitrogen') :  None :   0.008641728259234564 :  None : False : False :  Reals
#                          (0.0, 'phosphates') :  None :  0.0005201040156020801 :  None : False : False :  Reals
#                           (0.0, 'potassium') :  None :    0.01897379456917589 :  None : False : False :  Reals
#                            (0.0, 'selenium') :  None : 1.0602120318042406e-06 :  None : False : False :  Reals
#                             (0.0, 'silicon') :  None :    0.02104420863128417 :  None : False : False :  Reals
#                              (0.0, 'sodium') :  None :     0.2316263229483264 :  None : False : False :  Reals
#                             (0.0, 'sulfate') :  None :     0.1882876556482531 :  None : False : False :  Reals
#                                 (0.0, 'tds') :  None :     0.9857471395704427 :  None : False : False :  Reals
#                                 (0.0, 'toc') :  None :   0.009531906285938124 :  None : False : False :  Reals
#         (0.0, 'total_coliforms_fecal_ecoli') :  None :      294.2550780730638 :  None : False : False :  Reals
#                                 (0.0, 'tss') :  None :   0.006526305195776103 :  None : False : False :  Reals
#     pressure_outlet2 : Pressure at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#     temperature_outlet2 : Temperature at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 300.0 :  None : False : False : NonNegativeReals
#     split_fraction_outlet2 : split fraction
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  0.01 :  0.99 :  0.99 : False : False : NonNegativeReals
#     flow_vol_in : Volumetric flowrate of water out of unit
#         Size=1, Index=fs.time
#         Key : Lower : Value         : Upper : Fixed : Stale : Domain
#         0.0 : 1e-09 : 0.07498500075 : 100.0 : False : False : NonNegativeReals
#     conc_mass_in : Mass concentration of species at outlet
#         Size=25, Index=fs.splitter1.conc_mass_in_index
#         Key                                  : Lower : Value                  : Upper : Fixed : Stale : Domain
#                             (0.0, 'arsenic') :  None :  5.101020153020402e-07 :  None : False : False :  Reals
#                              (0.0, 'barium') :  None :  4.520904135618082e-05 :  None : False : False :  Reals
#                                 (0.0, 'bod') :  None :      99853.31850030458 :  None : False : False :  Reals
#                               (0.0, 'boron') :  None :  0.0004000800120016002 :  None : False : False :  Reals
#                             (0.0, 'bromide') :  None : 1.0002000300040004e-06 :  None : False : False :  Reals
#                             (0.0, 'calcium') :  None :    0.08046609241382183 :  None : False : False :  Reals
#                            (0.0, 'chloride') :  None :    0.29797959293879184 :  None : False : False :  Reals
#             (0.0, 'electrical_conductivity') :  None :     0.1700340051006801 :  None : False : False :  Reals
#                            (0.0, 'fluoride') :  None :  0.0009701940291038805 :  None : False : False :  Reals
#                            (0.0, 'hardness') :  None :     0.3120624093612481 :  None : False : False :  Reals
#                                (0.0, 'iron') :  None :  0.0003023104590687091 :  None : False : False :  Reals
#                           (0.0, 'magnesium') :  None :   0.027015402810408047 :  None : False : False :  Reals
#                           (0.0, 'manganese') :  None :  5.261052157821042e-05 :  None : False : False :  Reals
#                             (0.0, 'nitrate') :  None :      99853.31850030458 :  None : False : False :  Reals
#                 (0.0, 'nitrate_as_nitrogen') :  None :   0.008641728259234564 :  None : False : False :  Reals
#                          (0.0, 'phosphates') :  None :  0.0005201040156020801 :  None : False : False :  Reals
#                           (0.0, 'potassium') :  None :    0.01897379456917589 :  None : False : False :  Reals
#                            (0.0, 'selenium') :  None : 1.0602120318042406e-06 :  None : False : False :  Reals
#                             (0.0, 'silicon') :  None :    0.02104420863128417 :  None : False : False :  Reals
#                              (0.0, 'sodium') :  None :     0.2316263229483264 :  None : False : False :  Reals
#                             (0.0, 'sulfate') :  None :     0.1882876556482531 :  None : False : False :  Reals
#                                 (0.0, 'tds') :  None :     0.9857471395704427 :  None : False : False :  Reals
#                                 (0.0, 'toc') :  None :   0.009531906285938124 :  None : False : False :  Reals
#         (0.0, 'total_coliforms_fecal_ecoli') :  None :      294.2550780730638 :  None : False : False :  Reals
#                                 (0.0, 'tss') :  None :   0.006526305195776103 :  None : False : False :  Reals
#     temperature_in : Temperature at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None : 300.0 :  None : False : False :  Reals
#     pressure_in : Pressure at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :   1.0 :  None : False : False :  Reals
#
#   Objectives:
#     None
#
#   Constraints:
#     outlet1_total_coliforms_fecal_ecoli_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_tss_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_toc_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_nitrate_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_boron_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_selenium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_iron_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_manganese_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_hardness_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_magnesium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_phosphates_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_potassium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_sodium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_sulfate_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_chloride_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_electrical_conductivity_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_tds_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_bod_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_arsenic_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_barium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_calcium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_fluoride_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_nitrate_as_nitrogen_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_bromide_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_silicon_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_total_coliforms_fecal_ecoli_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_tss_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_toc_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_nitrate_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_boron_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_selenium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_iron_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_manganese_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_hardness_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_magnesium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_phosphates_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_potassium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_sodium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_sulfate_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_chloride_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_electrical_conductivity_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_tds_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_bod_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_arsenic_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_barium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_calcium_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_fluoride_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_nitrate_as_nitrogen_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_bromide_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_silicon_eq : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_eq_flow : Size=1
#         Key  : Lower : Body                    : Upper
#         None :   0.0 : -2.2835023560929812e-06 :   0.0
#     outlet2_eq_flow : Size=1
#         Key  : Lower : Body                  : Upper
#         None :   0.0 : 7.657995411136653e-07 :   0.0
#     outlet1_eq_temp : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_eq_temp : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet1_eq_pres : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0
#     outlet2_eq_pres : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :   0.0

# %%
import pyomo.util.infeasible as infeas

# %%
infeas.log_infeasible_bounds(m)

# %%
infeas.log_close_to_bounds(m)
# Out:
# INFO: fs.holding_tank.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.holding_tank.conc_mass_in[0.0,bromide] near LB of 0
# INFO: fs.holding_tank.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,total_coliforms_fecal_ecoli] near LB
#     of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,electrical_conductivity] near LB of
#     0
# INFO: fs.holding_tank.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.holding_tank.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.microfiltration.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.microfiltration.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,total_coliforms_fecal_ecoli] near
#     LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,electrical_conductivity] near LB
#     of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.microfiltration.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.ro_deep.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.ro_deep.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.ro_deep.conc_mass_out[0.0,bromide] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,total_coliforms_fecal_ecoli] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,electrical_conductivity] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.ro_deep.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.uv_aop.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.uv_aop.conc_mass_in[0.0,bromide] near LB of 0
# INFO: fs.uv_aop.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.uv_aop.conc_mass_out[0.0,bromide] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,electrical_conductivity] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.uv_aop.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.treated_storage.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.treated_storage.conc_mass_in[0.0,bromide] near LB of 0
# INFO: fs.treated_storage.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.treated_storage.conc_mass_out[0.0,bromide] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,total_coliforms_fecal_ecoli] near
#     LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,electrical_conductivity] near LB
#     of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.treated_storage.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_in[0.0,bromide] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_out[0.0,bromide] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,total_coliforms_fecal_ecoli]
#     near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,electrical_conductivity] near
#     LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB
#     of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.municipal_drinking.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,tss] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,nitrate] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,boron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,selenium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,iron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,manganese] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,hardness] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,phosphates] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,electrical_conductivity] near LB
#     of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,bod] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,arsenic] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,barium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_in[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,tss] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,nitrate] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,boron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,selenium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,iron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,manganese] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,hardness] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,phosphates] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,electrical_conductivity] near LB
#     of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,bod] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,barium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_out[0.0,nitrate_as_nitrogen] near LB of 0
# INFO: fs.surface_discharge.flow_vol_waste[0.0] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,total_coliforms_fecal_ecoli]
#     near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,tss] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,toc] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,nitrate] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,boron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,selenium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,iron] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,manganese] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,hardness] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,magnesium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,phosphates] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,potassium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,sodium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,sulfate] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,chloride] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,electrical_conductivity] near
#     LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,tds] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,bod] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,arsenic] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,barium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,calcium] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,fluoride] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,nitrate_as_nitrogen] near LB of
#     0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,bromide] near LB of 0
# INFO: fs.surface_discharge.conc_mass_waste[0.0,silicon] near LB of 0
# INFO: fs.Big_Spring_Feed.conc_mass_out[0.0,arsenic] near LB of 0
# INFO: fs.Big_Spring_Feed.conc_mass_out[0.0,bromide] near LB of 0

# %%
infeas.log_infeasible_constraints(m)

# %%
def it_gets_results(appended, print_it=False, write_it=True):    
    train = wt.case_study_trains.train

    py_var = [
        "fixed_cap_inv",
        "total_cap_investment",
        "cat_and_chem_cost",
        "electricity_cost",
        "total_fixed_op_cost",
    "flow_in", "flow_out"]

    excel_var = ['Fixed Capital Investment (FCI)',
                'Total Capital Investment (TCI)',
                'Catalysts and Chemicals',
                'Electricity',
                'Total Fixed Operating Costs']

    case_study = train['case_study']
    if print_it:
        print(f'\n######### Case study = {case_study} #########\n\n\n')

    cap_inv_tot = []

    big_dict = {}

    for b_unit in m.fs.component_objects(Block, descend_into=True):
        unit = str(b_unit)[3:]
        if hasattr(b_unit, 'costing'):
            if print_it:
                print(f'____________{unit}____________')
            py_vals =  []
            excel_vals = []
            big_dict[unit] = {'python': {}, 'excel': {}}
            df = pd.read_csv("data/case_study_results.csv")
            df = df[df.case_study == train['case_study']]
            df = df[df.scenario == train['scenario']]
            df = df[df.unit_process == unit]
            flow_in_excel = round(df[df.variable == "flow_vol_in"].value.sum(), 5)
            flow_out_excel = round(df[df.variable == 'flow_vol_out'].value.sum(), 5)
            flow_in_python = round(value(b_unit.inlet.flow_vol[0.0] * 3600), 5)
            flow_out_python = round(value(b_unit.outlet.flow_vol[0.0] * 3600), 5)
            waste_python = round(value(b_unit.waste.flow_vol[0.0] * 3600), 5)
            if print_it:
                print(f'\n#### flow_in\nPython --> {flow_in_python}')
                print(f'Excel --> {flow_in_excel}\n\n')
                print(f'#### flow out\nPython --> {flow_out_python}')
                print(f'Excel --> {flow_out_excel}\n\n')
                print(f'#### waste\nPython--> {waste_python}\n')
            for py, ex in dict(zip(py_var, excel_var)).items():
                if print_it:
                    print(f'\n#### {py}')
                try:
                    num = value(getattr(b_unit.costing, py))
                    py_vals.append(num)
                    if print_it:
                        print(f'Python --> {round(num, 5)}')
                except ZeroDivisionError:
                    if print_it:
                        print(f'Python --> {0} - ERROR')
                    py_vals.append(0)

                df = pd.read_csv("data/case_study_results.csv")
                df = df[df.case_study == train['case_study']]
                df = df[df.scenario == train['scenario']]
                df = df[df.unit_process == unit]
                num = df[df.Variable == ex].value.sum()
                if print_it:
                    print(f'Excel --> {round(num, 5)}\n\n')
                excel_vals.append(num)
            py_vals.append(flow_in_python)
            py_vals.append(flow_out_python)
            py_dict = dict(zip(py_var, py_vals))
            excel_vals.append(flow_in_excel)
            excel_vals.append(flow_out_excel)
            excel_dict = dict(zip(py_var, excel_vals))
            big_dict[unit]['python'] = py_dict
            big_dict[unit]['excel'] = excel_dict

    else:
        pass 

    df = pd.DataFrame.from_dict({(i,j): big_dict[i][j] 
                               for i in big_dict.keys() 
                               for j in big_dict[i].keys()},
                               orient='index')

    df['case_study'] = case_study
    df['LCOW'] = value(m.fs.costing.LCOW)
    if write_it:
        df.to_csv(f'results/test_compare_{case_study}_{appended}.csv')

# %%
# wt.run_water_tap(m=m, solver_results=True, print_model_results=True)
# it_gets_results('testy1')
# wt.run_water_tap(m=m, solver_results=True, print_model_results=False)
# it_gets_results('testy2')

# %%
def do_it_all(append1, append2, solver_results=True, model_results=False):
    case_studies = ['Ashkelon', 'Big_Spring', 'Carlsbad', 'EMWD', 'HRSD', 'Irwin', 'KBHDP', 'OCWD', 'Santa_Barbara', 'Solaire', 'Tampa_Bay']
    water_sources = ['Seawater', 'Big_Spring_Feed', 'Seawater', 'EMWD_CA_Brackish', 'HRSD_Municipal', 'Brackish', 'KBHDP_Brackish_Ave', 'OCWD_Feed', 'Seawater', 'Solaire_Graywater', 'Seawater']
    wt_dict = dict(zip(case_studies, water_sources))
    for k, v in wt_dict.items():
        
        m = wt.watertap_setup(dynamic = False)
        
        wt.case_study_trains.train = {"case_study": k,
                                 "reference": "NAWI",
                                 "scenario": "Baseline"}
        
        wt.case_study_trains.source_water = {"case_study": k, 
                                 "reference": "NAWI",
                                 "scenario": "Baseline",
                                 "water_type": v}
        
        wt.run_water_tap(m=m, solver_results=solver_results, print_model_results=model_results)
        
        it_gets_results(append1)
        
        wt.run_water_tap(m=m, solver_results=solver_results, print_model_results=model_results)
        
        it_gets_results(append2)
# value(m.fs.costing.LCOW)

# %%
# wt.run_water_tap(m=m, solver_results=True, print_model_results=False)

# %%
# df.to_csv(f'results/test_compare_{case_study}.csv')
wt.run_water_tap(m=m, solver_results=True, print_model_results=False)

train = wt.case_study_trains.train

py_var = [
    "fixed_cap_inv",
    "total_cap_investment",
    "cat_and_chem_cost",
    "electricity_cost",
    "total_fixed_op_cost",
"flow_in", "flow_out"]

excel_var = ['Fixed Capital Investment (FCI)',
            'Total Capital Investment (TCI)',
            'Catalysts and Chemicals',
            'Electricity',
            'Total Fixed Operating Costs']

case_study = train['case_study']
print(f'\n######### Case study = {case_study} #########\n\n\n')

cap_inv_tot = []

big_dict = {}

for b_unit in m.fs.component_objects(Block, descend_into=True):
    unit = str(b_unit)[3:]
    if hasattr(b_unit, 'costing'):
        print(f'____________{unit}____________')
        py_vals =  []
        excel_vals = []
        big_dict[unit] = {'python': {}, 'excel': {}}
        df = pd.read_csv("data/case_study_results.csv")
        df = df[df.case_study == train['case_study']]
        df = df[df.scenario == train['scenario']]
        df = df[df.unit_process == unit]
        flow_in_excel = round(df[df.variable == "flow_vol_in"].value.sum(), 5)
        flow_out_excel = round(df[df.variable == 'flow_vol_out'].value.sum(), 5)
        flow_in_python = round(value(b_unit.inlet.flow_vol[0.0] * 3600), 5)
        flow_out_python = round(value(b_unit.outlet.flow_vol[0.0] * 3600), 5)
        waste_python = round(value(b_unit.waste.flow_vol[0.0] * 3600), 5)
        print(f'\n#### flow_in\nPython --> {flow_in_python}')
        print(f'Excel --> {flow_in_excel}\n\n')
        print(f'#### flow out\nPython --> {flow_out_python}')
        print(f'Excel --> {flow_out_excel}\n\n')
        print(f'#### waste\nPython--> {waste_python}\n')
        for py, ex in dict(zip(py_var, excel_var)).items():
            print(f'\n#### {py}')
            try:
                num = value(getattr(b_unit.costing, py))
                py_vals.append(num)
                print(f'Python --> {round(num, 5)}')
            except ZeroDivisionError:
                print(f'Python --> {0} - ERROR')
                py_vals.append(0)
            
            df = pd.read_csv("data/case_study_results.csv")
            df = df[df.case_study == train['case_study']]
            df = df[df.scenario == train['scenario']]
            df = df[df.unit_process == unit]
            num = df[df.Variable == ex].value.sum()
            print(f'Excel --> {round(num, 5)}\n\n')
            excel_vals.append(num)
        py_vals.append(flow_in_python)
        py_vals.append(flow_out_python)
        py_dict = dict(zip(py_var, py_vals))
        excel_vals.append(flow_in_excel)
        excel_vals.append(flow_out_excel)
        excel_dict = dict(zip(py_var, excel_vals))
        big_dict[unit]['python'] = py_dict
        big_dict[unit]['excel'] = excel_dict
        
else:
    pass 

df = pd.DataFrame.from_dict({(i,j): big_dict[i][j] 
                           for i in big_dict.keys() 
                           for j in big_dict[i].keys()},
                           orient='index')

df['case_study'] = case_study
df['LCOW'] = value(m.fs.costing.LCOW)
df.to_csv(f'results/test_compare_{case_study}_new2.csv')

# %%
# value(m.fs.costing.LCOW)

# %%
value(m.fs.coag_and_floc.water_recovery[0])

# %%
df.to_csv(f'results/test_compare_{case_study}_new1.csv')

# %%
# df_final = pd.DataFrame()
# for case_name in ["Ashkelon", "Carlsbad", "Tampa_Bay"]: #, "Santa_Barbra"]: #, "Ashkelon"]:

#     m = wt.watertap_setup(dynamic = False)

#     wt.case_study_trains.train = {"case_study": case_name,
#                                  "reference": "NAWI",
#                                  "scenario": "Baseline"}

#     # TODO LATER: how to make this sync with info in train input data. We might not need to do that.
#     #But, if the source water type is different to what is in the train (pfd dictionary), 
#     #then we should updat the node name. If more than two sources - what to do? Needs to be
#     #based on pfd node!?

#     wt.case_study_trains.source_water = {"case_study": case_name, 
#                                  "reference": "NAWI",
#                                  "scenario": "Baseline",
#                                  "water_type": "Seawater"}
    
#     m = wt.case_study_trains.get_case_study(m = m) # flow is set as case study flow unless defined.
    
      
#     wt.run_water_tap(m = m, solver_results = False, print_model_results = False)
#     print(value(m.fs.costing.LCOW))
#     df = get_results_table()
#     df["case_study"] = case_name
#     df_final = pd.concat([df_final,df])

# %%
def get_results_table():

    train = wt.case_study_trains.train

    py_var = [
        "fixed_cap_inv",
        "total_cap_investment",
        "cat_and_chem_cost",
        "electricity_cost",
        "total_fixed_op_cost"]

    excel_var = ['Fixed Capital Investment (FCI)',
                'Total Capital Investment (TCI)',
                'Catalysts and Chemicals',
                'Electricity',
                'Total Fixed Operating Costs']
    big_dict = {}
    # for letter in ['A', 'B', 'C']:
    for b_unit in m.fs.component_objects(Block, descend_into=True):
        unit = str(b_unit)[3:]
        if hasattr(b_unit, 'costing'):
            #print(f'____________{unit}____________')
            py_vals =  []
            excel_vals = []
            big_dict[unit] = {'python': {}, 'excel': {}}
            for py, ex in dict(zip(py_var, excel_var)).items():
                #print(f'\n#### {py}')
                try:
                    num = value(getattr(b_unit.costing, py))
                    py_vals.append(num)
                    #print(f'Python --> {num}')
                except ZeroDivisionError:
                    #print(f'Python --> {0} - ERROR')
                    py_vals.append(0)
                py_dict = dict(zip(py_var, py_vals))
                df = pd.read_csv("data/case_study_results.csv")
                df = df[df.case_study == train['case_study']]
                df = df[df.scenario == train['scenario']]
                df = df[df.unit_process == unit]
                num = df[df.Variable == ex].value.max()
                #print(f'Excel --> {num}\n\n')
                excel_vals.append(num)
                excel_dict = dict(zip(py_var, excel_vals))
            big_dict[unit]['python'] = py_dict
            big_dict[unit]['excel'] = excel_dict
    else:
        pass 



    df = pd.DataFrame.from_dict({(i,j): big_dict[i][j] 
                               for i in big_dict.keys() 
                               for j in big_dict[i].keys()},
                           orient='index')
    
    return df

# %%
get_results_table()

# %%
train = case_study_trains.train 
source_water = case_study_trains.source_water 
source_or_use = None
# getting the list of consituents with removal factors that are bigger than 0
df1 = pd.read_csv("data/constituent_removal.csv")
df1 = df1[df1.reference == train["reference"]]
df1 = df1[df1.case_study == train["case_study"]]
df1 = df1[df1.scenario == train["scenario"]]

list1 = df1[df1.value >=0].constituent.unique()

import importfile

# grabs inlet water information
# df = importfile.feedwater(
#     input_file="data/case_study_water_sources.csv",
#     reference = source_water["reference"], 
#     water_type = source_water["water_type"], 
#     case_study = source_water["case_study"],
#     scenario = source_water["scenario"])

df2 = pd.read_csv('data/case_study_water_sources.csv', index_col='variable')
df2 = df2[df2.reference == source_water['reference']]
df2 = df2[df2.water_type == source_water['water_type']]
df2 = df2[df2.case_study == source_water['case_study']]
# df = df[df.source_or_use == source_water['source_or_use']]
df2 = df2[df2.scenario == source_water['scenario']]
df2 = df2.set_index(df2.index)
df2['feedwater'] = df2.value
df2['SourceNodeName'] = 'source_node'
# gets list of consituents in inlet water
list2 = df2.index

# # combines list
final_list = [x for x in list1 if x in list2]
print(f'list1 = {list1}')
print(f'list2 = {list2}')
print(f'final_list = {final_list}')

# %%
df1

# %%
df2

# %%
import case_study_trains
unit_process = 'ro_deep'
train = case_study_trains.train 
source_water = case_study_trains.source_water 

df = pd.read_csv("data/constituent_removal.csv")
df.case_study = np.where(df.case_study == "Default", train["case_study"], df.case_study)
df = df[df.reference == train["reference"]]
df = df[df.case_study == train["case_study"]]
df = df[df.scenario == train["scenario"]]
df = df[df.unit_process == unit_process]

removal_dict = {}
for constituent in df.constituent.unique():
    removal_dict[constituent] = df[df.constituent == constituent].value.max()

# %%
df

# %%
removal_dict

# %%
import generate_constituent_list
df = pd.read_csv("data/water_recovery.csv")
case_study_name = case_study_trains.train["case_study"]
unit_process_type = 'microfiltration'
unit_process_name = unit_process_type
if unit_process_type == "reverse_osmosis": unit_process_type = "ro_deep"

if case_study_name in df[df.unit_process == unit_process_type].case_study:
    if "calculated" not in df[((df.unit_process == unit_process_type) & (df.case_study == case_study_name))].recovery.max():
        flow_recovery_factor = float(df[((df.unit_process == unit_process_type) & (df.case_study == case_study_name))].recovery)
        print(f'A = {flow_recovery_factor}\n')
        getattr(m.fs, unit_process_name).water_recovery.fix(flow_recovery_factor)
else:
    if "calculated" not in df[((df.unit_process == unit_process_type) & (df.case_study == "Default"))].recovery.max():
        flow_recovery_factor = float(df[((df.unit_process == unit_process_type) & (df.case_study == "Default"))].recovery)
        print(f'B = {flow_recovery_factor}\n')
        getattr(m.fs, unit_process_name).water_recovery.fix(flow_recovery_factor)

# Get constituent list and removal rates for this unit process
train_constituent_removal_factors = generate_constituent_list.get_removal_factors(unit_process_type)

for constituent_name in getattr(m.fs, unit_process_name).config.property_package.component_list:
    print(constituent_name)

    if constituent_name in train_constituent_removal_factors.keys():
        getattr(m.fs, unit_process_name).removal_fraction[:, constituent_name].fix(train_constituent_removal_factors[constituent_name])
    else:
        getattr(m.fs, unit_process_name).removal_fraction[:, constituent_name].fix(0)

# %%
value(m.fs.microfiltration.water_recovery[0])

# %%
train_constituent_removal_factors

# %%
m.fs.microfiltration.display()

# %%
df[df.unit_process == unit_process_type]

# %%
df

# %%
cost_range_list = []; #results will be inputted in this array
#up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.

#for value_change in pct_to_target1: # cycles through each value from MC range
for value_change in [0.4, 0.8]: #, 0.9]:

    # create and build model
    m = wt.watertap_setup(dynamic = False)
    m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

    m.fs.tri_media_filtration.water_recovery.fix(value_change)

    # set variable to MC value
    wt.run_water_tap(m)
    results_table = get_results_table(m, unit_process_name)
    cost_range_list.append(results_table.total_up_cost.sum())

# %%
cost_range_list

# %%
#### DO NOT USE THE BELOW ####

# %%
import time
from multiprocessing import Pool
import multiprocessing

mu = 0.6
sigma = .1
num_reps = 50

input_list = np.random.normal(mu,sigma, size = num_reps) #, sigma, num_reps).round(4)

count, bins, ignored = plt.hist(input_list, 25, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
          linewidth=2, color='r')
plt.show()

### INPUT TO MODEL LIST: ### CAN BE AUTOMATED FOR USER TO LABEL THE VARIABLE. TOOD ###
no_of_proc = 4
list_final = []
for i in range(no_of_proc):
    part2 = len(input_list) / no_of_proc
    i2 = ((i+1)*part2)
    list1 = input_list[int(i*part2):int(i2)]
    list_final.append(list1)
    
    
def monte_run(list_final):
    print('goes in')

    up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.
    cost_range_list = []; #results will be inputted in this array

    #for value_change in pct_to_target1: # cycles through each value from MC range
    for value_change in list_final:

        # create and build model
        m = wt.watertap_setup(dynamic = False)
        m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

        getattr(m.fs, up_name).water_recovery.fix(value_change)

        # set variable to MC value
        result = wt.run_water_tap(m)
        results_table = get_results_table(m, unit_process_names)
        cost_range_list.append(results_table.total_up_cost.sum())


    return cost_range_list

startTime = time.time()

pool=Pool()
dfs = pool.map(monte_run, list_final) #SomeClass().preprocess_data()

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)
