# %%
# %matplotlib inline
from pylab import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import write_dot, graphviz_layout
from pyomo.environ import ConcreteModel, SolverFactory, TerminationCondition, \
    value, Var, Constraint, Expression, Objective, TransformationFactory, units as pyunits
from pyomo.network import Arc, SequentialDecomposition
from idaes.core.util.model_statistics import degrees_of_freedom

# %% [markdown]
# ### TODO: CREATE INTRO

# %% [markdown]
# ##### Import WaterTAP3 Package

# %%
import watertap as wt

# %% [markdown]
# ##### Step 1: Look up unit process library. Returns a List.

# %%
wt.unit_process_library_list
# Out:
# ['chlorination_twb',
#  'media_filtration_twb',
#  'microfiltration_twb',
#  'ultrafiltration_twb',
#  'nanofiltration_twb',
#  'coag_and_flocro_twb',
#  'uv_twb',
#  'ro_bor',
#  'uvozone_twb',
#  'mbr',
#  'water_pumping_station',
#  'ro_deep',
#  'media_filtration',
#  'coag_and_floc',
#  'lime_softening',
#  'ro_deep',
#  'treated_storage_24_hr',
#  'sedimentation',
#  'water_pumping_station',
#  'sulfuric_acid_addition',
#  'sodium_bisulfite_addition',
#  'co2_addition',
#  'ammonia_addition',
#  'municipal_drinking',
#  'sw_onshore_intake',
#  'holding_tank',
#  'tri_media_filtration',
#  'cartridge_filtration']

# %% [markdown]
# ##### Step 2: Look up source and end use source water options. Returns a Pandas dataframe.

# %%
# source node name, feedwater column not used. TODO.
wt.water_source_use_library.head()
# Out:
#          Variable  Unit  Value Reference   WaterType  \
# Variable
# Turb         Turb   NTU  100.0  Poseidon  Wastewater
# TSS           TSS  mg/L  210.0  Poseidon  Wastewater
# BOD           BOD  mg/L  190.0  Poseidon  Wastewater
# COD           COD  mg/L  430.0  Poseidon  Wastewater
# TN             TN  mg/L   40.0  Poseidon  Wastewater
#
#                                       CaseStudy SourceOrUse  feedwater  \
# Variable
# Turb      Typical untreated domestic wastewater      Source      100.0
# TSS       Typical untreated domestic wastewater      Source      210.0
# BOD       Typical untreated domestic wastewater      Source      190.0
# COD       Typical untreated domestic wastewater      Source      430.0
# TN        Typical untreated domestic wastewater      Source       40.0
#
#          SourceNodeName
# Variable
# Turb        source_node
# TSS         source_node
# BOD         source_node
# COD         source_node
# TN          source_node

# %% [markdown]
# ##### Step 3: Set up IDAES flowsheet for watertap. This selects a property package for you (see water_props.py). The property package could be changed in the future for performing heat/energy and other balances.

# %%
m = wt.watertap_setup(dynamic = False)

# %% [markdown]
# ##### Step 3: Add a water source and define inlet flow.

# %%
m = wt.design.add_water_source(m = m, source_name = "source1", link_to = None, 
                     reference = "Poseidon", water_type = "Wastewater", 
                     case_study = "Typical untreated domestic wastewater",
                               flow = 4.5833) # m3/s (4.38 m3/s = 16500 m3/h = 104.6121 MGD = 4.5833 m3/s)

# %% [markdown]
# ##### Step 4: Add unit processes. You can also add a unit process a link it directly to another unit process or source.

# %% [raw]
# # pseudo code for below
# for process in processes_i_care_about:
#     m = wt....(m = m, unit_process_name = process.name, unit_process_type = process.type)

# %%
m = wt.design.add_unit_process(m = m, unit_process_name = "swoi", unit_process_type = 'sw_onshore_intake')
m = wt.design.add_unit_process(m = m, unit_process_name = "coag_floc", unit_process_type = 'coag_and_floc')
m = wt.design.add_unit_process(m = m, unit_process_name = "tri_media_filtration", unit_process_type = 'tri_media_filtration')
m = wt.design.add_unit_process(m = m, unit_process_name = "SAA", unit_process_type = 'sulfuric_acid_addition')
m = wt.design.add_unit_process(m = m, unit_process_name = "SBA", unit_process_type = 'sodium_bisulfite_addition')
m = wt.design.add_unit_process(m = m, unit_process_name = "cf", unit_process_type = 'cartridge_filtration')
m = wt.design.add_unit_process(m = m, unit_process_name = "ro", unit_process_type = 'ro_deep')
m = wt.design.add_unit_process(m = m, unit_process_name = "lime", unit_process_type = 'lime_softening')
m = wt.design.add_unit_process(m = m, unit_process_name = "co2", unit_process_type = 'co2_addition')
m = wt.design.add_unit_process(m = m, unit_process_name = "chlor", unit_process_type = 'chlorination_twb')
m = wt.design.add_unit_process(m = m, unit_process_name = "ammonia", unit_process_type = 'ammonia_addition')
m = wt.design.add_unit_process(m = m, unit_process_name = "TWS_24_hr", unit_process_type = 'treated_storage_24_hr')
m = wt.design.add_unit_process(m = m, unit_process_name = "muni", unit_process_type = 'municipal_drinking')
# Out:
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)
# /Users/amiara/NAWI/WaterTap/IDAES-WaterTAP3_v2/ml_regression.py:149: RuntimeWarning: divide by zero encountered in power
#   return a*np.power(x, b)

# %% [markdown]
# ##### Step X: Connect the unit process to the source.

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc1",
                    from_node = "source1",
                    to_node = "swoi")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc2",
                    from_node = "swoi",
                    to_node = "coag_floc")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc3",
                    from_node = "coag_floc",
                    to_node = "tri_media_filtration")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc4",
                    from_node = "tri_media_filtration",
                    to_node = "SAA")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc5",
                    from_node = "SAA",
                    to_node = "SBA")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc6",
                    from_node = "SBA",
                    to_node = "cf")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc7",
                    from_node = "cf",
                    to_node = "ro")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc8",
                    from_node = "ro",
                    to_node = "lime")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc9",
                    from_node = "lime",
                    to_node = "co2")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc10",
                    from_node = "co2",
                    to_node = "chlor")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc11",
                    from_node = "chlor",
                    to_node = "ammonia")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc12",
                    from_node = "ammonia",
                    to_node = "TWS_24_hr")

# %%
m = wt.design.connect_blocks(m = m, 
                    stream_name = "arc13",
                    from_node = "TWS_24_hr",
                    to_node = "muni")

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##### Step 5: Add a splitter node if you want to split one stream into multiple streams. The outlet list defines the names of the outlets. The split fraction also needs to be provided, otherwise 0.5 will be chosen, unless using optimization in which case you need to unfix the fraction by setting unfix = True. The outlets will not show in the display until conntected to another node by an arc.

# %% [markdown]
# ##### Step 5:  Run model and display results. The resutls display will be put into easier format to read for user soon.

# %%
# Set up a solver in Pyomo and solve
solver1 = SolverFactory('ipopt')
results = solver1.solve(m, tee=True)

# Transform Arc to construct linking equations
TransformationFactory("network.expand_arcs").apply_to(m)
seq = SequentialDecomposition()
G = seq.create_graph(m)
print("degrees_of_freedom:", degrees_of_freedom(m))

# Display the inlets and outlets of each unit
for node in G.nodes():
    print("----------------------------------------------------------------------")
    print(node)
    
    if "split" in (str(node).replace('fs.', '')): 
        getattr(m.fs, str(node).replace('fs.', '')).inlet.display()
        getattr(m.fs, str(node).replace('fs.', '')).outlet1.display()
        getattr(m.fs, str(node).replace('fs.', '')).outlet2.display()
    elif "use" in (str(node).replace('fs.', '')): 
        getattr(m.fs, str(node).replace('fs.', '')).inlet.display()
        getattr(m.fs, str(node).replace('fs.', '')).outlet.display()
    elif "mixer" in (str(node).replace('fs.', '')): 
        getattr(m.fs, str(node).replace('fs.', '')).inlet1.display()
        getattr(m.fs, str(node).replace('fs.', '')).inlet2.display()
        getattr(m.fs, str(node).replace('fs.', '')).outlet.display()
    else:
        getattr(m.fs, str(node).replace('fs.', '')).inlet.display()
        getattr(m.fs, str(node).replace('fs.', '')).outlet.display()
        getattr(m.fs, str(node).replace('fs.', '')).waste.display()

        
    print("Show some costing values")
    print("---------------------")
    
    if "source" in (str(node).replace('fs.', '')): 
        print("should skip:", (str(node).replace('fs.', '')))
        continue
    elif "use" in (str(node).replace('fs.', '')): 
        print("should skip:", (str(node).replace('fs.', '')))
        continue
    elif "split" in (str(node).replace('fs.', '')): 
        print("should skip:", (str(node).replace('fs.', '')))
        continue  
    elif "mixer" in (str(node).replace('fs.', '')): 
        print("should skip:", (str(node).replace('fs.', '')))
        continue
    else:
        print("should have a cost", (str(node).replace('fs.', '')))
        if getattr(m.fs, str(node).replace('fs.', '')).costing.total_up_cost() is not None:
            print("total_up_cost:" , 
                  getattr(m.fs, str(node).replace('fs.', '')).costing.total_up_cost())
                
        else:
            getattr(m.fs, str(node).replace('fs.', '')).costing.total_up_cost.display()
    
    print("----------------------------------------------------------------------")
 # fixed_cap_inv_unadjusted
# total_up_cost
# Out:
# Ipopt 3.12.13:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      666
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      123
#
# Total number of variables............................:      246
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      246
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.18e+04 0.00e+00  -1.0 1.00e+05    -  1.00e+00 1.00e+00h  1
#    2  0.0000000e+00 7.95e+03 2.66e+09  -1.0 6.98e+04  -4.0 1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 4.13e+02 1.80e+04  -1.0 1.47e+03    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 4.46e-01 4.96e+07  -1.0 3.56e+00   5.8 1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 4.42e-01 4.92e+07  -1.0 3.79e+04    -  1.00e+00 7.81e-03h  8
#    6  0.0000000e+00 4.39e-01 4.89e+07  -1.0 3.82e+04    -  1.00e+00 7.81e-03h  8
#    7  0.0000000e+00 4.35e-01 4.85e+07  -1.0 3.85e+04    -  1.00e+00 7.81e-03h  8
#    8  0.0000000e+00 4.32e-01 4.81e+07  -1.0 3.88e+04    -  1.00e+00 7.81e-03h  8
#    9  0.0000000e+00 4.29e-01 4.77e+07  -1.0 3.91e+04    -  1.00e+00 7.81e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 4.25e-01 4.74e+07  -1.0 3.94e+04    -  1.00e+00 7.81e-03h  8
#   11  0.0000000e+00 4.22e-01 4.70e+07  -1.0 3.97e+04    -  1.00e+00 7.81e-03h  8
#   12  0.0000000e+00 4.19e-01 4.66e+07  -1.0 4.00e+04    -  1.00e+00 7.81e-03h  8
#   13  0.0000000e+00 4.15e-01 4.62e+07  -1.0 4.03e+04    -  1.00e+00 7.81e-03h  8
#   14  0.0000000e+00 4.12e-01 4.59e+07  -1.0 4.06e+04    -  1.00e+00 7.81e-03h  8
#   15  0.0000000e+00 2.86e+02 2.08e+07  -1.0 4.10e+04    -  1.00e+00 1.00e+00w  1
#   16  0.0000000e+00 1.59e-01 1.10e+06  -1.0 1.35e+00   5.4 1.00e+00 1.00e+00h  1
#   17  0.0000000e+00 1.59e-01 1.10e+06  -1.0 8.30e+04    -  1.00e+00 1.95e-03h 10
#   18  0.0000000e+00 1.58e-01 1.10e+06  -1.0 8.31e+04    -  1.00e+00 1.95e-03h 10
#   19  0.0000000e+00 1.58e-01 1.10e+06  -1.0 8.33e+04    -  1.00e+00 1.95e-03h 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  0.0000000e+00 1
-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  0.0000000e+00 1.22e+02 3.18e+10  -1.7 1.43e+06    -  1.00e+00 1.00e+00w  1
#   91  0.0000000e+00 7.81e-04 2.31e+08  -1.7 3.10e-04  11.9 1.00e+00 1.00e+00h  1
#   92r 0.0000000e+00 7.81e-04 9.75e+02  -1.7 0.00e+00    -  0.00e+00 4.77e-07R 22
#   93r 0.0000000e+00 3.11e-04 9.11e+02  -1.7 1.40e+01    -  1.00e+00 2.58e-02f  1
#   94r 0.0000000e+00 2.80e-04 1.57e+00  -1.7 1.24e+00    -  1.00e+00 1.00e+00f  1
#   95r 0.0000000e+00 1.57e-04 1.99e-04  -1.7 3.54e-02    -  1.00e+00 1.00e+00f  1
#   96r 0.0000000e+00 1.57e-04 4.52e+01  -3.8 2.04e-01    -  1.00e+00 8.36e-01f  1
#   97r 0.0000000e+00 1.54e-04 1.60e-01  -3.8 1.86e+01    -  1.00e+00 1.00e+00f  1
#   98r 0.0000000e+00 1.53e-04 2.00e-04  -3.8 1.17e-02    -  1.00e+00 1.00e+00h  1
#   99r 0.0000000e+00 1.54e-04 2.11e-04  -5.7 5.68e-02    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100r 0.0000000e+00 4.21e-03 1.27e+01  -5.7 1.22e+02    -  1.00e+00 1.00e+00f  1
#  101r 0.0000000e+00 1.82e-04 3.55e-02  -5.7 4.91e+00    -  1.00e+00 1.00e+00h  1
#  102r 0.0000000e+00 1.82e-04 1.99e-08  -5.7 6.67e-04    -  1.00e+00 1.00e+00h  1
#  103r 0.0000000e+00 2.18e-04 1.81e-02  -8.6 9.99e-03    -  8.35e-01 1.00e+00f  1
#  104r 0.0000000e+00 5.78e-02 1.75e+02  -8.6 1.53e+03    -  1.00e+00 1.00e+00f  1
#  105r 0.0000000e+00 5.97e-03 1.81e+01  -8.6 4.95e+02    -  1.00e+00 1.00e+00h  1
#  106r 0.0000000e+00 1.47e-04 7.96e-02  -8.6 2.47e+01    -  1.00e+00 1.00e+00h  1
#  107r 0.0000000e+00 1.47e-04 1.43e-06  -8.6 6.13e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 107
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   5.5282603433819748e-05    5.5282603433819748e-05
# Constraint violation....:   1.4734803646110350e-04    1.4734803646110350e-04
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.4734803646110350e-04    1.4734803646110350e-04
#
#
# Number of objective function evaluations             = 1288
# Number of objective gradient evaluations             = 94
# Number of equality constraint evaluations            = 1289
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 110
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 108
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.577
# Total CPU secs in NLP function evaluations           =      0.019
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
#     model=unknown;
#         message from solver=Ipopt 3.12.13\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 720.0, (0.0, 'TOC'): 140.0, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.928039292477, (0.0, 'TOC'): 139.98600764020387, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.583299749851096}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 2235.7835848963105, (0.0, 'TOC'): 434.7356970631611, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 0.00014759818536520054}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.swoi
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.928039292477, (0.0, 'TOC'): 139.98600764020387, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.583299749851096}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352386448635, (0.0, 'TOC'): 139.987407514279, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5832539168535975}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 9.619384866821538e-20, (0.0, 'TOC'): 1.3521983443437433e-14, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.583299749855702e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost swoi
# total_up_cost: 23.366025664859194
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9352386448635, (0.0, 'TOC'): 139.987407514279, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5832539168535975}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 719.9450638591209, (0.0, 'TOC'): 76.99412488493375, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 4.5831913683981815}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 4.578410836698673e-13, (0.0, 'TOC'): 3638932.6474560383, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0:
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.87827614116566, (0.0, 'TOC'): 162.50348479372087, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1715153311200575}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88207496191524, (0.0, 'TOC'): 162.50510984481932, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1714936159667464}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.378577371580984e-19, (0.0, 'TOC'): 1.378650694474179e-19, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1715153311063776e-05}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost chlor
# total_up_cost: 10.021529403678441
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88207496191524, (0.0, 'TOC'): 162.50510984481932, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1714936159667464}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88587382065344, (0.0, 'TOC'): 162.5067349121684, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.171471901030587}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 9.846687597165384e-20, (0.0, 'TOC'): 9.846781933824918e-20, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1714936159433765e-05}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost ammonia
# total_up_cost: 0.8333764475747829
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.TWS_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88587382065344, (0.0, 'TOC'): 162.5067349121684, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.171471901030587}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88967271738056, (0.0, 'TOC'): 162.50835999576836, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.171450186311577}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 5.909688130460126e-20, (0.0, 'TOC'): 5.909015120960375e-20, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.17147190100242e-05}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost TWS_24_hr
# total_up_cost: 12.463139629982951
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.muni
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.88967271738056, (0.0, 'TOC'): 162.50835999576836, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.171450186311577}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 379.893471652097, (0.0, 'TOC'): 162.5099850956193, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.171428471809714}
#          :    pressure : {0.0: 199999.9986}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'TDS'): 1.972193782281673e-20, (0.0, 'TOC'): 1.9711279462452724e-20, (0.0, 'nitrates'): 0.0}
#          :    flow_vol : {0.0: 2.1714501862835082e-05}
#          :    pressure : {0.0: 199999.9986}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost muni
# total_up_cost: 4.3971705502502285
# ----------------------------------------------------------------------

# %%
m.fs.ammonia.costing.catalysts_chemicals
# Out:
# 1.4497931099098118

# %%
m.fs.chlor.costing.applied_cl2_dose
# Out:
# 9.5

# %%
unit_process_name = [
    "swoi", 
    "coag_floc",
    "tri_media_filtration",
    "SAA",
    "SBA",
    "cf",
    "ro",
    "lime",
    "co2",
    "chlor",
    "ammonia",
    "TWS_24_hr",
    "muni"
]


cost_variables = [
    "total_up_cost",
    "fixed_cap_inv_unadjusted",
    "fixed_cap_inv",
    "total_fixed_op_cost",
    "total_cap_investment",
    "land_cost",
    "working_cap",
    "catalysts_chemicals",#
    "electricity",##
    "cap_replacement_parts", #
    "salaries",
    "benefits",
    "maintenance",
    "lab",
    "insurance_taxes",
    "base_employee_salary_cost",
    
    "cat_and_chem_cost",##
    "labor_and_other_fixed",#
    "consumer_price_index",#
    
    "electricity_cost", ##
    "other_var_cost"   ## 
]

# %%
import pandas as pd
import numpy

def get_results_table(model, unit_process_name):
    data = {} 

    for variable in cost_variables:
        cost_list = []
        for node in unit_process_name:
            # call m.fs.'node'.costing.'variable'() for each node and variable
            costing_attr = getattr(m.fs, node).costing
            cost_method = getattr(costing_attr, variable) #m.fs.swoi.costing.total_up_cost
            
            if type(cost_method) == int:
                cost_method = np.float64(cost_method)
                
            if type(cost_method) == np.float64:
                cost_value = cost_method
            else:
                cost_value = cost_method()
            # append ^ to a list
            cost_list.append(cost_value)
        # assign 'variable': List['node' values] in a data dictionary
        data[variable] = cost_list


    df = pd.DataFrame(data = data, index = unit_process_name, columns = cost_variables)
    print(df)
    return df

# %%
get_results_table(m,unit_process_name)
# Out:
#                       total_up_cost  fixed_cap_inv_unadjusted  fixed_cap_inv  \
# swoi                      23.366026                 20.308783      20.980305
# coag_floc                 13.104165                 11.765745      11.765745
# tri_media_filtration      13.426630                 11.080272      12.026418
# SAA                        0.390702                  0.295020       0.351112
# SBA                        0.438049                  0.330773       0.393662
# cf                        12.580562                 10.416512      11.305979
# ro                       913.272581                213.839658     254.496571
# lime                      53.796621                 49.187757      49.187757
# co2                        7.925649                  7.130754       7.246728
# chlor                     10.021529                  8.429884       9.149713
# ammonia                    0.833376                  0.639317       0.760869
# TWS_24_hr                 12.463140                  9.136112      11.434646
# muni                       4.397171                  4.020460       4.020460
#
#                       total_fixed_op_cost  total_cap_investment  land_cost  \
# swoi                             1.305235             22.060790   0.031470
# coag_floc                        0.732484             12.371681   0.017649
# tri_media_filtration             0.780851             12.645779   0.018040
# SAA                              0.021507              0.369194   0.000527
# SBA                              0.024114              0.413936   0.000590
# cf                               0.692325             11.888237   0.016959
# ro                              15.589030            267.603145   0.381745
# lime                             2.075695             51.720927   0.073782
# co2                              0.305715              7.619935   0.010870
# chlor                            0.400606              9.620923   0.013725
# ammonia                          0.033323              0.800054   0.001141
# TWS_24_hr                        0.439609             12.023530   0.017152
# muni                             0.169657              4.227514   0.006031
#
#                       working_cap  catalysts_chemicals  electricity  \
# swoi                     1.049015             1.045314          0.0
# coag_floc                0.588287             1.000000          0.0
# tri_media_filtration     0.601321             1.094885          0.0
# SAA                      0.017556             1.449793          0.0
# SBA                      0.019683             1.449793          0.0
# cf                       0.565299             1.094885          0.0
# ro                      12.724829             1.449793          0.0
# lime                     2.459388             1.000000          0.0
# co2                      0.362336             1.022155          0.0
# chlor                    0.457486             1.094885          0.0
# ammonia                  0.038043             1.449793          0.0
# TWS_24_hr                0.571732             1.497678          0.0
# muni                     0.201023             1.000000          0.0
#
#                       cap_replacement_parts  ...  benefits  maintenance  \
# swoi                               1.033066  ...  0.489075     0.167842
# coag_floc                          1.000000  ...  0.274514     0.094126
# tri_media_filtration               1.085390  ...  0.295819     0.096211
# SAA                                1.190128  ...  0.008026     0.002809
# SBA                                1.190128  ...  0.008998     0.003149
# cf                                 1.085390  ...  0.258323     0.090448
# ro                                 1.190128  ...  5.817114     2.035973
# lime                               1.000000  ...  0.680331     0.393502
# co2                                1.016264  ...  0.100188     0.057974
# chlor                              1.085390  ...  0.133418     0.073198
# ammonia                            1.190128  ...  0.011099     0.006087
# TWS_24_hr                          1.251588  ...  0.159407     0.045910
# muni                               1.000000  ...  0.055606     0.032164
#
#                            lab  insurance_taxes  base_employee_salary_cost  \
# swoi                  0.062941         0.041961                   0.020309
# coag_floc             0.035297         0.023531                   0.011766
# tri_media_filtration  0.036079         0.024053                   0.011080
# SAA                   0.001053         0.000702                   0.000295
# SBA                   0.001181         0.000787                   0.000331
# cf                    0.033918         0.022612                   0.010417
# ro                    0.763490         0.508993                   0.213840
# lime                  0.147563         0.098376                   0.049188
# co2                   0.021740         0.014493                   0.007131
# chlor                 0.027449         0.018299                   0.008430
# ammonia               0.002283         0.001522                   0.000639
# TWS_24_hr             0.034304         0.022869                   0.009182
# muni                  0.012061         0.008041                   0.004020
#
#                       cat_and_chem_cost  labor_and_other_fixed  \
# swoi                                0.0               1.032158
# coag_floc                           0.0               1.000000
# tri_media_filtration                0.0               1.144289
# SAA                                 0.0               1.255215
# SBA                                 0.0               1.255215
# cf                                  0.0               1.144289
# ro                                  0.0               1.255215
# lime                                0.0               1.000000
# co2                                 0.0               1.015824
# chlor                               0.0               1.144289
# ammonia                             0.0               1.255215
# TWS_24_hr                           0.0               1.255215
# muni                                0.0               1.000000
#
#                       consumer_price_index  electricity_cost  other_var_cost
# swoi                              1.034582               0.0            -0.0
# coag_floc                         1.000000               0.0            -0.0
# tri_media_filtration              1.104141               0.0            -0.0
# SAA                               1.260734               0.0            -0.0
# SBA                               1.260734               0.0            -0.0
# cf                                1.104141               0.0            -0.0
# ro                                1.260734               0.0            -0.0
# lime                              1.000000               0.0            -0.0
# co2                               1.016997               0.0            -0.0
# chlor                             1.104141               0.0            -0.0
# ammonia                           1.260734               0.0            -0.0
# TWS_24_hr                         1.296380               0.0            -0.0
# muni                              1.000000               0.0            -0.0
#
# [13 rows x 21 columns]
#                       total_up_cost  fixed_cap_inv_unadjusted  fixed_cap_inv  \
# swoi                      23.366026                 20.308783      20.980305
# coag_floc                 13.104165                 11.765745      11.765745
# tri_media_filtration      13.426630                 11.080272      12.026418
# SAA                        0.390702                  0.295020       0.351112
# SBA                        0.438049                  0.330773       0.393662
# cf                        12.580562                 10.416512      11.305979
# ro                       913.272581                213.839658     254.496571
# lime                      53.796621                 49.187757      49.187757
# co2                        7.925649                  7.130754       7.246728
# chlor                     10.021529                  8.429884       9.149713
# ammonia                    0.833376                  0.639317       0.760869
# TWS_24_hr                 12.463140                  9.136112      11.434646
# muni                       4.397171                  4.020460       4.020460
#
#                       total_fixed_op_cost  total_cap_investment  land_cost  \
# swoi                             1.305235             22.060790   0.031470
# coag_floc                        0.732484             12.371681   0.017649
# tri_media_filtration             0.780851             12.645779   0.018040
# SAA                              0.021507              0.369194   0.000527
# SBA                              0.024114              0.413936   0.000590
# cf                               0.692325             11.888237   0.016959
# ro                              15.589030            267.603145   0.381745
# lime                             2.075695             51.720927   0.073782
# co2                              0.305715              7.619935   0.010870
# chlor                            0.400606              9.620923   0.013725
# ammonia                          0.033323              0.800054   0.001141
# TWS_24_hr                        0.439609             12.023530   0.017152
# muni                             0.169657              4.227514   0.006031
#
#                       working_cap  catalysts_chemicals  electricity  \
# swoi                     1.049015             1.045314          0.0
# coag_floc                0.588287             1.000000          0.0
# tri_media_filtration     0.601321             1.094885          0.0
# SAA                      0.017556             1.449793          0.0
# SBA                      0.019683             1.449793          0.0
# cf                       0.565299             1.094885          0.0
# ro                      12.724829             1.449793          0.0
# lime                     2.459388             1.000000          0.0
# co2                      0.362336             1.022155          0.0
# chlor                    0.457486             1.094885          0.0
# ammonia                  0.038043             1.449793          0.0
# TWS_24_hr                0.571732             1.497678          0.0
# muni                     0.201023             1.000000          0.0
#
#                       cap_replacement_parts  ...  benefits  maintenance  \
# swoi                               1.033066  ...  0.489075     0.167842
# coag_floc                          1.000000  ...  0.274514     0.094126
# tri_media_filtration               1.085390  ...  0.295819     0.096211
# SAA                                1.190128  ...  0.008026     0.002809
# SBA                                1.190128  ...  0.008998     0.003149
# cf                                 1.085390  ...  0.258323     0.090448
# ro                                 1.190128  ...  5.817114     2.035973
# lime                               1.000000  ...  0.680331     0.393502
# co2                                1.016264  ...  0.100188     0.057974
# chlor                              1.085390  ...  0.133418     0.073198
# ammonia                            1.190128  ...  0.011099     0.006087
# TWS_24_hr                          1.251588  ...  0.159407     0.045910
# muni                               1.000000  ...  0.055606     0.032164
#
#                            lab  insurance_taxes  base_employee_salary_cost  \
# swoi                  0.062941         0.041961                   0.020309
# coag_floc             0.035297         0.023531                   0.011766
# tri_media_filtration  0.036079         0.024053                   0.011080
# SAA                   0.001053         0.000702                   0.000295
# SBA                   0.001181         0.000787                   0.000331
# cf                    0.033918         0.022612                   0.010417
# ro                    0.763490         0.508993                   0.213840
# lime                  0.147563         0.098376                   0.049188
# co2                   0.021740         0.014493                   0.007131
# chlor                 0.027449         0.018299                   0.008430
# ammonia               0.002283         0.001522                   0.000639
# TWS_24_hr             0.034304         0.022869                   0.009182
# muni                  0.012061         0.008041                   0.004020
#
#                       cat_and_chem_cost  labor_and_other_fixed  \
# swoi                                0.0               1.032158
# coag_floc                           0.0               1.000000
# tri_media_filtration                0.0               1.144289
# SAA                                 0.0               1.255215
# SBA                                 0.0               1.255215
# cf                                  0.0               1.144289
# ro                                  0.0               1.255215
# lime                                0.0               1.000000
# co2                                 0.0               1.015824
# chlor                               0.0               1.144289
# ammonia                             0.0               1.255215
# TWS_24_hr                           0.0               1.255215
# muni                                0.0               1.000000
#
#                       consumer_price_index  electricity_cost  other_var_cost
# swoi                              1.034582               0.0            -0.0
# coag_floc                         1.000000               0.0            -0.0
# tri_media_filtration              1.104141               0.0            -0.0
# SAA                               1.260734               0.0            -0.0
# SBA                               1.260734               0.0            -0.0
# cf                                1.104141               0.0            -0.0
# ro                                1.260734               0.0            -0.0
# lime                              1.000000               0.0            -0.0
# co2                               1.016997               0.0            -0.0
# chlor                             1.104141               0.0            -0.0
# ammonia                           1.260734               0.0            -0.0
# TWS_24_hr                         1.296380               0.0            -0.0
# muni                              1.000000               0.0            -0.0
#
# [13 rows x 21 columns]

# %%
x = get_results_table(m,unit_process_name)
x.to_csv('cost_results.csv', index = True)
# Out:
#                       total_up_cost  fixed_cap_inv_unadjusted  fixed_cap_inv  \
# swoi                      23.366026                 20.308783      20.980305
# coag_floc                 13.104165                 11.765745      11.765745
# tri_media_filtration      13.426630                 11.080272      12.026418
# SAA                        0.390702                  0.295020       0.351112
# SBA                        0.438049                  0.330773       0.393662
# cf                        12.580562                 10.416512      11.305979
# ro                       913.272581                213.839658     254.496571
# lime                      53.796621                 49.187757      49.187757
# co2                        7.925649                  7.130754       7.246728
# chlor                     10.021529                  8.429884       9.149713
# ammonia                    0.833376                  0.639317       0.760869
# TWS_24_hr                 12.463140                  9.136112      11.434646
# muni                       4.397171                  4.020460       4.020460
#
#                       total_fixed_op_cost  total_cap_investment  land_cost  \
# swoi                             1.305235             22.060790   0.031470
# coag_floc                        0.732484             12.371681   0.017649
# tri_media_filtration             0.780851             12.645779   0.018040
# SAA                              0.021507              0.369194   0.000527
# SBA                              0.024114              0.413936   0.000590
# cf                               0.692325             11.888237   0.016959
# ro                              15.589030            267.603145   0.381745
# lime                             2.075695             51.720927   0.073782
# co2                              0.305715              7.619935   0.010870
# chlor                            0.400606              9.620923   0.013725
# ammonia                          0.033323              0.800054   0.001141
# TWS_24_hr                        0.439609             12.023530   0.017152
# muni                             0.169657              4.227514   0.006031
#
#                       working_cap  catalysts_chemicals  electricity  \
# swoi                     1.049015             1.045314          0.0
# coag_floc                0.588287             1.000000          0.0
# tri_media_filtration     0.601321             1.094885          0.0
# SAA                      0.017556             1.449793          0.0
# SBA                      0.019683             1.449793          0.0
# cf                       0.565299             1.094885          0.0
# ro                      12.724829             1.449793          0.0
# lime                     2.459388             1.000000          0.0
# co2                      0.362336             1.022155          0.0
# chlor                    0.457486             1.094885          0.0
# ammonia                  0.038043             1.449793          0.0
# TWS_24_hr                0.571732             1.497678          0.0
# muni                     0.201023             1.000000          0.0
#
#                       cap_replacement_parts  ...  benefits  maintenance  \
# swoi                               1.033066  ...  0.489075     0.167842
# coag_floc                          1.000000  ...  0.274514     0.094126
# tri_media_filtration               1.085390  ...  0.295819     0.096211
# SAA                                1.190128  ...  0.008026     0.002809
# SBA                                1.190128  ...  0.008998     0.003149
# cf                                 1.085390  ...  0.258323     0.090448
# ro                                 1.190128  ...  5.817114     2.035973
# lime                               1.000000  ...  0.680331     0.393502
# co2                                1.016264  ...  0.100188     0.057974
# chlor                              1.085390  ...  0.133418     0.073198
# ammonia                            1.190128  ...  0.011099     0.006087
# TWS_24_hr                          1.251588  ...  0.159407     0.045910
# muni                               1.000000  ...  0.055606     0.032164
#
#                            lab  insurance_taxes  base_employee_salary_cost  \
# swoi                  0.062941         0.041961                   0.020309
# coag_floc             0.035297         0.023531                   0.011766
# tri_media_filtration  0.036079         0.024053                   0.011080
# SAA                   0.001053         0.000702                   0.000295
# SBA                   0.001181         0.000787                   0.000331
# cf                    0.033918         0.022612                   0.010417
# ro                    0.763490         0.508993                   0.213840
# lime                  0.147563         0.098376                   0.049188
# co2                   0.021740         0.014493                   0.007131
# chlor                 0.027449         0.018299                   0.008430
# ammonia               0.002283         0.001522                   0.000639
# TWS_24_hr             0.034304         0.022869                   0.009182
# muni                  0.012061         0.008041                   0.004020
#
#                       cat_and_chem_cost  labor_and_other_fixed  \
# swoi                                0.0               1.032158
# coag_floc                           0.0               1.000000
# tri_media_filtration                0.0               1.144289
# SAA                                 0.0               1.255215
# SBA                                 0.0               1.255215
# cf                                  0.0               1.144289
# ro                                  0.0               1.255215
# lime                                0.0               1.000000
# co2                                 0.0               1.015824
# chlor                               0.0               1.144289
# ammonia                             0.0               1.255215
# TWS_24_hr                           0.0               1.255215
# muni                                0.0               1.000000
#
#                       consumer_price_index  electricity_cost  other_var_cost
# swoi                              1.034582               0.0            -0.0
# coag_floc                         1.000000               0.0            -0.0
# tri_media_filtration              1.104141               0.0            -0.0
# SAA                               1.260734               0.0            -0.0
# SBA                               1.260734               0.0            -0.0
# cf                                1.104141               0.0            -0.0
# ro                                1.260734               0.0            -0.0
# lime                              1.000000               0.0            -0.0
# co2                               1.016997               0.0            -0.0
# chlor                             1.104141               0.0            -0.0
# ammonia                           1.260734               0.0            -0.0
# TWS_24_hr                         1.296380               0.0            -0.0
# muni                              1.000000               0.0            -0.0
#
# [13 rows x 21 columns]

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-830ed5e65d76> in <module>
# ----> 1 x.head()
#
# NameError: name 'x' is not defined

# %%
from financials import *

# %%
basis_year = 2020

# %%
get_ind_table().loc[2020]
# Out:
# Year              2020.000000
# Capital_Index      625.293268
# CatChem_Index      294.742939
# Labor_Index         24.602217
# CPI_Index          261.350246
# Capital_Factor       1.000000
# CatChem_Factor       1.000000
# Labor_Factor         1.000000
# CPI_Factor           1.000000
# Name: 2020, dtype: float64

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)

# %%
df = pd.read_csv("data/plant_cost_indices.csv")

df1 = pd.DataFrame()
for name in df.columns[1:]:
    a, b = ml_regression.get_linear_regression(
        list(df.Year), list(df[("%s" % name)]), name
    )
    new_list = []
    yr_list = []
    for yr in range(df.Year.max() + 1, last_year_for_cost_indicies + 1):
        new_list.append(a * yr + b)
        yr_list.append(yr)
    df1[name] = new_list
df1["Year"] = yr_list
df = pd.concat([df, df1], axis=0)

new_cost_variables = ["Capital"] #, "CatChem", "Labor", "CPI"]
for variable in new_cost_variables:
    ind_name = "%s_Index" % variable
    fac_name = "%s_Factor" % variable
    df[fac_name] = (
         df[df.Year == analysis_yr_cost_indicies][ind_name].max() / df[ind_name]
    )

# %%
df[ind_name]
# Out:
# 0     357.600000
# 1     361.300000
# 2     358.200000
# 3     359.200000
# 4     368.100000
#          ...
# 28    885.474001
# 29    895.480952
# 30    905.487904
# 31    915.494855
# 32    925.501806
# Name: Capital_Index, Length: 61, dtype: float64

# %%
df[df.Year == analysis_yr_cost_indicies][ind_name].max()
# Out:
# 625.2932676518867

# %%
contact_time = 1.5  # hours
contact_time_mins = 1.5 * 60
ct = 450  # mg/L-min ---> ASSUME CALI STANDARD FOR NOW
chlorine_decay_rate = 3.0  # mg/Lh

# %%
chlorine_decay_rate * contact_time + ct / contact_time_mins
# Out:
# 9.5

# %%
from scipy.optimize import curve_fit

def power_law(x, a, b):

     return a*np.power(x, b)

# %%
ys = [0, 2,
4.4,
5,
5.4,
6]

xs = [0, 1,
3,
5,
10,
25]

# %%
pars, cov = curve_fit(f=power_law, xdata=xs, ydata=ys)

# %%
ys_new = pars[0] * xs ** pars[1]

# %%
ys_new
# Out:
# array([0.        , 2.99359142, 3.88823816, 4.3909188 , 5.17850022,
#        6.44048076])
