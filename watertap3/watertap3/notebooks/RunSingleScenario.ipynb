# %%
# %cd ..
from watertap3.utils import watertap_setup, get_case_study, run_water_tap, run_water_tap_ro, show_train2
# Out:
# /Users/ksitterl/Documents/Python/watertap3/NAWI-WaterTAP3/watertap3/watertap3

# %%
case_study = 'ashkelon'
scenario = 'baseline'
reference = 'nawi'
source_water = 'seawater'
source_water_category = 'seawater'
ro_bounds = 'seawater'
desired_recovery = 0.44

# case_study = 'carlsbad'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'seawater'
# source_water_category = 'seawater'
# ro_bounds = 'seawater'
# desired_recovery = 0.5

# case_study = 'santa_barbara'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'seawater'
# source_water_category = 'seawater'
# ro_bounds = 'seawater'
# desired_recovery = 0.5

# case_study = 'tampa_bay'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'seawater'
# source_water_category = 'seawater'
# ro_bounds = 'seawater'
# desired_recovery = 0.56

# case_study = 'emwd'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'emwd_ca_brackish'
# source_water_category = 'brackish'
# ro_bounds = 'other'
# desired_recovery = 0.7

# case_study = 'irwin'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'brackish'
# source_water_category = 'brackish'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'kbhdp'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'kbhdp_brackish_ave'
# source_water_category = 'brackish'
# ro_bounds = 'other'
# desired_recovery = 0.83

# case_study = 'big_spring'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'big_spring_feed'
# source_water_category = 'municipal'
# ro_bounds = 'baseline'
# desired_recovery = 1

# case_study = 'hrsd'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'hrsd_municipal'
# source_water_category = 'municipal'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'ocwd'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'ocwd_feed'
# source_water_category = 'municipal'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'solaire'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['solaire_graywater', 'solaire_blackwater']
# source_water_category = 'municipal'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'heap_leaching'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['ore_heap_make_up', 'ore_heap_recycle']
# source_water_category = 'mining'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'lithium'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'lithium_brine'
# source_water_category = 'mining'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'uranium'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['uranium_active', 'uranium_restore']
# source_water_category = 'mining'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'cherokee'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['cherokee_ct_makeup', 'denver_city_water']
# source_water_category = 'power'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'gila_river'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'gila_river_water'
# source_water_category = 'power'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'beef'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'beef_processing'
# source_water_category = 'agriculture'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'monterey_one'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'secondary_ww'
# source_water_category = 'agriculture'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'san_luis'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'irrigation_and_drainage'
# source_water_category = 'agriculture'
# ro_bounds = 'seawater'
# desired_recovery = 1

# case_study = 'iron_and_steel'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['steel_oily_ww', 'steel_metal_ww', 'hot_mill_blowdown', 'hot_mill_blowdown_b']
# source_water_category = 'industrial'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'pulp_and_paper'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['main_sewer', 'corrosive_sewer']
# source_water_category = 'industrial'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'upw'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'fab25'
# source_water_category = 'industrial'
# ro_bounds = 'seawater'
# desired_recovery = 1

# case_study = 'kern_county'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = ['produced_water', 'surface_water']
# source_water_category = 'conventional'
# ro_bounds = 'other'
# desired_recovery = 1

# case_study = 'damodar'
# scenario = 'baseline'
# reference = 'nawi'
# source_water = 'powder_river_basin_cbm'
# source_water_category = 'conventional'
# ro_bounds = 'other'
# desired_recovery = 1

case_study = 'produced_water_injection'
scenario = 'baseline'
reference = 'nawi'
source_water = 'produced_water_for_dw'
source_water_category = 'conventional'
ro_bounds = 'other'
desired_recovery = 1



m = watertap_setup(dynamic=False, case_study=case_study, reference=reference, 
                      scenario=scenario, source_scenario=scenario)

m = get_case_study(m=m)

m = run_water_tap_ro(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds,
                 source_water_category=source_water_category, scenario_name=scenario,
                 source_scenario=scenario)    

# run_water_tap(m, print_model_results='summary')
# Out:
# PRODUCED WATER INJECTION
#
# ------- Adding Unit Processes -------
# PASSTHROUGH
# HOLDING TANK
# INJECTION WELL DISPOSAL
# -------------------------------------
#
#
# Connecting unit processes...
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# PASSTHROUGH:
#
# 	total cap investment: 0.0
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# HOLDING TANK:
#
# 	total cap investment: 0.08026
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00103
#
# INJECTION WELL DISPOSAL:
#
# 	total cap investment: 12.10547
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03012
# 	total fixed op cost: 0.15602
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
#
#
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 12.186
# Annual Fixed Operating Cost ($MM/yr) 0.157
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.0
# Annual Electricity Costs ($MM/yr) 0.03
# Annual Other Variable Costs ($MM/yr) 0.0
# Annual Operating Costs ($MM/yr) 0.187
# Treated water (m3/s) ---> 0.046
# Total water recovery (%) ---> 99.97
# Electricity intensity (kwh/m3) --->  0.41
# LCOW ($/m3) --->  1.111
# Electricity portion of LCOW (%) ---> 1.87
# ----------------------------------------------------------------------

# %%
m = watertap_setup(dynamic=False, case_study=case_study, reference=reference, 
                      scenario=scenario, source_scenario="baseline")

m = get_case_study(m=m)

m = run_water_tap_ro(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds,
                 source_water_category='seawater', scenario_name=scenario,
                 source_scenario='baseline')  

# m = run_water_tap(m, print_model_results='summary')

# %%
import pyomo.util.infeasible as infeas
print(infeas.log_infeasible_bounds(m))
print(infeas.log_infeasible_constraints(m))
