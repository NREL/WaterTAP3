# %% [markdown]
# ### This is a tutorial for running the Carlsbad case study. The steps are:
# #### 1. Import WaterTAP3 package
# #### 2. Look up case study options
# #### 3. Define your case study, reference, and water type based on the case study library.
# #### 4. Set up model and populate model with case study information.
# #### 5. View the treatment train.
# #### 6. Run the treatment train.
# #### 7. Look at the results table.
# #### 8. View results using Dash.
# #### 9. Sensitivity Analysis

# %% [markdown]
# ##### Step 1. Import WaterTAP3 package

# %%
import watertap as wt

# %% [markdown]
# ##### Step 2. Look up case study options. For now each case study has only one reference and water type and the baseline scenario is the only option. Eventually we will be able to mix and match options below. For example, selecting a train from one place and the source water from another. We may or may not have the scenario selection here.

# %%
wt.case_study_trains.case_study_library.head()
# Out:
#       Case_Study   Scenario Reference WaterType
# 0       Ashkelon   Baseline      NAWI  Seawater
# 1       Carlsbad  TwoPassRO      NAWI  Seawater
# 2       Carlsbad   Baseline      NAWI  Seawater
# 3      Tampa_Bay   Baseline      NAWI  Seawater
# 4  Santa_Barbara   Baseline      NAWI  Seawater

# %% [markdown]
# ##### Step 3: Define your case study, reference, and water type based on the case study library.

# %%
wt.case_study_trains.case_study = "Carlsbad"
wt.case_study_trains.reference = "NAWI"
wt.case_study_trains.water_type = "Seawater"
wt.case_study_trains.scenario = "TwoPassRO"

# %% [markdown]
# ##### Step 4: Set up model and populate model with case study information. #TODO Flow is in m3/s (user can select unit of their choice - future tutorial).

# %%
# eventually we may want to be able to choose a dynamic model or different model set ups.
m = wt.watertap_setup(dynamic = False)

# load the treatment train, source water information, and flow to the model. #TODO automate flow based on case study.
m = wt.case_study_trains.get_case_study(flow = 4.5833, m = m)

# %% [markdown]
# ##### Step 5: View the treatment train.

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##### Step 6. Run the treatment train.

# %%
wt.run_water_tap(m = m, solver_results = True, print_model_results = True)
# Out:
# Ipopt 3.12.13:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2124
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      485
#
# Total number of variables............................:      692
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      692
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.98e+04 4.18e+00  -1.0 1.00e+05    -  9.56e-02 4.02e-01h  1
#    2  0.0000000e+00 1.19e+02 1.12e+02  -1.0 5.98e+04    -  1.01e-02 1.00e+00h  1
#    3  0.0000000e+00 1.64e+00 2.07e+01  -1.0 3.03e+01  -4.0 1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 1.05e-05 1.10e+00  -1.0 6.07e+01    -  1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 3.39e-11 4.08e-10  -1.0 4.15e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.3853575582480470e-11    3.3853575582480470e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.3853575582480470e-11    3.3853575582480470e-11
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.051
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0, (0.0, 'Anionic_Polymer'): 0.0, (0.0, 'Cationic_Polymer'): 0.0, (0.0, 'Lime_Suspension_CaOH_2'): 0.0, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0, (0.0, 'TDS'): 3.1554436208840472e-30}
#          :    flow_vol : {0.0: 2.6105828073107434e-16}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.sw_onshore_intake
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000010000100001, (0.0, 'Anionic_Polymer'): 0.0001000010000100001, (0.0, 'Cationic_Polymer'): 0.0001000010000100001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000010000100001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000010000100001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000010000100001, (0.0, 'TDS'): 35.00035000350003}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 3.43375374824602e-26, (0.0, 'Anionic_Polymer'): 3.433438203883932e-26, (0.0, 'Cationic_Polymer'): 3.433438203883932e-26, (0.0, 'Lime_Suspension_CaOH_2'): 3.433438203883932e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.433438203883932e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 3.433438203883932e-26, (0.0, 'TDS'): -6.590445725230491e-19}
#          :    flow_vol : {0.0: 4.583299999971757e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost sw_onshore_intake
# total_up_cost: 24.358000894568768
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_and_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000010000100001, (0.0, 'Anionic_Polymer'): 0.0001000010000100001, (0.0, 'Cationic_Polymer'): 0.0001000010000100001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000010000100001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000010000100001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000010000100001, (0.0, 'TDS'): 35.00035000350003}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000020000300004, (0.0, 'Anionic_Polymer'): 0.0001000020000300004, (0.0, 'Cationic_Polymer'): 0.0001000020000300004, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000020000300004, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000020000300004, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000020000300004, (0.0, 'TDS'): 35.00070001050013}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 7.970966130715192e-26, (0.0, 'Anionic_Polymer'): 7.970966130715192e-26, (0.0, 'Cationic_Polymer'): 7.970966130715192e-26, (0.0, 'Lime_Suspension_CaOH_2'): 7.970966130715192e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 7.970966130715192e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 7.970966130715192e-26, (0.0, 'TDS'): -1.388922275260239e-18}
#          :    flow_vol : {0.0: 4.583254166945494e-05}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost coag_and_floc
# total_up_cost: 13.654196217986414
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer1
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000020000300004, (0.0, 'Anionic_Polymer'): 0.0001000020000300004, (0.0, 'Cationic_Polymer'): 0.0001000020000300004, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000020000300004, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000020000300004, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000020000300004, (0.0, 'TDS'): 35.00070001050013}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.5407439555097887e-33, (0.0, 'Anionic_Polymer'): -2.311115933264683e-33, (0.0, 'Cationic_Polymer'): -2.311115933264683e-33, (0.0, 'Lime_Suspension_CaOH_2'): -2.311115933264683e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): -2.311115933264683e-33, (0.0, 'Sulphuric_Acid_H2SO4'): -1.5407439555097887e-33, (0.0, 'TDS'): 9.466330862652142e-30}
#          :    flow_vol : {0.0: 0.4811102671530844}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.050181002715036e-05, (0.0, 'Anionic_Polymer'): 9.050181002715036e-05, (0.0, 'Cationic_Polymer'): 9.050181002715036e-05, (0.0, 'Lime_Suspension_CaOH_2'): 9.050181002715036e-05, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.050181002715036e-05, (0.0, 'Sulphuric_Acid_H2SO4'): 9.050181002715036e-05, (0.0, 'TDS'): 31.675633509502624}
#          :    flow_vol : {0.0: 5.064318601611415}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should skip: mixer1
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.050181002715036e-05, (0.0, 'Anionic_Polymer'): 9.050181002715036e-05, (0.0, 'Cationic_Polymer'): 9.050181002715036e-05, (0.0, 'Lime_Suspension_CaOH_2'): 9.050181002715036e-05, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.050181002715036e-05, (0.0, 'Sulphuric_Acid_H2SO4'): 9.050181002715036e-05, (0.0, 'TDS'): 31.675633509502624}
#          :    flow_vol : {0.0: 5.064318601611415}
#          :    pressure : {0.0: 199999.99929999997}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055756669683373, (0.0, 'Anionic_Polymer'): 0.00010055756669683373, (0.0, 'Cationic_Polymer'): 0.00010055756669683373, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055756669683373, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055756669683373, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055756669683373, (0.0, 'TDS'): 35.19514834389181}
#          :    flow_vol : {0.0: 4.5578867414502735}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.1754943508222875e-38, (0.0, 'Anionic_Polymer'): 1.1754943508222875e-38, (0.0, 'Cationic_Polymer'): 1.1754943508222875e-38, (0.0, 'Lime_Suspension_CaOH_2'): 1.1754943508222875e-38, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.1754943508222875e-38, (0.0, 'Sulphuric_Acid_H2SO4'): 1.1754943508222875e-38, (0.0, 'TDS'): 4.622231866529366e-33}
#          :    flow_vol : {0.0: 0.5064318601611415}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost tri_media_filtration
# total_up_cost: 17.842225083369772
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.backwash_solids_handling
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.1754943508222875e-38, (0.0, 'Anionic_Polymer'): 1.1754943508222875e-38, (0.0, 'Cationic_Polymer'): 1.1754943508222875e-38, (0.0, 'Lime_Suspension_CaOH_2'): 1.1754943508222875e-38, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.1754943508222875e-38, (0.0, 'Sulphuric_Acid_H2SO4'): 1.1754943508222875e-38, (0.0, 'TDS'): 4.622231866529366e-33}
#          :    flow_vol : {0.0: 0.5064318601611415}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.5407439555097887e-33, (0.0, 'Anionic_Polymer'): -2.311115933264683e-33, (0.0, 'Cationic_Polymer'): -2.311115933264683e-33, (0.0, 'Lime_Suspension_CaOH_2'): -2.311115933264683e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): -2.311115933264683e-33, (0.0, 'Sulphuric_Acid_H2SO4'): -1.5407439555097887e-33, (0.0, 'TDS'): 9.466330862652142e-30}
#          :    flow_vol : {0.0: 0.4811102671530844}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -9.62964972193618e-35, (0.0, 'Anionic_Polymer'): -7.222237291452134e-35, (0.0, 'Cationic_Polymer'): -7.222237291452134e-35, (0.0, 'Lime_Suspension_CaOH_2'): -7.222237291452134e-35, (0.0, 'Sodium_Bisullfite_NaHSO3'): -7.222237291452134e-35, (0.0, 'Sulphuric_Acid_H2SO4'): -7.222237291452134e-35, (0.0, 'TDS'): 8.077935669463161e-28}
#          :    flow_vol : {0.0: 0.0253215930080571}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost backwash_solids_handling
# total_up_cost: 15.947883652484713
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.sulfuric_acid_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055756669683373, (0.0, 'Anionic_Polymer'): 0.00010055756669683373, (0.0, 'Cationic_Polymer'): 0.00010055756669683373, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055756669683373, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055756669683373, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055756669683373, (0.0, 'TDS'): 35.19514834389181}
#          :    flow_vol : {0.0: 4.5578867414502735}
#          :    pressure : {0.0: 199999.99919999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055857228255656, (0.0, 'Anionic_Polymer'): 0.00010055857228255656, (0.0, 'Cationic_Polymer'): 0.00010055857228255656, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055857228255656, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055857228255656, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055857228255656, (0.0, 'TDS'): 35.19550029889479}
#          :    flow_vol : {0.0: 4.557841162582859}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -7.734307859148888e-26, (0.0, 'Anionic_Polymer'): -6.869085218302482e-26, (0.0, 'Cationic_Polymer'): -7.220917182031054e-26, (0.0, 'Lime_Suspension_CaOH_2'): -7.170745628458997e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): -7.018337701570298e-26, (0.0, 'Sulphuric_Acid_H2SO4'): -7.00413820527632e-26, (0.0, 'TDS'): 9.746702244936827e-19}
#          :    flow_vol : {0.0: 4.5578867414519664e-05}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost sulfuric_acid_addition
# total_up_cost: 0.6960759870157917
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.sodium_bisulfite_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055857228255656, (0.0, 'Anionic_Polymer'): 0.00010055857228255656, (0.0, 'Cationic_Polymer'): 0.00010055857228255656, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055857228255656, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055857228255656, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055857228255656, (0.0, 'TDS'): 35.19550029889479}
#          :    flow_vol : {0.0: 4.557841162582859}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055957787833532, (0.0, 'Anionic_Polymer'): 0.00010055957787833534, (0.0, 'Cationic_Polymer'): 0.00010055957787833534, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055957787833534, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055957787833532, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055957787833534, (0.0, 'TDS'): 35.195852257417364}
#          :    flow_vol : {0.0: 4.557795584171234}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.156587942693202e-25, (0.0, 'Anionic_Polymer'): 2.156619497129411e-25, (0.0, 'Cationic_Polymer'): 2.156587942693202e-25, (0.0, 'Lime_Suspension_CaOH_2'): 2.156587942693202e-25, (0.0, 'Sodium_Bisullfite_NaHSO3'): 2.156619497129411e-25, (0.0, 'Sulphuric_Acid_H2SO4'): 2.156587942693202e-25, (0.0, 'TDS'): -2.6224669442585172e-18}
#          :    flow_vol : {0.0: 4.5578411625335484e-05}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost sodium_bisulfite_addition
# total_up_cost: 1.1967603299519687
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.cartridge_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055957787833532, (0.0, 'Anionic_Polymer'): 0.00010055957787833534, (0.0, 'Cationic_Polymer'): 0.00010055957787833534, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055957787833534, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055957787833532, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055957787833534, (0.0, 'TDS'): 35.195852257417364}
#          :    flow_vol : {0.0: 4.557795584171234}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010056058348417016, (0.0, 'Anionic_Polymer'): 0.00010056058348417016, (0.0, 'Cationic_Polymer'): 0.00010056058348417016, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010056058348417016, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010056058348417016, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010056058348417016, (0.0, 'TDS'): 35.19620421945955}
#          :    flow_vol : {0.0: 4.557750006215392}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.5467037996487334e-25, (0.0, 'Anionic_Polymer'): -1.5467037996487334e-25, (0.0, 'Cationic_Polymer'): -1.5467037996487334e-25, (0.0, 'Lime_Suspension_CaOH_2'): -1.5467353540849423e-25, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.5467353540849423e-25, (0.0, 'Sulphuric_Acid_H2SO4'): -1.5467353540849423e-25, (0.0, 'TDS'): 1.7283707288723998e-18}
#          :    flow_vol : {0.0: 4.557795584148039e-05}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost cartridge_filtration
# total_up_cost: 12.784502940962351
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro_deep
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010056058348417016, (0.0, 'Anionic_Polymer'): 0.00010056058348417016, (0.0, 'Cationic_Polymer'): 0.00010056058348417016, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010056058348417016, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010056058348417016, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010056058348417016, (0.0, 'TDS'): 35.19620421945955}
#          :    flow_vol : {0.0: 4.557750006215392}
#          :    pressure : {0.0: 199999.99889999998}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001919769000145099, (0.0, 'Anionic_Polymer'): 0.0001919769000145099, (0.0, 'Cationic_Polymer'): 0.0001919769000145099, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001919769000145099, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001919769000145099, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001919769000145099, (0.0, 'TDS'): 0.5375353200406391}
#          :    flow_vol : {0.0: 2.387422653274216}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.0377264129059154e-34, (0.0, 'Anionic_Polymer'): 1.0377264129059154e-34, (0.0, 'Cationic_Polymer'): 1.0377264129059154e-34, (0.0, 'Lime_Suspension_CaOH_2'): 1.0377264129059154e-34, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.0377264129059154e-34, (0.0, 'Sulphuric_Acid_H2SO4'): 1.0377264129059154e-34, (0.0, 'TDS'): 73.32173913043478}
#          :    flow_vol : {0.0: 2.1703273529411766}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost ro_deep
# total_up_cost: 259.25689967753044
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro_deep_scnd_pass
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001919769000145099, (0.0, 'Anionic_Polymer'): 0.0001919769000145099, (0.0, 'Cationic_Polymer'): 0.0001919769000145099, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001919769000145099, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001919769000145099, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001919769000145099, (0.0, 'TDS'): 0.5375353200406391}
#          :    flow_vol : {0.0: 2.387422653274216}
#          :    pressure : {0.0: 199999.99879999997}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338328706353978, (0.0, 'Anionic_Polymer'): 0.00019338328706353978, (0.0, 'Cationic_Polymer'): 0.00019338328706353978, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338328706353978, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338328706353978, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338328706353978, (0.0, 'TDS'): 0.004331785630223412}
#          :    flow_vol : {0.0: 2.3700600344506864}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -3.353254681765845e-31, (0.0, 'Anionic_Polymer'): -3.353254681765845e-31, (0.0, 'Cationic_Polymer'): -3.353254681765845e-31, (0.0, 'Lime_Suspension_CaOH_2'): -3.353254681765845e-31, (0.0, 'Sodium_Bisullfite_NaHSO3'): -3.353254681765845e-31, (0.0, 'Sulphuric_Acid_H2SO4'): -3.353254681765845e-31, (0.0, 'TDS'): 73.32173913043526}
#          :    flow_vol : {0.0: 0.017362618823529664}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost ro_deep_scnd_pass
# total_up_cost: 78.57220177591172
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime_softening
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338328706353978, (0.0, 'Anionic_Polymer'): 0.00019338328706353978, (0.0, 'Cationic_Polymer'): 0.00019338328706353978, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338328706353978, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338328706353978, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338328706353978, (0.0, 'TDS'): 0.004331785630223412}
#          :    flow_vol : {0.0: 2.3700600344506864}
#          :    pressure : {0.0: 199999.99869999997}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338522091574896, (0.0, 'Anionic_Polymer'): 0.00019338522091574893, (0.0, 'Cationic_Polymer'): 0.00019338522091574896, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338522091574893, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338522091574896, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338522091574893, (0.0, 'TDS'): 0.004331828948512897}
#          :    flow_vol : {0.0: 2.370036333850342}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 4.4096338525723034e-27, (0.0, 'Anionic_Polymer'): 4.4096338525723034e-27, (0.0, 'Cationic_Polymer'): 4.4096338525723034e-27, (0.0, 'Lime_Suspension_CaOH_2'): 4.4096338525723034e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): 4.4096338525723034e-27, (0.0, 'Sulphuric_Acid_H2SO4'): 4.4096338525723034e-27, (0.0, 'TDS'): 9.28849510888891e-23}
#          :    flow_vol : {0.0: 2.3700600344523863e-05}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost lime_softening
# total_up_cost: 56.78915124446787
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.co2_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338522091574896, (0.0, 'Anionic_Polymer'): 0.00019338522091574893, (0.0, 'Cationic_Polymer'): 0.00019338522091574896, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338522091574893, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338522091574896, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338522091574893, (0.0, 'TDS'): 0.004331828948512897}
#          :    flow_vol : {0.0: 2.370036333850342}
#          :    pressure : {0.0: 199999.99859999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338715478729683, (0.0, 'Anionic_Polymer'): 0.0001933871547872968, (0.0, 'Cationic_Polymer'): 0.00019338715478729683, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001933871547872968, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338715478729683, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001933871547872968, (0.0, 'TDS'): 0.004331872267235569}
#          :    flow_vol : {0.0: 2.3700126334870033}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 5.672846680864025e-27, (0.0, 'Anionic_Polymer'): 5.672846680864025e-27, (0.0, 'Cationic_Polymer'): 5.672895984670601e-27, (0.0, 'Lime_Suspension_CaOH_2'): 5.672846680864025e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): 5.672846680864025e-27, (0.0, 'Sulphuric_Acid_H2SO4'): 5.672895984670601e-27, (0.0, 'TDS'): 1.4370970673401742e-22}
#          :    flow_vol : {0.0: 2.3700363338553458e-05}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost co2_addition
# total_up_cost: 8.31608556681439
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.chlorination_twb
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019338715478729683, (0.0, 'Anionic_Polymer'): 0.0001933871547872968, (0.0, 'Cationic_Polymer'): 0.00019338715478729683, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001933871547872968, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019338715478729683, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001933871547872968, (0.0, 'TDS'): 0.004331872267235569}
#          :    flow_vol : {0.0: 2.3700126334870033}
#          :    pressure : {0.0: 199999.99849999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001933890886781836, (0.0, 'Anionic_Polymer'): 0.00019338908867818359, (0.0, 'Cationic_Polymer'): 0.0001933890886781836, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338908867818359, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001933890886781836, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338908867818359, (0.0, 'TDS'): 0.004331915586391433}
#          :    flow_vol : {0.0: 2.3699889333606685}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -8.44623510458822e-28, (0.0, 'Anionic_Polymer'): -8.44623510458822e-28, (0.0, 'Cationic_Polymer'): -8.44623510458822e-28, (0.0, 'Lime_Suspension_CaOH_2'): -8.44623510458822e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): -8.44623510458822e-28, (0.0, 'Sulphuric_Acid_H2SO4'): -8.44623510458822e-28, (0.0, 'TDS'): -2.707239360263884e-23}
#          :    flow_vol : {0.0: 2.3700126334803492e-05}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost chlorination_twb
# total_up_cost: 10.295173033594272
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001933890886781836, (0.0, 'Anionic_Polymer'): 0.00019338908867818359, (0.0, 'Cationic_Polymer'): 0.0001933890886781836, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019338908867818359, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001933890886781836, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019338908867818359, (0.0, 'TDS'): 0.004331915586391433}
#          :    flow_vol : {0.0: 2.3699889333606685}
#          :    pressure : {0.0: 199999.99839999995}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001933910225884095, (0.0, 'Anionic_Polymer'): 0.00019339102258840947, (0.0, 'Cationic_Polymer'): 0.0001933910225884095, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019339102258840947, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001933910225884095, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019339102258840947, (0.0, 'TDS'): 0.004331958905980493}
#          :    flow_vol : {0.0: 2.369965233471335}
#          :    pressure : {0.0: 199999.99829999998}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 3.9758589623138995e-28, (0.0, 'Anionic_Polymer'): 3.9758589623138995e-28, (0.0, 'Cationic_Polymer'): 3.9758589623138995e-28, (0.0, 'Lime_Suspension_CaOH_2'): 3.9758589623138995e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.9758589623138995e-28, (0.0, 'Sulphuric_Acid_H2SO4'): 3.9758589623138995e-28, (0.0, 'TDS'): 1.7556585384011234e-23}
#          :    flow_vol : {0.0: 2.369988933371807e-05}
#          :    pressure : {0.0: 199999.99829999998}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost ammonia_addition
# total_up_cost: 0.8600169419420021
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.treated_storage_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001933910225884095, (0.0, 'Anionic_Polymer'): 0.00019339102258840947, (0.0, 'Cationic_Polymer'): 0.0001933910225884095, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019339102258840947, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001933910225884095, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019339102258840947, (0.0, 'TDS'): 0.004331958905980493}
#          :    flow_vol : {0.0: 2.369965233471335}
#          :    pressure : {0.0: 199999.99829999998}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019339295651797466, (0.0, 'Anionic_Polymer'): 0.00019339295651797463, (0.0, 'Cationic_Polymer'): 0.00019339295651797466, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019339295651797463, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019339295651797466, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019339295651797463, (0.0, 'TDS'): 0.004332002226002753}
#          :    flow_vol : {0.0: 2.3699415338190004}
#          :    pressure : {0.0: 199999.99819999997}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -2.052320252545615e-27, (0.0, 'Anionic_Polymer'): -2.052320252545615e-27, (0.0, 'Cationic_Polymer'): -2.052320252545615e-27, (0.0, 'Lime_Suspension_CaOH_2'): -2.052320252545615e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): -2.052320252545615e-27, (0.0, 'Sulphuric_Acid_H2SO4'): -2.052320252545615e-27, (0.0, 'TDS'): -1.4851123169594632e-22}
#          :    flow_vol : {0.0: 2.3699652334409002e-05}
#          :    pressure : {0.0: 199999.99819999997}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost treated_storage_24_hr
# total_up_cost: 12.81420620132051
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.municipal_drinking
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019339295651797466, (0.0, 'Anionic_Polymer'): 0.00019339295651797463, (0.0, 'Cationic_Polymer'): 0.00019339295651797466, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019339295651797463, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019339295651797466, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019339295651797463, (0.0, 'TDS'): 0.004332002226002753}
#          :    flow_vol : {0.0: 2.3699415338190004}
#          :    pressure : {0.0: 199999.99819999997}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019339489046687932, (0.0, 'Anionic_Polymer'): 0.00019339489046687932, (0.0, 'Cationic_Polymer'): 0.00019339489046687932, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001933948904668793, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019339489046687932, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001933948904668793, (0.0, 'TDS'): 0.004332045546458218}
#          :    flow_vol : {0.0: 2.369917834403662}
#          :    pressure : {0.0: 199999.99809999997}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.745644247317331e-29, (0.0, 'Anionic_Polymer'): 2.745644247317331e-29, (0.0, 'Cationic_Polymer'): 2.745644247317331e-29, (0.0, 'Lime_Suspension_CaOH_2'): 2.745644247317331e-29, (0.0, 'Sodium_Bisullfite_NaHSO3'): 2.745644247317331e-29, (0.0, 'Sulphuric_Acid_H2SO4'): 2.745644247317331e-29, (0.0, 'TDS'): 4.447819650765658e-28}
#          :    flow_vol : {0.0: 2.3699415338208567e-05}
#          :    pressure : {0.0: 199999.99809999997}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost municipal_drinking
# total_up_cost: 7.703343205045051
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer2
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 3.43375374824602e-26, (0.0, 'Anionic_Polymer'): 3.433438203883932e-26, (0.0, 'Cationic_Polymer'): 3.433438203883932e-26, (0.0, 'Lime_Suspension_CaOH_2'): 3.433438203883932e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.433438203883932e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 3.433438203883932e-26, (0.0, 'TDS'): -6.590445725230491e-19}
#          :    flow_vol : {0.0: 4.583299999971757e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 7.970966130715192e-26, (0.0, 'Anionic_Polymer'): 7.970966130715192e-26, (0.0, 'Cationic_Polymer'): 7.970966130715192e-26, (0.0, 'Lime_Suspension_CaOH_2'): 7.970966130715192e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 7.970966130715192e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 7.970966130715192e-26, (0.0, 'TDS'): -1.388922275260239e-18}
#          :    flow_vol : {0.0: 4.583254166945494e-05}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -7.063949924147809e-32, (0.0, 'Anionic_Polymer'): 1.1068981428811828e-31, (0.0, 'Cationic_Polymer'): 3.7802393689675714e-32, (0.0, 'Lime_Suspension_CaOH_2'): 4.766676612358409e-32, (0.0, 'Sodium_Bisullfite_NaHSO3'): 7.968234218348378e-32, (0.0, 'Sulphuric_Acid_H2SO4'): 8.312193269353786e-32, (0.0, 'TDS'): 73.31011436539058}
#          :    flow_vol : {0.0: 2.1880368731729427}
#          :    pressure : {0.0: 199999.99873333328}
#          : temperature : {0.0: 299.9997333333333}
# Show some costing values
# ---------------------
# should skip: mixer2
# ----------------------------------------------------------------------
# fs.surface_discharge
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -7.063949924147809e-32, (0.0, 'Anionic_Polymer'): 1.1068981428811828e-31, (0.0, 'Cationic_Polymer'): 3.7802393689675714e-32, (0.0, 'Lime_Suspension_CaOH_2'): 4.766676612358409e-32, (0.0, 'Sodium_Bisullfite_NaHSO3'): 7.968234218348378e-32, (0.0, 'Sulphuric_Acid_H2SO4'): 8.312193269353786e-32, (0.0, 'TDS'): 73.31011436539058}
#          :    flow_vol : {0.0: 2.1880368731729427}
#          :    pressure : {0.0: 199999.99873333328}
#          : temperature : {0.0: 299.9997333333333}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.308625578453032e-25, (0.0, 'Anionic_Polymer'): 1.308625578453032e-25, (0.0, 'Cationic_Polymer'): 1.3083731429633613e-25, (0.0, 'Lime_Suspension_CaOH_2'): 1.308625578453032e-25, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.3083731429633613e-25, (0.0, 'Sulphuric_Acid_H2SO4'): 1.3083731429633613e-25, (0.0, 'TDS'): 73.31084747386531}
#          :    flow_vol : {0.0: 2.188014992804211}
#          :    pressure : {0.0: 199999.9986333333}
#          : temperature : {0.0: 299.9997333333333}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.1387060796189532e-32, (0.0, 'Anionic_Polymer'): -1.1387060796189532e-32, (0.0, 'Cationic_Polymer'): -1.1387060796189532e-32, (0.0, 'Lime_Suspension_CaOH_2'): -1.1387060796189532e-32, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.1387060796189532e-32, (0.0, 'Sulphuric_Acid_H2SO4'): -1.1387060796189532e-32, (0.0, 'TDS'): -1.4085900323626387e-25}
#          :    flow_vol : {0.0: 2.188036873150514e-05}
#          :    pressure : {0.0: 199999.9986333333}
#          : temperature : {0.0: 299.9997333333333}
# Show some costing values
# ---------------------
# should have a cost surface_discharge
# total_up_cost: 31.665767628156875
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.landfill
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -9.62964972193618e-35, (0.0, 'Anionic_Polymer'): -7.222237291452134e-35, (0.0, 'Cationic_Polymer'): -7.222237291452134e-35, (0.0, 'Lime_Suspension_CaOH_2'): -7.222237291452134e-35, (0.0, 'Sodium_Bisullfite_NaHSO3'): -7.222237291452134e-35, (0.0, 'Sulphuric_Acid_H2SO4'): -7.222237291452134e-35, (0.0, 'TDS'): 8.077935669463161e-28}
#          :    flow_vol : {0.0: 0.0253215930080571}
#          :    pressure : {0.0: 199999.99909999996}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.9721522630525295e-31, (0.0, 'Anionic_Polymer'): -1.9721522630525295e-31, (0.0, 'Cationic_Polymer'): -1.9721522630525295e-31, (0.0, 'Lime_Suspension_CaOH_2'): -1.9721522630525295e-31, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.9721522630525295e-31, (0.0, 'Sulphuric_Acid_H2SO4'): -1.9721522630525295e-31, (0.0, 'TDS'): 7.068193710780266e-28}
#          :    flow_vol : {0.0: 0.025321339792127022}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -2.6307525112989217e-27, (0.0, 'Anionic_Polymer'): -2.6307525112989217e-27, (0.0, 'Cationic_Polymer'): -2.6307525112989217e-27, (0.0, 'Lime_Suspension_CaOH_2'): -2.6307525112989217e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): -2.6307525112989217e-27, (0.0, 'Sulphuric_Acid_H2SO4'): -2.6307525112989217e-27, (0.0, 'TDS'): -2.6727593545019406e-27}
#          :    flow_vol : {0.0: 2.5321593007804365e-07}
#          :    pressure : {0.0: 199999.99899999995}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost landfill
# total_up_cost: 0.00791137117002745
# ----------------------------------------------------------------------

# %% [markdown]
# #### 7. Look at the results table.

# %%
wt.get_results_table(m = m).tail()
# Out:
#      Unit Process Name                         Variable   Value       Metric  \
# 1045            System               System Electricity  66.801  Annual Cost
# 1046            System  System Other Variable Operating   0.000  Annual Cost
# 1047            System           System Fixed Operating   6.732  Annual Cost
# 1048            System      System Total Operating Cost  83.312  Annual Cost
# 1049            System            System Levelized Cost   1.624         LCOW
#
#         Unit Case Study   Scenario
# 1045  $MM/yr   Carlsbad  TwoPassRO
# 1046  $MM/yr   Carlsbad  TwoPassRO
# 1047  $MM/yr   Carlsbad  TwoPassRO
# 1048  $MM/yr   Carlsbad  TwoPassRO
# 1049    $/m3   Carlsbad  TwoPassRO

# %%
#### 8. View results using Dash.

# %%
csv_dir = './results/Carlsbad_TwoPassRO_results.csv'
json_dir = './tmp/example.json'

wt.run_dash(csv_dir, json_dir)
# Out:
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# ##### Comparison of two scenarios

# %%
# See that there are two Carlsbad options, so we can compare those (others currently in progress)
wt.case_study_trains.case_study_library.head()
# Out:
#       Case_Study   Scenario Reference WaterType
# 0       Ashkelon   Baseline      NAWI  Seawater
# 1       Carlsbad  TwoPassRO      NAWI  Seawater
# 2       Carlsbad   Baseline      NAWI  Seawater
# 3      Tampa_Bay   Baseline      NAWI  Seawater
# 4  Santa_Barbara   Baseline      NAWI  Seawater

# %%
results = wt.run_model_comparison(scenarioA = "Baseline", scenarioB = "TwoPassRO", flow = 4.5833)

# %%
results.head()
# Out:
#    Unit Process Name                        Variable   Value       Metric  \
# 0  sw_onshore_intake  Fixed Capital Investment (FCI)  20.980         Cost
# 1  sw_onshore_intake                            Land   0.031         Cost
# 2  sw_onshore_intake                 Working Capital   1.049         Cost
# 3  sw_onshore_intake  Total Capital Investment (TCI)  22.061         Cost
# 4  sw_onshore_intake         Catalysts and Chemicals   0.000  Annual Cost
#
#      Unit Case Study  Scenario
# 0     $MM   Carlsbad  Baseline
# 1     $MM   Carlsbad  Baseline
# 2     $MM   Carlsbad  Baseline
# 3     $MM   Carlsbad  Baseline
# 4  $MM/yr   Carlsbad  Baseline

# %%
results.tail()
# Out:
#      Unit Process Name                         Variable   Value       Metric  \
# 1045            System               System Electricity  66.801  Annual Cost
# 1046            System  System Other Variable Operating   0.000  Annual Cost
# 1047            System           System Fixed Operating   6.732  Annual Cost
# 1048            System      System Total Operating Cost  83.312  Annual Cost
# 1049            System            System Levelized Cost   1.624         LCOW
#
#         Unit Case Study   Scenario
# 1045  $MM/yr   Carlsbad  TwoPassRO
# 1046  $MM/yr   Carlsbad  TwoPassRO
# 1047  $MM/yr   Carlsbad  TwoPassRO
# 1048  $MM/yr   Carlsbad  TwoPassRO
# 1049    $/m3   Carlsbad  TwoPassRO

# %% [markdown]
# #### 9. Sensitivity Analysis

# %%
import numpy as np
import pandas as pd
from pyomo.environ import value
import time

# %%
#tds_range = np.arange(1, 200)
#backwash_scenario = [1e-5, 0.5, 0.95]

tds_range = np.arange(25, 85)
backwash_scenario = [0.95]
pmax_range = np.arange(75, 95)

# %%
startTime = time.time()

lcow_list = []
recovery_list = []
scenario_list = []
tds_list = []

wt.case_study_trains.case_study = "Carlsbad"
wt.case_study_trains.reference = "NAWI"
wt.case_study_trains.water_type = "Seawater"
wt.case_study_trains.scenario = "TwoPassRO"

final_df = pd.DataFrame()

for pmax_scenario in pmax_range:

    for bw_scenario in backwash_scenario:

        #for value_change in pct_to_target1: # cycles through each value from MC range
        for tds_value in tds_range:

            # create and build model
            m = wt.watertap_setup(dynamic = False)
            m = wt.case_study_trains.get_case_study(flow = 4.5833, m = m)

            m.fs.backwash_solids_handling.water_recovery.fix(bw_scenario)
            m.fs.ro_deep.pmax.fix(pmax_scenario)
            m.fs.source1.conc_mass_in[0, "TDS"].fix(tds_value)

            wt.run_water_tap(m = m, solver_results = False, print_model_results = False)

            #df = wt.get_results_table(m = m)
            #df[df["Unit Process Name"] == "System"]
            
            if "j" in str(value(m.fs.costing.LCOW)):
                continue
            else:
                inlet_flow = value(m.fs.municipal_drinking.flow_vol_in[0])
                outlet_flow = value(m.fs.source1.flow_vol_in[0])
                recovery_list.append(inlet_flow / outlet_flow)
                scenario_list.append(pmax_scenario)
                tds_list.append(value(m.fs.source1.conc_mass_in[0, "TDS"]))
                lcow_list.append(value(m.fs.costing.LCOW))

final_df["sys_recovery"] = recovery_list
final_df["lcow"] = lcow_list
final_df["tds_inlet"] = tds_list
final_df["p_max"] = scenario_list

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
final_df.to_csv("sens_test.csv")

# %%
df.to_csv("")

# %%
#### DO NOT USE THE BELOW ####

# %%
cost_range_list = []; #results will be inputted in this array
#up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.

#for value_change in pct_to_target1: # cycles through each value from MC range
for value_change in [0.4, 0.8]: #, 0.9]:

    # create and build model
    m = wt.watertap_setup(dynamic = False)
    m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

    m.fs.tri_media_filtration.water_recovery.fix(value_change)

    # set variable to MC value
    wt.run_water_tap(m)
    results_table = get_results_table(m, unit_process_name)
    cost_range_list.append(results_table.total_up_cost.sum())

# %%
import time
from multiprocessing import Pool
import multiprocessing

mu = 0.6
sigma = .1
num_reps = 50

input_list = np.random.normal(mu,sigma, size = num_reps) #, sigma, num_reps).round(4)

count, bins, ignored = plt.hist(input_list, 25, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
          linewidth=2, color='r')
plt.show()

### INPUT TO MODEL LIST: ### CAN BE AUTOMATED FOR USER TO LABEL THE VARIABLE. TOOD ###
no_of_proc = 4
list_final = []
for i in range(no_of_proc):
    part2 = len(input_list) / no_of_proc
    i2 = ((i+1)*part2)
    list1 = input_list[int(i*part2):int(i2)]
    list_final.append(list1)
    
    
def monte_run(list_final):
    print('goes in')

    up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.
    cost_range_list = []; #results will be inputted in this array

    #for value_change in pct_to_target1: # cycles through each value from MC range
    for value_change in list_final:

        # create and build model
        m = wt.watertap_setup(dynamic = False)
        m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

        getattr(m.fs, up_name).water_recovery.fix(value_change)

        # set variable to MC value
        result = wt.run_water_tap(m)
        results_table = get_results_table(m, unit_process_names)
        cost_range_list.append(results_table.total_up_cost.sum())


    return cost_range_list

startTime = time.time()

pool=Pool()
dfs = pool.map(monte_run, list_final) #SomeClass().preprocess_data()

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
2.37 / 2.39

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)
