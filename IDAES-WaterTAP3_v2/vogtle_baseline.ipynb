# %%
import watertap as wt
import pandas as pd
from pyomo.environ import value, Block
from idaes.core import FlowsheetBlock
import numpy as np
from case_study_trains import *
import case_study_trains
import pyomo.environ as env
from pyomo.environ import Constraint
m = wt.watertap_setup(dynamic=False)


wt.case_study_trains.train = {"case_study": "vogtle",
                             "reference": "nawi",
                             "scenario": "baseline"}


wt.case_study_trains.source_water = {"case_study": "vogtle", 
                             "reference": "nawi",
                             "scenario": "baseline",
                             "water_type": ['savannah_river_water', 'nuclear_raw_outfall']}

m = wt.case_study_trains.get_case_study(m=m)
# Out:
# vogtle
#
# ------- Adding Unit Processes -------
# water_pumping_station
# microscreen_filtration
# cooling_tower
# assuming cycles of concentration is: 5.0
# holding_tank
# treated_storage_a
# discharge_a
# tramp_oil_tank
# treated_storage_b
# discharge_b
# -------------------------------------
#
# adding source
# adding source
# adding splitter
#
# Connecting unit processes...

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
wt.run_water_tap(m=m, objective=False, skip_small=False, print_model_results='summary')
# Out:
# Flow is relatively small (< 1 m3/s). Running model with larger dummy flows to initialize...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Model finished running to initialize conditions. Now running with actual flow...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# WATER PUMPING STATION:
#
# 	total cap investment: 7.20276
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.09591
#
# MICROSCREEN FILTRATION:
#
# 	total cap investment: 2.31866
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.03076
#
# COOLING TOWER:
#
# 	total cap investment: 0.0
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# HOLDING TANK:
#
# 	total cap investment: 6.78758
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.09038
#
# TREATED STORAGE A:
#
# 	total cap investment: 5.30189
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.06969
#
# DISCHARGE A:
#
# 	total cap investment: 6.59034
# 	cat and chem cost: 0.0
# 	electricity cost: 0.36013
# 	total fixed op cost: 0.08743
#
# TRAMP OIL TANK:
#
# 	total cap investment: 0.0086
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00011
#
# TREATED STORAGE B:
#
# 	total cap investment: 0.58378
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.00767
#
# DISCHARGE B:
#
# 	total cap investment: 0.46592
# 	cat and chem cost: 0.0
# 	electricity cost: 0.01688
# 	total fixed op cost: 0.00618
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 29.26
# Annual Fixed Operating Cost ($MM/yr) 0.388
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.0
# Annual Electricity Costs ($MM/yr) 0.377
# Annual Other Variable Costs ($MM/yr) 0.0
# Annual Operating Costs ($MM/yr) 0.765
# Treated water (m3/s) ---> 3.797
# Total water recovery (%) ---> 63.548
# Electricity intensity (kwh/m3) --->  0.051
# LCOW ($/m3) --->  0.022
# Electricity portion of LCOW (%) ---> 14.128
# ----------------------------------------------------------------------

# %%
# creates csv in results folder with the name: *case_study*_*scenario*.csv
# In this case, save the final baseline result.

df = wt.get_results_table(m=m, case_study=wt.case_study_trains.source_water["case_study"], 
                                scenario=wt.case_study_trains.source_water["scenario"])

# %%
m.fs.cooling_tower.display()
# Out:
# Block fs.cooling_tower
#
#   Variables:
#     flow_vol_in : Volumetric flowrate of water into unit
#         Size=1, Index=fs.time
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 : 1e-08 : 2.9018292665671486 : 100.0 : False : False : NonNegativeReals
#     conc_mass_in : Mass concentration of species at inlet
#         Size=4, Index=fs.cooling_tower.conc_mass_in_index
#         Key               : Lower : Value                 : Upper : Fixed : Stale : Domain
#              (0.0, 'bod') :  None :    0.0020001800180018 :  None : False : False :  Reals
#         (0.0, 'thallium') :  None : 9.799107950234038e-23 :  None : False : False :  Reals
#              (0.0, 'toc') :  None : 0.0026602394239423942 :  None : False : False :  Reals
#              (0.0, 'tss') :  None :  0.008000720072007202 :  None : False : False :  Reals
#     temperature_in : Temperature at inlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None : 300.0 :  None : False : False :  Reals
#     pressure_in : Pressure at inlet
#         Size=1, Index=fs.time
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 1.0002 :  None : False : False : NonNegativeReals
#     flow_vol_out : Volumetric flowrate of water out of unit
#         Size=1, Index=fs.time
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 0.7254573166417869 :  None : False : False : NonNegativeReals
#     conc_mass_out : Mass concentration of species at outlet
#         Size=4, Index=fs.cooling_tower.conc_mass_out_index
#         Key               : Lower : Value                  : Upper : Fixed : Stale : Domain
#              (0.0, 'bod') :  None :   0.008000640064806483 :  None : False : False :  Reals
#         (0.0, 'thallium') :  None : 3.9196039836618176e-22 :  None : False : False :  Reals
#              (0.0, 'toc') :  None :   0.010640851286192621 :  None : False : False :  Reals
#              (0.0, 'tss') :  None :    0.03200256025922593 :  None : False : False :  Reals
#     temperature_out : Temperature at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None : 300.0 :  None : False : False :  Reals
#     pressure_out : Pressure at outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 1.0003 :  None : False : False : NonNegativeReals
#     flow_vol_waste : Volumetric flowrate of water in waste
#         Size=1, Index=fs.time
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 2.1763719499253615 :  None : False : False : NonNegativeReals
#     conc_mass_waste : Mass concentration of species in waste
#         Size=4, Index=fs.cooling_tower.conc_mass_waste_index
#         Key               : Lower : Value                  : Upper : Fixed : Stale : Domain
#              (0.0, 'bod') :  None : 2.6669066906690672e-08 :  None : False : False :  Reals
#         (0.0, 'thallium') :  None : 1.3065477266978764e-27 :  None : False : False :  Reals
#              (0.0, 'toc') :  None :  3.546985898589859e-08 :  None : False : False :  Reals
#              (0.0, 'tss') :  None : 1.0667626762676269e-07 :  None : False : False :  Reals
#     temperature_waste : Temperature of waste
#         Size=1, Index=fs.time
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 300.0 :  None : False : False : NonNegativeReals
#     pressure_waste : Pressure of waste
#         Size=1, Index=fs.time
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 1.0003 :  None : False : False : NonNegativeReals
#     deltaP_outlet : Pressure change between inlet and outlet
#         Size=1, Index=fs.time
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#         0.0 :  None : 0.0001 :  None :  True :  True :  Reals
#     deltaP_waste : Pressure change between inlet and waste
#         Size=1, Index=fs.time
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#         0.0 :  None : 0.0001 :  None :  True :  True :  Reals
#     water_recovery : Water recovery fraction
#         Size=1, Index=fs.time
#         Key : Lower : Value                                                                                                          : Upper     : Fixed : Stale : Domain
#         0.0 : 1e-08 : (fs.cooling_tower.flow_vol_in[0.0] - 0.75*fs.cooling_tower.flow_vol_in[0.0])/fs.cooling_tower.flow_vol_in[0.0] : 1.0000001 :  True :  True : NonNegativeReals
#     removal_fraction : Component removal fraction
#         Size=4, Index=fs.cooling_tower.removal_fraction_index
#         Key               : Lower : Value : Upper : Fixed : Stale : Domain
#              (0.0, 'bod') :     0 : 1e-05 :  None :  True :  True : NonNegativeReals
#         (0.0, 'thallium') :     0 : 1e-05 :  None :  True :  True : NonNegativeReals
#              (0.0, 'toc') :     0 : 1e-05 :  None :  True :  True : NonNegativeReals
#              (0.0, 'tss') :     0 : 1e-05 :  None :  True :  True : NonNegativeReals
#
#   Objectives:
#     None
#
#   Constraints:
#     outlet_pressure_constraint : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     waste_pressure_constraint : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     recovery_equation : Size=1
#         Key : Lower : Body                                                                                                                                                   : Upper
#         0.0 :   0.0 : (fs.cooling_tower.flow_vol_in[0.0] - 0.75*fs.cooling_tower.flow_vol_in[0.0])/fs.cooling_tower.flow_vol_in[0.0]*2.9018292665671486 - 0.7254573166417869 :   0.0
#     flow_balance : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     component_removal_equation : Size=4
#         Key               : Lower : Body                    : Upper
#              (0.0, 'bod') :   0.0 : -1.3234889800848443e-23 :   0.0
#         (0.0, 'thallium') :   0.0 : -1.0044507392280289e-41 :   0.0
#              (0.0, 'toc') :   0.0 : -1.3234889800848443e-23 :   0.0
#              (0.0, 'tss') :   0.0 :                     0.0 :   0.0
#     component_mass_balance : Size=4
#         Key               : Lower : Body                   : Upper
#              (0.0, 'bod') :   0.0 :                    0.0 :   0.0
#         (0.0, 'thallium') :   0.0 : -1.410593220986745e-37 :   0.0
#              (0.0, 'toc') :   0.0 :  8.673617379884035e-19 :   0.0
#              (0.0, 'tss') :   0.0 :  3.469446951953614e-18 :   0.0
#     outlet_temperature_constraint : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     waste_temperature_constraint : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#
#   Blocks:
#     Block fs.cooling_tower.costing
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         None
