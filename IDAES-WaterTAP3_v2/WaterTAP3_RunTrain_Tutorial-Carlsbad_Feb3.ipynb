# %% [markdown]
# ### This is a tutorial for running the Carlsbad case study. The steps are:
# #### 1. Import WaterTAP3 package
# #### 2. Look up case study options
# #### 3. Define your case study, reference, and water type based on the case study library.
# #### 4. Set up model and populate model with case study information.
# #### 5. View the treatment train.
# #### 6. Run the treatment train.
# #### 7. Look at the results table.
# #### 8. View results using Dash.
# #### 9. Sensitivity Analysis

# %% [markdown]
# ##### Step 1. Import WaterTAP3 package

# %%
import watertap as wt

# %% [markdown]
# ##### Step 2. Look up case study options. For now each case study has only one reference and water type and the baseline scenario is the only option. Eventually we will be able to mix and match options below. For example, selecting a train from one place and the source water from another. We may or may not have the scenario selection here.

# %%
wt.case_study_trains.case_study_library.head()
# Out:
#       Case_Study  Scenario Reference WaterType
# 0       Ashkelon  Baseline      NAWI  Seawater
# 1       Carlsbad  Baseline      NAWI  Seawater
# 2      Tampa_Bay  Baseline      NAWI  Seawater
# 3  Santa_Barbara  Baseline      NAWI  Seawater
# 4          KBHDP  Baseline      NAWI       NaN

# %% [markdown]
# ##### Step 3: Define your case study, reference, and water type based on the case study library.

# %%
wt.case_study_trains.case_study = "Carlsbad"
wt.case_study_trains.reference = "NAWI"
wt.case_study_trains.water_type = "Seawater"
wt.case_study_trains.scenario = "Baseline"

# %% [markdown]
# ##### Step 4: Set up model and populate model with case study information. #TODO Flow is in m3/s (user can select unit of their choice - future tutorial).

# %%
# eventually we may want to be able to choose a dynamic model or different model set ups.
m = wt.watertap_setup(dynamic = False)

# load the treatment train, source water information, and flow to the model. #TODO automate flow based on case study.
m = wt.case_study_trains.get_case_study(flow = 4.5833, m = m)

# %% [markdown]
# ##### Step 5: View the treatment train.

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##### Step 6. Run the treatment train.

# %%
wt.run_water_tap(m = m, solver_results = True, print_model_results = True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1993
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      456
#
# Total number of variables............................:      651
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        1
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      651
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.98e+04 4.19e+00  -1.0 1.00e+05    -  9.56e-02 4.02e-01h  1
#    2  0.0000000e+00 1.19e+02 1.12e+02  -1.0 5.98e+04    -  1.01e-02 1.00e+00h  1
#    3  0.0000000e+00 1.64e+00 2.07e+01  -1.0 3.03e+01  -4.0 1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 2.11e-06 9.66e-04  -1.0 7.41e-01    -  1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 2.44e-11 4.24e-13  -2.5 1.25e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.4354085330986937e-11    2.4354085330986937e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.4354085330986937e-11    2.4354085330986937e-11
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.010
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# degrees_of_freedom: 0
# ----------------------------------------------------------------------
# fs.source1
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 200000.0}
#          : temperature : {0.0: 300}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0, (0.0, 'Anionic_Polymer'): 0.0, (0.0, 'Cationic_Polymer'): 0.0, (0.0, 'Lime_Suspension_CaOH_2'): 0.0, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0, (0.0, 'TDS'): 0.0}
#          :    flow_vol : {0.0: -2.307894524818235e-16}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should skip: source1
# ----------------------------------------------------------------------
# fs.sw_onshore_intake
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001, (0.0, 'Anionic_Polymer'): 0.0001, (0.0, 'Cationic_Polymer'): 0.0001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001, (0.0, 'TDS'): 35.0}
#          :    flow_vol : {0.0: 4.5833}
#          :    pressure : {0.0: 199999.9999}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000010000100001, (0.0, 'Anionic_Polymer'): 0.0001000010000100001, (0.0, 'Cationic_Polymer'): 0.0001000010000100001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000010000100001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000010000100001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000010000100001, (0.0, 'TDS'): 35.00035000350003}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.7664173389708896e-26, (0.0, 'Anionic_Polymer'): -1.7664173389708896e-26, (0.0, 'Cationic_Polymer'): -1.7664173389708896e-26, (0.0, 'Lime_Suspension_CaOH_2'): -1.7664173389708896e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.7664173389708896e-26, (0.0, 'Sulphuric_Acid_H2SO4'): -1.7664173389708896e-26, (0.0, 'TDS'): 2.2274848930419963e-18}
#          :    flow_vol : {0.0: 4.583299999971757e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost sw_onshore_intake
# total_up_cost: 24.358000894568768
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.coag_and_floc
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001000010000100001, (0.0, 'Anionic_Polymer'): 0.0001000010000100001, (0.0, 'Cationic_Polymer'): 0.0001000010000100001, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001000010000100001, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001000010000100001, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001000010000100001, (0.0, 'TDS'): 35.00035000350003}
#          :    flow_vol : {0.0: 4.583254167000001}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010000200003000038, (0.0, 'Anionic_Polymer'): 0.00010000200003000038, (0.0, 'Cationic_Polymer'): 0.00010000200003000038, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010000200003000038, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010000200003000038, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010000200003000038, (0.0, 'TDS'): 35.00070001050013}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.4567894336716425e-26, (0.0, 'Anionic_Polymer'): 1.4567894336716425e-26, (0.0, 'Cationic_Polymer'): 1.4567894336716425e-26, (0.0, 'Lime_Suspension_CaOH_2'): 1.4567894336716425e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.4567894336716425e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 1.4567894336716425e-26, (0.0, 'TDS'): -1.1090837653110995e-18}
#          :    flow_vol : {0.0: 4.583254166945494e-05}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# Show some costing values
# ---------------------
# should have a cost coag_and_floc
# total_up_cost: 13.654196217986414
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer1
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010000200003000038, (0.0, 'Anionic_Polymer'): 0.00010000200003000038, (0.0, 'Cationic_Polymer'): 0.00010000200003000038, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010000200003000038, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010000200003000038, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010000200003000038, (0.0, 'TDS'): 35.00070001050013}
#          :    flow_vol : {0.0: 4.583208334458331}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -3.851859888774472e-33, (0.0, 'Anionic_Polymer'): -3.851859888774472e-33, (0.0, 'Cationic_Polymer'): -3.851859888774472e-33, (0.0, 'Lime_Suspension_CaOH_2'): -3.0814879110195774e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): -3.851859888774472e-33, (0.0, 'Sulphuric_Acid_H2SO4'): -3.851859888774472e-33, (0.0, 'TDS'): 9.466330862652142e-30}
#          :    flow_vol : {0.0: 0.4811102671530844}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.050181002715036e-05, (0.0, 'Anionic_Polymer'): 9.050181002715036e-05, (0.0, 'Cationic_Polymer'): 9.050181002715036e-05, (0.0, 'Lime_Suspension_CaOH_2'): 9.050181002715036e-05, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.050181002715036e-05, (0.0, 'Sulphuric_Acid_H2SO4'): 9.050181002715036e-05, (0.0, 'TDS'): 31.675633509502624}
#          :    flow_vol : {0.0: 5.064318601611415}
#          :    pressure : {0.0: 199999.9993}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should skip: mixer1
# ----------------------------------------------------------------------
# fs.tri_media_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.050181002715036e-05, (0.0, 'Anionic_Polymer'): 9.050181002715036e-05, (0.0, 'Cationic_Polymer'): 9.050181002715036e-05, (0.0, 'Lime_Suspension_CaOH_2'): 9.050181002715036e-05, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.050181002715036e-05, (0.0, 'Sulphuric_Acid_H2SO4'): 9.050181002715036e-05, (0.0, 'TDS'): 31.675633509502624}
#          :    flow_vol : {0.0: 5.064318601611415}
#          :    pressure : {0.0: 199999.9993}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055756669683373, (0.0, 'Anionic_Polymer'): 0.00010055756669683373, (0.0, 'Cationic_Polymer'): 0.00010055756669683373, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055756669683373, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055756669683373, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055756669683373, (0.0, 'TDS'): 35.1951483438918}
#          :    flow_vol : {0.0: 4.5578867414502735}
#          :    pressure : {0.0: 199999.9992}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.350988701644575e-38, (0.0, 'Anionic_Polymer'): 2.350988701644575e-38, (0.0, 'Cationic_Polymer'): 2.350988701644575e-38, (0.0, 'Lime_Suspension_CaOH_2'): 2.350988701644575e-38, (0.0, 'Sodium_Bisullfite_NaHSO3'): 2.350988701644575e-38, (0.0, 'Sulphuric_Acid_H2SO4'): 2.350988701644575e-38, (0.0, 'TDS'): 6.162975822039155e-33}
#          :    flow_vol : {0.0: 0.5064318601611415}
#          :    pressure : {0.0: 199999.9992}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost tri_media_filtration
# total_up_cost: 17.842225083369772
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.backwash_solids_handling
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.350988701644575e-38, (0.0, 'Anionic_Polymer'): 2.350988701644575e-38, (0.0, 'Cationic_Polymer'): 2.350988701644575e-38, (0.0, 'Lime_Suspension_CaOH_2'): 2.350988701644575e-38, (0.0, 'Sodium_Bisullfite_NaHSO3'): 2.350988701644575e-38, (0.0, 'Sulphuric_Acid_H2SO4'): 2.350988701644575e-38, (0.0, 'TDS'): 6.162975822039155e-33}
#          :    flow_vol : {0.0: 0.5064318601611415}
#          :    pressure : {0.0: 199999.9992}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -3.851859888774472e-33, (0.0, 'Anionic_Polymer'): -3.851859888774472e-33, (0.0, 'Cationic_Polymer'): -3.851859888774472e-33, (0.0, 'Lime_Suspension_CaOH_2'): -3.0814879110195774e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): -3.851859888774472e-33, (0.0, 'Sulphuric_Acid_H2SO4'): -3.851859888774472e-33, (0.0, 'TDS'): 9.466330862652142e-30}
#          :    flow_vol : {0.0: 0.4811102671530844}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -8.425943506694157e-35, (0.0, 'Anionic_Polymer'): -8.425943506694157e-35, (0.0, 'Cationic_Polymer'): -8.425943506694157e-35, (0.0, 'Lime_Suspension_CaOH_2'): -8.425943506694157e-35, (0.0, 'Sodium_Bisullfite_NaHSO3'): -8.425943506694157e-35, (0.0, 'Sulphuric_Acid_H2SO4'): -8.425943506694157e-35, (0.0, 'TDS'): 1.1107161545511846e-27}
#          :    flow_vol : {0.0: 0.025321593008057103}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost backwash_solids_handling
# total_up_cost: 15.947883652484713
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.sulfuric_acid_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055756669683373, (0.0, 'Anionic_Polymer'): 0.00010055756669683373, (0.0, 'Cationic_Polymer'): 0.00010055756669683373, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055756669683373, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055756669683373, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055756669683373, (0.0, 'TDS'): 35.1951483438918}
#          :    flow_vol : {0.0: 4.5578867414502735}
#          :    pressure : {0.0: 199999.9992}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055857228255656, (0.0, 'Anionic_Polymer'): 0.00010055857228255656, (0.0, 'Cationic_Polymer'): 0.00010055857228255656, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055857228255656, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055857228255656, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055857228255656, (0.0, 'TDS'): 35.19550029889479}
#          :    flow_vol : {0.0: 4.557841162582859}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.122896166927797e-25, (0.0, 'Anionic_Polymer'): -1.122896166927797e-25, (0.0, 'Cationic_Polymer'): -1.122896166927797e-25, (0.0, 'Lime_Suspension_CaOH_2'): -1.122896166927797e-25, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.122896166927797e-25, (0.0, 'Sulphuric_Acid_H2SO4'): -1.122896166927797e-25, (0.0, 'TDS'): 3.625459832926016e-18}
#          :    flow_vol : {0.0: 4.5578867414519664e-05}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost sulfuric_acid_addition
# total_up_cost: 0.6960759870157917
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.sodium_bisulfite_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055857228255656, (0.0, 'Anionic_Polymer'): 0.00010055857228255656, (0.0, 'Cationic_Polymer'): 0.00010055857228255656, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055857228255656, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055857228255656, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055857228255656, (0.0, 'TDS'): 35.19550029889479}
#          :    flow_vol : {0.0: 4.557841162582859}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055957787833532, (0.0, 'Anionic_Polymer'): 0.00010055957787833532, (0.0, 'Cationic_Polymer'): 0.00010055957787833532, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055957787833532, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055957787833532, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055957787833532, (0.0, 'TDS'): 35.195852257417364}
#          :    flow_vol : {0.0: 4.557795584171234}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.774617704412513e-26, (0.0, 'Anionic_Polymer'): 9.774617704412513e-26, (0.0, 'Cationic_Polymer'): 9.774617704412513e-26, (0.0, 'Lime_Suspension_CaOH_2'): 9.774617704412513e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.774617704412513e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 9.774617704412513e-26, (0.0, 'TDS'): -2.5963148020120407e-18}
#          :    flow_vol : {0.0: 4.5578411625335484e-05}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost sodium_bisulfite_addition
# total_up_cost: 1.1967603299519687
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.cartridge_filtration
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010055957787833532, (0.0, 'Anionic_Polymer'): 0.00010055957787833532, (0.0, 'Cationic_Polymer'): 0.00010055957787833532, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010055957787833532, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010055957787833532, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010055957787833532, (0.0, 'TDS'): 35.195852257417364}
#          :    flow_vol : {0.0: 4.557795584171234}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010056058348417016, (0.0, 'Anionic_Polymer'): 0.00010056058348417016, (0.0, 'Cationic_Polymer'): 0.00010056058348417016, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010056058348417016, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010056058348417016, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010056058348417016, (0.0, 'TDS'): 35.19620421945956}
#          :    flow_vol : {0.0: 4.557750006215392}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 3.7161659523151424e-26, (0.0, 'Anionic_Polymer'): 3.7161659523151424e-26, (0.0, 'Cationic_Polymer'): 3.7161659523151424e-26, (0.0, 'Lime_Suspension_CaOH_2'): 3.7161659523151424e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.7161659523151424e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 3.7161659523151424e-26, (0.0, 'TDS'): -8.291923158027566e-19}
#          :    flow_vol : {0.0: 4.557795584148038e-05}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost cartridge_filtration
# total_up_cost: 12.784502940962351
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ro_deep
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00010056058348417016, (0.0, 'Anionic_Polymer'): 0.00010056058348417016, (0.0, 'Cationic_Polymer'): 0.00010056058348417016, (0.0, 'Lime_Suspension_CaOH_2'): 0.00010056058348417016, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00010056058348417016, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00010056058348417016, (0.0, 'TDS'): 35.19620421945956}
#          :    flow_vol : {0.0: 4.557750006215392}
#          :    pressure : {0.0: 199999.9989}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019197690001450987, (0.0, 'Anionic_Polymer'): 0.00019197690001450987, (0.0, 'Cationic_Polymer'): 0.00019197690001450987, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019197690001450987, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019197690001450987, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019197690001450987, (0.0, 'TDS'): 0.5375353200406209}
#          :    flow_vol : {0.0: 2.3874226532742164}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 5.649425850051914e-35, (0.0, 'Anionic_Polymer'): 5.647074861350269e-35, (0.0, 'Cationic_Polymer'): 5.649425850051914e-35, (0.0, 'Lime_Suspension_CaOH_2'): 5.649425850051914e-35, (0.0, 'Sodium_Bisullfite_NaHSO3'): 5.649425850051914e-35, (0.0, 'Sulphuric_Acid_H2SO4'): 5.649425850051914e-35, (0.0, 'TDS'): 73.3217391304348}
#          :    flow_vol : {0.0: 2.170327352941176}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost ro_deep
# total_up_cost: 315.8348268388664
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.lime_softening
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019197690001450987, (0.0, 'Anionic_Polymer'): 0.00019197690001450987, (0.0, 'Cationic_Polymer'): 0.00019197690001450987, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019197690001450987, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019197690001450987, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019197690001450987, (0.0, 'TDS'): 0.5375353200406209}
#          :    flow_vol : {0.0: 2.3874226532742164}
#          :    pressure : {0.0: 199999.9988}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019197881980270788, (0.0, 'Anionic_Polymer'): 0.00019197881980270788, (0.0, 'Cationic_Polymer'): 0.00019197881980270785, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019197881980270788, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019197881980270788, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019197881980270788, (0.0, 'TDS'): 0.5375406954475754}
#          :    flow_vol : {0.0: 2.387398779047684}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.7824558672501643e-27, (0.0, 'Anionic_Polymer'): -1.7824558672501643e-27, (0.0, 'Cationic_Polymer'): -1.7824558672501643e-27, (0.0, 'Lime_Suspension_CaOH_2'): -1.7824558672501643e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.7824558672501643e-27, (0.0, 'Sulphuric_Acid_H2SO4'): -1.7824558672501643e-27, (0.0, 'TDS'): -4.9495935227501626e-23}
#          :    flow_vol : {0.0: 2.3874226532616642e-05}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost lime_softening
# total_up_cost: 57.09453050506802
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.co2_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019197881980270788, (0.0, 'Anionic_Polymer'): 0.00019197881980270788, (0.0, 'Cationic_Polymer'): 0.00019197881980270785, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019197881980270788, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019197881980270788, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019197881980270788, (0.0, 'TDS'): 0.5375406954475754}
#          :    flow_vol : {0.0: 2.387398779047684}
#          :    pressure : {0.0: 199999.9987}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198073961010397, (0.0, 'Anionic_Polymer'): 0.00019198073961010397, (0.0, 'Cationic_Polymer'): 0.00019198073961010397, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198073961010397, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198073961010397, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198073961010397, (0.0, 'TDS'): 0.5375460709082844}
#          :    flow_vol : {0.0: 2.387374905059893}
#          :    pressure : {0.0: 199999.9986}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -4.715416060958598e-28, (0.0, 'Anionic_Polymer'): -4.715416060958598e-28, (0.0, 'Cationic_Polymer'): -4.715416060958598e-28, (0.0, 'Lime_Suspension_CaOH_2'): -4.715416060958598e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): -4.715416060958598e-28, (0.0, 'Sulphuric_Acid_H2SO4'): -4.715416060958598e-28, (0.0, 'TDS'): -1.5433703890076315e-23}
#          :    flow_vol : {0.0: 2.387398779025743e-05}
#          :    pressure : {0.0: 199999.9986}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost co2_addition
# total_up_cost: 8.35890514555387
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.chlorination_twb
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198073961010397, (0.0, 'Anionic_Polymer'): 0.00019198073961010397, (0.0, 'Cationic_Polymer'): 0.00019198073961010397, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198073961010397, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198073961010397, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198073961010397, (0.0, 'TDS'): 0.5375460709082844}
#          :    flow_vol : {0.0: 2.387374905059893}
#          :    pressure : {0.0: 199999.9986}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198265943669833, (0.0, 'Anionic_Polymer'): 0.00019198265943669833, (0.0, 'Cationic_Polymer'): 0.00019198265943669833, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198265943669833, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198265943669833, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198265943669833, (0.0, 'TDS'): 0.5375514464227487}
#          :    flow_vol : {0.0: 2.3873510313108426}
#          :    pressure : {0.0: 199999.9985}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 4.69520150026231e-28, (0.0, 'Anionic_Polymer'): 4.69520150026231e-28, (0.0, 'Cationic_Polymer'): 4.69520150026231e-28, (0.0, 'Lime_Suspension_CaOH_2'): 4.69520150026231e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): 4.69520150026231e-28, (0.0, 'Sulphuric_Acid_H2SO4'): 4.69520150026231e-28, (0.0, 'TDS'): 1.9059889212098328e-23}
#          :    flow_vol : {0.0: 2.387374905056275e-05}
#          :    pressure : {0.0: 199999.9985}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost chlorination_twb
# total_up_cost: 10.058829865506432
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.ammonia_addition
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198265943669833, (0.0, 'Anionic_Polymer'): 0.00019198265943669833, (0.0, 'Cationic_Polymer'): 0.00019198265943669833, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198265943669833, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198265943669833, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198265943669833, (0.0, 'TDS'): 0.5375514464227487}
#          :    flow_vol : {0.0: 2.3873510313108426}
#          :    pressure : {0.0: 199999.9985}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198457928249114, (0.0, 'Anionic_Polymer'): 0.00019198457928249114, (0.0, 'Cationic_Polymer'): 0.00019198457928249114, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198457928249114, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198457928249114, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198457928249114, (0.0, 'TDS'): 0.5375568219909685}
#          :    flow_vol : {0.0: 2.3873271578005295}
#          :    pressure : {0.0: 199999.99839999998}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 9.839930456984155e-28, (0.0, 'Anionic_Polymer'): 9.839930456984155e-28, (0.0, 'Cationic_Polymer'): 9.839930456984155e-28, (0.0, 'Lime_Suspension_CaOH_2'): 9.839930456984155e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): 9.839930456984155e-28, (0.0, 'Sulphuric_Acid_H2SO4'): 9.839930456984155e-28, (0.0, 'TDS'): 5.392345176793438e-23}
#          :    flow_vol : {0.0: 2.3873510313088516e-05}
#          :    pressure : {0.0: 199999.99839999998}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost ammonia_addition
# total_up_cost: 0.8626694900202977
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.treated_storage_24_hr
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198457928249114, (0.0, 'Anionic_Polymer'): 0.00019198457928249114, (0.0, 'Cationic_Polymer'): 0.00019198457928249114, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198457928249114, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198457928249114, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198457928249114, (0.0, 'TDS'): 0.5375568219909685}
#          :    flow_vol : {0.0: 2.3873271578005295}
#          :    pressure : {0.0: 199999.99839999998}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001919864991474826, (0.0, 'Anionic_Polymer'): 0.0001919864991474826, (0.0, 'Cationic_Polymer'): 0.00019198649914748263, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001919864991474826, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001919864991474826, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001919864991474826, (0.0, 'TDS'): 0.5375621976129445}
#          :    flow_vol : {0.0: 2.3873032845289517}
#          :    pressure : {0.0: 199999.9983}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.6476099562639476e-28, (0.0, 'Anionic_Polymer'): -1.6476099562639476e-28, (0.0, 'Cationic_Polymer'): -1.6476099562639476e-28, (0.0, 'Lime_Suspension_CaOH_2'): -1.6476099562639476e-28, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.6476099562639476e-28, (0.0, 'Sulphuric_Acid_H2SO4'): -1.6476099562639476e-28, (0.0, 'TDS'): -1.449423997171775e-23}
#          :    flow_vol : {0.0: 2.387327157783472e-05}
#          :    pressure : {0.0: 199999.9983}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost treated_storage_24_hr
# total_up_cost: 12.871388114125123
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.municipal_drinking
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.0001919864991474826, (0.0, 'Anionic_Polymer'): 0.0001919864991474826, (0.0, 'Cationic_Polymer'): 0.00019198649914748263, (0.0, 'Lime_Suspension_CaOH_2'): 0.0001919864991474826, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.0001919864991474826, (0.0, 'Sulphuric_Acid_H2SO4'): 0.0001919864991474826, (0.0, 'TDS'): 0.5375621976129445}
#          :    flow_vol : {0.0: 2.3873032845289517}
#          :    pressure : {0.0: 199999.9983}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 0.00019198841903167292, (0.0, 'Anionic_Polymer'): 0.00019198841903167292, (0.0, 'Cationic_Polymer'): 0.00019198841903167292, (0.0, 'Lime_Suspension_CaOH_2'): 0.00019198841903167292, (0.0, 'Sodium_Bisullfite_NaHSO3'): 0.00019198841903167292, (0.0, 'Sulphuric_Acid_H2SO4'): 0.00019198841903167292, (0.0, 'TDS'): 0.5375675732886775}
#          :    flow_vol : {0.0: 2.3872794114961065}
#          :    pressure : {0.0: 199999.9982}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 6.61788047490342e-30, (0.0, 'Anionic_Polymer'): 6.61788047490342e-30, (0.0, 'Cationic_Polymer'): 6.617687881908981e-30, (0.0, 'Lime_Suspension_CaOH_2'): 6.617687881908981e-30, (0.0, 'Sodium_Bisullfite_NaHSO3'): 6.617687881908981e-30, (0.0, 'Sulphuric_Acid_H2SO4'): 6.61788047490342e-30, (0.0, 'TDS'): 1.3672931639743187e-26}
#          :    flow_vol : {0.0: 2.3873032845245468e-05}
#          :    pressure : {0.0: 199999.9982}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost municipal_drinking
# total_up_cost: 7.755212050892839
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.mixer2
# inlet1 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -1.7664173389708896e-26, (0.0, 'Anionic_Polymer'): -1.7664173389708896e-26, (0.0, 'Cationic_Polymer'): -1.7664173389708896e-26, (0.0, 'Lime_Suspension_CaOH_2'): -1.7664173389708896e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): -1.7664173389708896e-26, (0.0, 'Sulphuric_Acid_H2SO4'): -1.7664173389708896e-26, (0.0, 'TDS'): 2.2274848930419963e-18}
#          :    flow_vol : {0.0: 4.583299999971757e-05}
#          :    pressure : {0.0: 199999.9998}
#          : temperature : {0.0: 300.0}
# inlet2 : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 1.4567894336716425e-26, (0.0, 'Anionic_Polymer'): 1.4567894336716425e-26, (0.0, 'Cationic_Polymer'): 1.4567894336716425e-26, (0.0, 'Lime_Suspension_CaOH_2'): 1.4567894336716425e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 1.4567894336716425e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 1.4567894336716425e-26, (0.0, 'TDS'): -1.1090837653110995e-18}
#          :    flow_vol : {0.0: 4.583254166945494e-05}
#          :    pressure : {0.0: 199999.9997}
#          : temperature : {0.0: 300.0}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.9535941256501125e-33, (0.0, 'Anionic_Polymer'): 3.3636065552169264e-33, (0.0, 'Cationic_Polymer'): 3.0649369505599996e-33, (0.0, 'Lime_Suspension_CaOH_2'): 3.0732124307897885e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.0483859901004217e-33, (0.0, 'Sulphuric_Acid_H2SO4'): 2.9535941256501125e-33, (0.0, 'TDS'): 73.30999206340844}
#          :    flow_vol : {0.0: 2.1706751224629914}
#          :    pressure : {0.0: 199999.9987909091}
#          : temperature : {0.0: 299.9997363636364}
# Show some costing values
# ---------------------
# should skip: mixer2
# ----------------------------------------------------------------------
# fs.surface_discharge
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 2.9535941256501125e-33, (0.0, 'Anionic_Polymer'): 3.3636065552169264e-33, (0.0, 'Cationic_Polymer'): 3.0649369505599996e-33, (0.0, 'Lime_Suspension_CaOH_2'): 3.0732124307897885e-33, (0.0, 'Sodium_Bisullfite_NaHSO3'): 3.0483859901004217e-33, (0.0, 'Sulphuric_Acid_H2SO4'): 2.9535941256501125e-33, (0.0, 'TDS'): 73.30999206340844}
#          :    flow_vol : {0.0: 2.1706751224629914}
#          :    pressure : {0.0: 199999.9987909091}
#          : temperature : {0.0: 299.9997363636364}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): 5.605330048138421e-26, (0.0, 'Anionic_Polymer'): 5.605330048138421e-26, (0.0, 'Cationic_Polymer'): 5.605330048138421e-26, (0.0, 'Lime_Suspension_CaOH_2'): 5.605330048138421e-26, (0.0, 'Sodium_Bisullfite_NaHSO3'): 5.605330048138421e-26, (0.0, 'Sulphuric_Acid_H2SO4'): 5.605330048138421e-26, (0.0, 'TDS'): 73.31072517066015}
#          :    flow_vol : {0.0: 2.170653415711767}
#          :    pressure : {0.0: 199999.9986909091}
#          : temperature : {0.0: 299.9997363636364}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -3.8720219678797756e-31, (0.0, 'Anionic_Polymer'): -3.8720219678797756e-31, (0.0, 'Cationic_Polymer'): -3.8720219678797756e-31, (0.0, 'Lime_Suspension_CaOH_2'): -3.8720219678797756e-31, (0.0, 'Sodium_Bisullfite_NaHSO3'): -3.8720219678797756e-31, (0.0, 'Sulphuric_Acid_H2SO4'): -3.8720219678797756e-31, (0.0, 'TDS'): -4.532984088017187e-24}
#          :    flow_vol : {0.0: 2.1706751224470388e-05}
#          :    pressure : {0.0: 199999.9986909091}
#          : temperature : {0.0: 299.9997363636364}
# Show some costing values
# ---------------------
# should have a cost surface_discharge
# total_up_cost: 31.44724160178448
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# fs.landfill
# inlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -8.425943506694157e-35, (0.0, 'Anionic_Polymer'): -8.425943506694157e-35, (0.0, 'Cationic_Polymer'): -8.425943506694157e-35, (0.0, 'Lime_Suspension_CaOH_2'): -8.425943506694157e-35, (0.0, 'Sodium_Bisullfite_NaHSO3'): -8.425943506694157e-35, (0.0, 'Sulphuric_Acid_H2SO4'): -8.425943506694157e-35, (0.0, 'TDS'): 1.1107161545511846e-27}
#          :    flow_vol : {0.0: 0.025321593008057103}
#          :    pressure : {0.0: 199999.9991}
#          : temperature : {0.0: 299.9998}
# outlet : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -4.437342591868191e-31, (0.0, 'Anionic_Polymer'): -4.437342591868191e-31, (0.0, 'Cationic_Polymer'): -4.437342591868191e-31, (0.0, 'Lime_Suspension_CaOH_2'): -4.437342591868191e-31, (0.0, 'Sodium_Bisullfite_NaHSO3'): -4.437342591868191e-31, (0.0, 'Sulphuric_Acid_H2SO4'): -4.437342591868191e-31, (0.0, 'TDS'): 1.1107161545511846e-27}
#          :    flow_vol : {0.0: 0.025321339792127025}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 299.9998}
# waste : Size=1
#     Key  : Name        : Value
#     None :   conc_mass : {(0.0, 'Aluminum_Al2_SO4_3'): -5.3309247822572925e-27, (0.0, 'Anionic_Polymer'): -5.3309247822572925e-27, (0.0, 'Cationic_Polymer'): -5.3309247822572925e-27, (0.0, 'Lime_Suspension_CaOH_2'): -5.3309247822572925e-27, (0.0, 'Sodium_Bisullfite_NaHSO3'): -5.3309247822572925e-27, (0.0, 'Sulphuric_Acid_H2SO4'): -5.3309247822572925e-27, (0.0, 'TDS'): -5.416318975247467e-27}
#          :    flow_vol : {0.0: 2.5321593007804376e-07}
#          :    pressure : {0.0: 199999.99899999998}
#          : temperature : {0.0: 299.9998}
# Show some costing values
# ---------------------
# should have a cost landfill
# total_up_cost: 0.007911371170027453
# ----------------------------------------------------------------------

# %% [markdown]
# #### 7. Look at the results table.

# %%
wt.get_results_table(m = m).head()
# Out:
#    Unit Process Name                        Variable   Value Metric    Unit  \
# 0  sw_onshore_intake  Fixed Capital Investment (FCI)  20.980   Cost     $MM
# 1  sw_onshore_intake                            Land   0.031   Cost     $MM
# 2  sw_onshore_intake                 Working Capital   1.049   Cost     $MM
# 3  sw_onshore_intake  Total Capital Investment (TCI)  22.061   Cost     $MM
# 4  sw_onshore_intake         Catalysts and Chemicals   0.000   Cost  $MM/yr
#
#   Case Study  Scenario
# 0   Carlsbad  Baseline
# 1   Carlsbad  Baseline
# 2   Carlsbad  Baseline
# 3   Carlsbad  Baseline
# 4   Carlsbad  Baseline

# %%
df = wt.get_results_table(m = m)
df[df["Unit Process Name"] == "ro_deep"].head(20)
# Out:
#     Unit Process Name                        Variable    Value       Metric  \
# 366           ro_deep  Fixed Capital Investment (FCI)  264.575         Cost
# 367           ro_deep                            Land    0.397         Cost
# 368           ro_deep                 Working Capital   13.229         Cost
# 369           ro_deep  Total Capital Investment (TCI)  278.200         Cost
# 370           ro_deep         Catalysts and Chemicals    0.000         Cost
# 371           ro_deep                     Electricity   33.665         Cost
# 372           ro_deep                 Other Operating    0.000         Cost
# 373           ro_deep               Employee Salaries    0.279         Cost
# 374           ro_deep                        Benefits    0.251         Cost
# 375           ro_deep                     Maintenance    2.117         Cost
# 376           ro_deep                      Laboratory    0.794         Cost
# 377           ro_deep             Insurance and Taxes    0.529         Cost
# 378           ro_deep          Total Fixed Operating     3.970         Cost
# 379           ro_deep            Base Employee Salary    0.222         Cost
# 380           ro_deep         Electricity consumption    1.747  Electricity
# 381           ro_deep                 Total Unit Cost  315.835         Cost
# 382           ro_deep                     Inlet Water    4.558   Water Flow
# 383           ro_deep                    Outlet Water    2.387   Water Flow
# 384           ro_deep                     Waste Water    2.170   Water Flow
# 385           ro_deep               Inlet Constituent   35.196          TDS
#
#        Unit Case Study  Scenario
# 366     $MM   Carlsbad  Baseline
# 367     $MM   Carlsbad  Baseline
# 368     $MM   Carlsbad  Baseline
# 369     $MM   Carlsbad  Baseline
# 370  $MM/yr   Carlsbad  Baseline
# 371  $MM/yr   Carlsbad  Baseline
# 372  $MM/yr   Carlsbad  Baseline
# 373  $MM/yr   Carlsbad  Baseline
# 374  $MM/yr   Carlsbad  Baseline
# 375  $MM/yr   Carlsbad  Baseline
# 376  $MM/yr   Carlsbad  Baseline
# 377  $MM/yr   Carlsbad  Baseline
# 378  $MM/yr   Carlsbad  Baseline
# 379  $MM/yr   Carlsbad  Baseline
# 380  kWh/m3   Carlsbad  Baseline
# 381     $MM   Carlsbad  Baseline
# 382    m3/s   Carlsbad  Baseline
# 383    m3/s   Carlsbad  Baseline
# 384    m3/s   Carlsbad  Baseline
# 385   kg/m3   Carlsbad  Baseline

# %% [markdown]
# #### 8. View results using Dash.

# %%
csv_dir = './results/Carlsbad_Baseline_results.csv'
json_dir = './tmp/example.json'

wt.run_dash(csv_dir, json_dir)
# Out:
# Dash app running on http://127.0.0.1:8055/

# %% [markdown]
# #### 9. Sensitivity Analysis

# %%
import numpy as np
import pandas as pd
from pyomo.environ import value
import time

# %%
#tds_range = np.arange(1, 200)
#backwash_scenario = [1e-5, 0.5, 0.95]

tds_range = np.arange(30, 50)
backwash_scenario = [0.95]
pmax_range = np.arange(70, 120)

# %%
startTime = time.time()

lcow_list = []
recovery_list = []
scenario_list = []
tds_list = []

final_df = pd.DataFrame()

for pmax_scenario in pmax_range:

    for bw_scenario in backwash_scenario:

        #for value_change in pct_to_target1: # cycles through each value from MC range
        for tds_value in tds_range:

            # create and build model
            m = wt.watertap_setup(dynamic = False)
            m = wt.case_study_trains.get_case_study(flow = 4.5833, m = m)

            m.fs.backwash_solids_handling.water_recovery.fix(bw_scenario)
            m.fs.ro_deep.pmax.fix(pmax_scenario)
            m.fs.source1.conc_mass_in[0, "TDS"].fix(tds_value)

            wt.run_water_tap(m = m, solver_results = False, print_model_results = False)

            #df = wt.get_results_table(m = m)
            #df[df["Unit Process Name"] == "System"]
            inlet_flow = value(m.fs.municipal_drinking.flow_vol_in[0])
            outlet_flow = value(m.fs.source1.flow_vol_in[0])
            recovery_list.append(inlet_flow / outlet_flow)
            scenario_list.append(bw_scenario)
            tds_list.append(value(m.fs.source1.conc_mass_in[0, "TDS"]))
            lcow_list.append(value(m.fs.costing.LCOW))

final_df["sys_recovery"] = recovery_list
final_df["lcow"] = lcow_list
final_df["tds_inlet"] = tds_list
final_df["bw_scenario"] = scenario_list

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
# Out:
# Execution time in seconds: 630.648943901062

# %%
final_df
# Out:
#      sys_recovery      lcow  tds_inlet  bw_scenario
# 0        0.501543  1.271385         30         0.95
# 1        0.485115  1.294468         31         0.95
# 2        0.468688  1.318849         32         0.95
# 3        0.452260  1.344662         33         0.95
# 4        0.435832  1.372060         34         0.95
# ..            ...       ...        ...          ...
# 995      0.559523  1.488564         45         0.95
# 996      0.549860  1.506721         46         0.95
# 997      0.540197  1.525484         47         0.95
# 998      0.530533  1.544889         48         0.95
# 999      0.520870  1.564972         49         0.95
#
# [1000 rows x 4 columns]

# %%
final_df.sys_recovery.max()
# Out:
# 0.9808469597751073

# %%
final_df.to_csv("/Users/amiara/Desktop/wt3_test.csv")

# %%
value(m.fs.ro_deep.conc_mass_in[0, "TDS"])
# Out:
# 99.22718348204131

# %%
value(m.fs.source1.conc_mass_in[0, "TDS"])
# Out:
# 94

# %%
value(m.fs.backwash_solids_handling.water_recovery[0])
# Out:
# 0.5

# %%
value(m.fs.ro_deep.conc_mass_in[0, "TDS"])
# Out:
# 20.056558363417363

# %%
value(m.fs.ro_deep.conc_mass_out[0, "TDS"])
# Out:
# 0.2202061671389632

# %%
value(m.fs.ro_deep.conc_mass_waste[0, "TDS"])
# Out:
# 73.32173913043476

# %%
value(m.fs.ro_deep.flow_vol_in[0])
# Out:
# 4.3418565848683475

# %%
value(m.fs.ro_deep.flow_vol_out[0])
# Out:
# 3.163678878985994

# %%
value(m.fs.ro_deep.flow_vol_waste[0])
# Out:
# 1.1781777058823533

# %%
#### DO NOT USE THE BELOW ####

# %%
cost_range_list = []; #results will be inputted in this array
#up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.

#for value_change in pct_to_target1: # cycles through each value from MC range
for value_change in [0.4, 0.8]: #, 0.9]:

    # create and build model
    m = wt.watertap_setup(dynamic = False)
    m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

    m.fs.tri_media_filtration.water_recovery.fix(value_change)

    # set variable to MC value
    wt.run_water_tap(m)
    results_table = get_results_table(m, unit_process_name)
    cost_range_list.append(results_table.total_up_cost.sum())

# %%
import time
from multiprocessing import Pool
import multiprocessing

mu = 0.6
sigma = .1
num_reps = 50

input_list = np.random.normal(mu,sigma, size = num_reps) #, sigma, num_reps).round(4)

count, bins, ignored = plt.hist(input_list, 25, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
          linewidth=2, color='r')
plt.show()

### INPUT TO MODEL LIST: ### CAN BE AUTOMATED FOR USER TO LABEL THE VARIABLE. TOOD ###
no_of_proc = 4
list_final = []
for i in range(no_of_proc):
    part2 = len(input_list) / no_of_proc
    i2 = ((i+1)*part2)
    list1 = input_list[int(i*part2):int(i2)]
    list_final.append(list1)
    
    
def monte_run(list_final):
    print('goes in')

    up_name = "tri_media_filtration" # which unit process it applies to. TODO hould be user input.
    cost_range_list = []; #results will be inputted in this array

    #for value_change in pct_to_target1: # cycles through each value from MC range
    for value_change in list_final:

        # create and build model
        m = wt.watertap_setup(dynamic = False)
        m = wt.case_study_trains.get_case_study(name = 'carlsbad', flow = 4.5833, m = m)

        getattr(m.fs, up_name).water_recovery.fix(value_change)

        # set variable to MC value
        result = wt.run_water_tap(m)
        results_table = get_results_table(m, unit_process_names)
        cost_range_list.append(results_table.total_up_cost.sum())


    return cost_range_list

startTime = time.time()

pool=Pool()
dfs = pool.map(monte_run, list_final) #SomeClass().preprocess_data()

executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
####TO DO LOAD AND SAVE!!

# %%
#### SAVE TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# wt.save_train(T, path)

# %%
# #### LOAD TRAIN ####
# path = 'trains/Tutorial1_treatment_train_example.csv'
# TT = wt.load_train(path)

# %%
# wt.display.show_train(TT)
