# %%
import watertap as wt
import pandas as pd
from pyomo.environ import value, Block
from idaes.core import FlowsheetBlock
import numpy as np
from case_study_trains import *
import case_study_trains
import pyomo.environ as env
from pyomo.environ import Constraint
m = wt.watertap_setup(dynamic=False)


wt.case_study_trains.train = {"case_study": "gila_river",
                             "reference": "nawi",
                             "scenario": "baseline"}


wt.case_study_trains.source_water = {"case_study": "gila_river", 
                             "reference": "nawi",
                             "scenario": "baseline",
                             "water_type": "gila_river_water"}

m = wt.case_study_trains.get_case_study(m=m)
# Out:
# gila_river
#
# ------- Adding Unit Processes -------
# cooling_tower
# assuming cycles of concentration is: 5.0
# holding_tank
# brine_concentrator
# evaporation_pond
# industrial_a
# ultra_filtration
# reverse_osmosis
# industrial_b
# -------------------------------------
#
# adding source
# adding splitter
#
# Connecting unit processes...

# %%
wt.display.show_train2(model_name=m)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="tmp/example.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# RUN MODEL with optimal ro so that the model solves. Then runs again with set pressure.

# %%
# # RUN MODEL with optimal ro --> estimating area and pressure for optimal LCOW
# so that the model solves and gets you results. Then runs again with set pressure.
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).feed.pressure.unfix()
        getattr(m.fs, key).membrane_area.unfix()
        print("Unfixing feed presure and area for", key, '...\n')
        
        
wt.run_water_tap(m=m, objective=True, skip_small=False)

# prints RO results
print("\nOptimal RO area and pressures:")
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(f'\tFeed pressure for {key}: {round(getattr(m.fs, key).feed.pressure[0](), 2)} bar')
        print(f'\tMembrane area for {key}: {round(getattr(m.fs, key).membrane_area[0](), 2)} m2')

# RESET PRESSURE TO USER INPUT
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        if "feed_pressure" in m.fs.pfd_dict[key]["Parameter"]:
            getattr(m.fs, key).feed.pressure.fix(m.fs.pfd_dict[key]["Parameter"]["feed_pressure"])
            print(f'\nSetting feed presure for {key} to {m.fs.pfd_dict[key]["Parameter"]["feed_pressure"]} bar (user input)...\n')

wt.run_water_tap(m=m, objective=True, print_model_results="summary")

for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(f'\tFeed pressure for {key}: {round(getattr(m.fs, key).feed.pressure[0](), 2)} bar')
        print(f'\tMembrane area: for {key}: {round(getattr(m.fs, key).membrane_area[0](), 2)} m2')
# Out:
# Unfixing feed presure and area for reverse_osmosis ...
#
# Flow is relatively small (< 1 m3/s). Running model with larger dummy flows to initialize...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
# Model finished running to initialize conditions. Now running with actual flow...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 2
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# Optimal RO area and pressures:
# 	Feed pressure for reverse_osmosis: 36.62 bar
# 	Membrane area for reverse_osmosis: 37080.46 m2
#
# Setting feed presure for reverse_osmosis to 30 bar (user input)...
#
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 1
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# COOLING TOWER:
#
# 	total cap investment: 0.0
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# HOLDING TANK:
#
# 	total cap investment: 25.80952
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.34368
#
# BRINE CONCENTRATOR:
#
# 	total cap investment: 103.82562
# 	cat and chem cost: 0.0
# 	electricity cost: 13.56584
# 	total fixed op cost: 1.38256
#
# EVAPORATION POND:
#
# 	total cap investment: 5.95841
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.07934
#
# INDUSTRIAL A:
#
# 	total cap investment: 0.71436
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03317
# 	total fixed op cost: 0.00948
#
# ULTRA FILTRATION:
#
# 	total cap investment: 19.09059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.15837
# 	total fixed op cost: 0.25421
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 5.69531
# 	cat and chem cost: 0.05416
# 	electricity cost: 0.61591
# 	total fixed op cost: 0.07555
#
# INDUSTRIAL B:
#
# 	total cap investment: 0.68782
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03175
# 	total fixed op cost: 0.00913
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 161.782
# Annual Fixed Operating Cost ($MM/yr) 2.154
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.054
# Annual Electricity Costs ($MM/yr) 14.405
# Annual Other Variable Costs ($MM/yr) 0.273
# Annual Operating Costs ($MM/yr) 16.886
# Treated water (m3/s) ---> 0.545
# Total water recovery (%) ---> 83.662
# Electricity intensity (kwh/m3) --->  11.325
# LCOW ($/m3) --->  1.595
# Electricity portion of LCOW (%) ---> 52.554
# ----------------------------------------------------------------------
# 	Feed pressure for reverse_osmosis: 30 bar
# 	Membrane area: for reverse_osmosis: 45491.28 m2

# %%
wt.run_water_tap(m=m, objective=True, print_model_results="summary")
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        print(key, "feed pressure", getattr(m.fs, key).feed.pressure[0]())
        print(key, "membrane area", getattr(m.fs, key).membrane_area[0]())
# Out:
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 1
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# COOLING TOWER:
#
# 	total cap investment: 0.0
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# HOLDING TANK:
#
# 	total cap investment: 25.80952
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.34368
#
# BRINE CONCENTRATOR:
#
# 	total cap investment: 103.82562
# 	cat and chem cost: 0.0
# 	electricity cost: 13.56584
# 	total fixed op cost: 1.38256
#
# EVAPORATION POND:
#
# 	total cap investment: 5.95841
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.07934
#
# INDUSTRIAL A:
#
# 	total cap investment: 0.71436
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03317
# 	total fixed op cost: 0.00948
#
# ULTRA FILTRATION:
#
# 	total cap investment: 19.09059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.15837
# 	total fixed op cost: 0.25421
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 5.69531
# 	cat and chem cost: 0.05416
# 	electricity cost: 0.61591
# 	total fixed op cost: 0.07555
#
# INDUSTRIAL B:
#
# 	total cap investment: 0.68782
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03175
# 	total fixed op cost: 0.00913
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 161.782
# Annual Fixed Operating Cost ($MM/yr) 2.154
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.054
# Annual Electricity Costs ($MM/yr) 14.405
# Annual Other Variable Costs ($MM/yr) 0.273
# Annual Operating Costs ($MM/yr) 16.886
# Treated water (m3/s) ---> 0.545
# Total water recovery (%) ---> 83.662
# Electricity intensity (kwh/m3) --->  11.325
# LCOW ($/m3) --->  1.595
# Electricity portion of LCOW (%) ---> 52.554
# ----------------------------------------------------------------------
# reverse_osmosis feed pressure 30
# reverse_osmosis membrane area 45491.28020516562

# %%
# RESET AREA BASED ON RO RECOVERY
for key in m.fs.pfd_dict.keys():
    if m.fs.pfd_dict[key]["Unit"] == "reverse_osmosis":
        getattr(m.fs, key).membrane_area.fix(getattr(m.fs, key).membrane_area[0]())

# %%
# Readjust recovery constraint and deactivate objective constraint
m.fs.objective_function.deactivate() # deactivate LCOW objective function

# %%
# NOW RUN AS SIMULATION
wt.run_water_tap(m=m, objective=False, print_model_results="summary")
# Out:
# ----------------------------------------------------------------------
#
# Degrees of Freedom: 0
#
# WaterTAP3 solution optimal
#
# ----------------------------------------------------------------------
#
# ***UNIT PROCESS RESULTS (in $MM)***
#
#
# COOLING TOWER:
#
# 	total cap investment: 0.0
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.0
#
# HOLDING TANK:
#
# 	total cap investment: 25.80952
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.34368
#
# BRINE CONCENTRATOR:
#
# 	total cap investment: 103.82562
# 	cat and chem cost: 0.0
# 	electricity cost: 13.56584
# 	total fixed op cost: 1.38256
#
# EVAPORATION POND:
#
# 	total cap investment: 5.95841
# 	cat and chem cost: 0.0
# 	electricity cost: 0.0
# 	total fixed op cost: 0.07934
#
# INDUSTRIAL A:
#
# 	total cap investment: 0.71436
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03317
# 	total fixed op cost: 0.00948
#
# ULTRA FILTRATION:
#
# 	total cap investment: 19.09059
# 	cat and chem cost: 0.0
# 	electricity cost: 0.15837
# 	total fixed op cost: 0.25421
#
# REVERSE OSMOSIS:
#
# 	total cap investment: 5.69531
# 	cat and chem cost: 0.05416
# 	electricity cost: 0.61591
# 	total fixed op cost: 0.07555
#
# INDUSTRIAL B:
#
# 	total cap investment: 0.68782
# 	cat and chem cost: 0.0
# 	electricity cost: 0.03175
# 	total fixed op cost: 0.00913
#
# ----------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------
# ------------------- System Level Metrics and Costs -------------------
# Total Capital Investment ($MM) 161.782
# Annual Fixed Operating Cost ($MM/yr) 2.154
# Annual Catalysts and Chemicals Cost ($MM/yr) 0.054
# Annual Electricity Costs ($MM/yr) 14.405
# Annual Other Variable Costs ($MM/yr) 0.273
# Annual Operating Costs ($MM/yr) 16.886
# Treated water (m3/s) ---> 0.545
# Total water recovery (%) ---> 83.662
# Electricity intensity (kwh/m3) --->  11.325
# LCOW ($/m3) --->  1.595
# Electricity portion of LCOW (%) ---> 52.554
# ----------------------------------------------------------------------

# %%
# creates csv in results folder with the name: *case_study*_*scenario*.csv
# In this case, save the final baseline result.

df = wt.get_results_table(m=m, case_study=wt.case_study_trains.source_water["case_study"], 
                                scenario=wt.case_study_trains.source_water["scenario"])
